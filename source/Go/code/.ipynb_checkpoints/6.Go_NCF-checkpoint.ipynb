# %% [markdown]
# # NCF Cornac

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ncf_data.csv')
df.rename(columns = {'p_id' : 'itemID', 'u_id' : 'userID', 'u_rate' : 'rating'}, inplace = True)

# %%
# df = df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
# df[df['userID'] == '진규 이']
# Out:
#       itemID userID  rating
# 3650     237   진규 이       4
# 4320     592   진규 이       3
# 5370     828   진규 이       3
# 5789     418   진규 이       4
# 7196     591   진규 이       4
# 8773     341   진규 이       4
# 11450      4   진규 이       4
# 12524    225   진규 이       4
# 13562      0   진규 이       3
# 14119   1404   진규 이       4
# 15055      1   진규 이       2
# 15421    595   진규 이       4
# 16430    556   진규 이       4
# 18349     79   진규 이       4
# 19103      2   진규 이       4
# 19542    757   진규 이       4
# 20899    596   진규 이       4
# 22426   1059   진규 이       3
# 23149     23   진규 이       4
# 23392     22   진규 이       4
# 24637    280   진규 이       4
# 24876    121   진규 이       4
# 26180     34   진규 이       4
# 27413    492   진규 이       4
# 28241    685   진규 이       4
# 28862    120   진규 이       4
# 31106    441   진규 이       2
# 31532    251   진규 이       2
# 31815    872   진규 이       3
# 32822     26   진규 이       5
# 35642    244   진규 이       4
# 35993    881   진규 이       4
# 36193    499   진규 이       4
# 38830    105   진규 이       4
# 39842   1446   진규 이       4
# 43664   1136   진규 이       4
# 44241    460   진규 이       4
# 44297    851   진규 이       4
# 44538    110   진규 이       4
# 44923    702   진규 이       4
# 46464    311   진규 이       4
# 47233    661   진규 이       4
# 48224    772   진규 이       4
# 49546    410   진규 이       4
# 50067    439   진규 이       3
# 51726     74   진규 이       4
# 52341   1344   진규 이       4
# 53259    598   진규 이       4
# 56095    823   진규 이       4
# 57540    572   진규 이       4
# 58578   1169   진규 이       4
# 58768    167   진규 이       5
# 59493    213   진규 이       4
# 60709    159   진규 이       3

# %%
df.reset_index(inplace=True)
df
# Out:
#        index itemID      userID  rating
# 0          0   f239   batoo2000     5.0
# 1          1   f239  Woongs Lee     5.0
# 2          2   f239         박우석     5.0
# 3          3   f239         EOS     5.0
# 4          4   f239         ㅎㅈㅊ     4.0
# ...      ...    ...         ...     ...
# 50881  50881    572           쥬     NaN
# 50882  50882    595           쥬     NaN
# 50883  50883    213           쥬     NaN
# 50884  50884    685           쥬     NaN
# 50885  50885      3           쥬     NaN
#
# [50886 rows x 4 columns]

# %%
ls=[]
for i in range (0,len(df)):
    new_tuple = (df['userID'][i], df['itemID'][i], df['rating'][i])
    ls.append(new_tuple)

# %%
ls
# Out:
# [('batoo2000', 'f239', 5.0),
#  ('Woongs Lee', 'f239', 5.0),
#  ('박우석', 'f239', 5.0),
#  ('EOS', 'f239', 5.0),
#  ('ㅎㅈㅊ', 'f239', 4.0),
#  ('한효선', 'b209', 4.0),
#  ('백지현', 'e810', 3.0),
#  ('uni', 'e810', 1.0),
#  ('Hannah-Gahee U♥', 'a211', 5.0),
#  ('김세미', 'a211', 5.0),
#  ('쑨꿍', 'a211', 5.0),
#  ('제주벼', 'a211', 2.0),
#  ('혜진', 'a211', 5.0),
#  ('L', 'a211', 2.0),
#  ('작은배', 'a211', 1.0),
#  ('jw', 'a211', 1.0),
#  ('정원', 'a211', 5.0),
#  ('꿀벌', 'a211', 1.0),
#  ('바지우', 'a211', 1.0),
#  ('fjhndklhvnkl', 'a211', 5.0),
#  ('eodeoddl', 'a211', 5.0),
#  ('나상준', 'a211', 5.0),
#  ('문수', 'a211', 5.0),
#  ('ㅎㅎ', 'a211', 5.0),
#  ('김진영', 'a211', 5.0),
#  ('이동훈', 'a211', 5.0),
#  ('서수진', 'a211', 1.0),
#  ('안영준', 'a211', 1.0),
#  ('ryu', 'a211', 1.0),
#  ('볼링마니아', 'a211', 1.0),
#  ('시닝', 'a211', 1.0),
#  ('zjffltmxj', 'a211', 1.0),
#  ('영원관세법인', 'a211', 1.0),
#  ('이정근', 'a211', 5.0),
#  ('카카카', 'a211', 5.0),
#  ('비호', 'a211', 1.0),
#  ('자의식', 'a211', 3.0),
#  ('쥴리', 'b44', 3.0),
#  ('2020년 화이팅!', 'b44', 5.0),
#  ('DAAS', 'b44', 5.0),
#  ('윤오', 'f206', 5.0),
#  ('용이', 'f206', 5.0),
#  ('김가현', 'f20', 5.0),
#  ('태찌', 'f20', 3.0),
#  ('솔직한평가', 'g112', 5.0),
#  ('chloe', 'g112', 5.0),
#  ('노웅철', 'g112', 5.0),
#  ('김철호', 'g112', 5.0),
#  ('개금장', 'g112', 5.0),
#  ('아닌건 아니다', 'b88', 1.0),
#  ('장원혁', 'g327', 1.0),
#  ('륜하', 'g115', 5.0),
#  ('뽁뽁이', 'd15', 5.0),
#  ('은경이', 'd15', 5.0),
#  ('young', 'f27', 1.0),
#  ('박민지', 'b43', 3.0),
#  ('ㅇㅎ', 'f201', 3.0),
#  ('김현진', 'f201', 5.0),
#  ('권세윤', 'f201', 5.0),
#  ('Equity', 'f201', 2.0),
#  ('김혜진', 'a811', 5.0),
#  ('예옹', 'f208', 1.0),
#  ('황영주', 'f208', 1.0),
#  ('현', 'f208', 1.0),
#  ('motive', 'f208', 2.0),
#  ('서재원', 'f208', 2.0),
#  ('박성인', 'e210', 1.0),
#  ('이현정', 'e210', 5.0),
#  ('다다다', 'e210', 4.0),
#  ('만경이', 'e210', 4.0),
#  ('평점가', 'e210', 3.0),
#  ('구름별', 'g311', 5.0),
#  ('전성배', 'g311', 5.0),
#  ('지정현', 'g311', 5.0),
#  ('KM', 'g123', 1.0),
#  ('김미희', 'g123', 5.0),
#  ('dawon', 'g123', 5.0),
#  ('ㄱㄱㅑ', 'f237', 3.0),
#  ('고먐미', 'c113', 1.0),
#  ('홍', 'c113', 3.0),
#  ('이수광', 'c113', 5.0),
#  ('686', 'f29', 4.0),
#  ('류정진', 'f16', 5.0),
#  ('HG', 'f16', 5.0),
#  ('영수운', 'f16', 5.0),
#  ('JY', 'f16', 5.0),
#  ('뭔데말해바', 'f16', 5.0),
#  ('나먄아니면되', 'd24', 2.0),
#  ('영더', 'd24', 1.0),
#  ('으에엥', 'd24', 1.0),
#  ('뿌애애애', 'd24', 1.0),
#  ('뿌애애애', 'd24', 1.0),
#  ('다라', 'c114', 1.0),
#  ('짠티항', 'c114', 5.0),
#  ('전대운(lucas)', 'c114', 4.0),
#  ('신논현 네일한 나', 'f230', 5.0),
#  ('JL', 'f230', 1.0),
#  ('김소라', 'b72', 5.0),
#  ('이제현', 'b72', 5.0),
#  ('용성', 'g124', 1.0),
#  ('호두과자', 'b2410', 2.0),
#  ('piazza', 'b2410', 1.0),
#  ('별맘', 'b86', 3.0),
#  ('Jae-Gyung Ahn', 'b200', 5.0),
#  ('서슐랭', 'b200', 4.0),
#  ('hb', 'b200', 4.0),
#  ('최재혁', 'b200', 5.0),
#  ('허남열', 'g1313', 5.0),
#  ('서연', 'f42', 5.0),
#  ('태', 'f42', 1.0),
#  ('박우진', 'b26', 5.0),
#  ('망구루', 'b26', 5.0),
#  ('정은정', 'b26', 2.0),
#  ('flower', 'b26', 3.0),
#  ('H', 'b26', 5.0),
#  ('달님', 'b26', 5.0),
#  ('fff', 'b26', 5.0),
#  ('Utd_Batistuta', 'b26', 5.0),
#  ('김진우', 'b26', 5.0),
#  ('^^', 'f264', 1.0),
#  ('김초설', 'g184', 5.0),
#  ('빵가루', 'f1511', 5.0),
#  ('쎄쎄주인', 'f1511', 5.0),
#  ('영히', 'f1511', 5.0),
#  ('보리차', 'f1511', 5.0),
#  ('0', 'g514', 1.0),
#  ('괭이', 'g514', 1.0),
#  ('빈', 'g514', 2.0),
#  ('전미선', 'g514', 4.0),
#  ('박철홍 🗣곰돌이 👥', 'b19', 5.0),
#  ('M', 'b19', 1.0),
#  ('상엽', 'b19', 1.0),
#  ('😋', 'b19', 5.0),
#  ('Mr.Rhee', 'b19', 5.0),
#  ('강대형', 'b19', 3.0),
#  ('apple_00', 'b19', 4.0),
#  ('김레볼', 'b19', 5.0),
#  ('별맘', 'b19', 5.0),
#  ('정훈', 'b19', 5.0),
#  ('Anh Bình', 'b19', 5.0),
#  ('루루', 'b19', 5.0),
#  ('박봉옥(ㅇㅎㄹㄷㅇ~)', 'b19', 5.0),
#  ('Benjamin', 'b19', 5.0),
#  ('Mori-AN', 'f89', 5.0),
#  ('s링', 'f89', 5.0),
#  ('슛돌이', 'f89', 5.0),
#  ('리커버리', 'b253', 5.0),
#  ('맛집탐험가', 'g513', 4.0),
#  ('HEYBUE', 'g513', 5.0),
#  ('가양', 'e412', 5.0),
#  ('꾸', 'e412', 1.0),
#  ('달', 'e412', 1.0),
#  ('강지수', 'e412', 1.0),
#  ('호잇', 'e412', 5.0),
#  ('(...)', 'b21', 5.0),
#  ('시욱♡시헌 맘', 'b21', 5.0),
#  ('kh. k.s.', 'b21', 4.0),
#  ('정남선생', 'b21', 4.0),
#  ('키이라', 'b21', 5.0),
#  ('설문규', 'b21', 5.0),
#  ('국민짱지', 'b21', 1.0),
#  ('엉터리타자', 'c711', 5.0),
#  ('ansunjung', 'c711', 5.0),
#  ('므ㅏ', 'f263', 4.0),
#  ('렬이', 'f263', 4.0),
#  ('민이', 'f45', 5.0),
#  ('불만많은꿀꿀이', 'c147', 5.0),
#  ('s', 'c147', 5.0),
#  ('빼앰', 'g1314', 3.0),
#  ('보름달', 'a610', 4.0),
#  ('Woods', 'a610', 2.0),
#  ('우유', 'a610', 3.0),
#  ('뿌따따', 'a610', 1.0),
#  ('ㄱ. jeong', 'a610', 2.0),
#  ('PhLOx', 'c178', 4.0),
#  ('이정아', 'c178', 5.0),
#  ('강민구', 'c178', 5.0),
#  ('한동원', 'g141', 1.0),
#  ('김고은', 'f1712', 5.0),
#  ('맛집만 리뷰쓰는편', 'f1712', 5.0),
#  ('gogi', 'f1712', 4.0),
#  ('zzzini', 'f1712', 3.0),
#  ('밥맹이', 'f1712', 3.0),
#  ('.', 'f1712', 5.0),
#  ('문', 'f1712', 5.0),
#  ('Y', 'b291', 1.0),
#  ('Charming-Park', 'a414', 1.0),
#  ('~.~', 'f73', 2.0),
#  ('최윤영', 'f73', 5.0),
#  ('신유리', 'f73', 1.0),
#  ('배추김치', 'f73', 2.0),
#  ('열음', 'f255', 1.0),
#  ('💟', 'f255', 1.0),
#  ('alliwannado', 'f255', 1.0),
#  ('.', 'f255', 1.0),
#  ('고양이', 'f255', 5.0),
#  ('평점가', 'f255', 3.0),
#  ('용', 'b17', 5.0),
#  ('포티노', 'b17', 5.0),
#  ('윤혁', 'b17', 5.0),
#  ('밍터', 'b17', 2.0),
#  ('김찬호', 'b17', 5.0),
#  ('tkhsjr', 'b17', 4.0),
#  ('복슬복슬알파카', 'b17', 4.0),
#  ('nujay', 'b17', 3.0),
#  ('Lucida', 'b17', 4.0),
#  ('이승현_데이빗', 'b17', 5.0),
#  ('wow', 'b28', 5.0),
#  ('little prince', 'b28', 5.0),
#  ('언제나 맑음', 'b28', 5.0),
#  ('이하닮', 'b28', 5.0),
#  ('2020년 화이팅!', 'b28', 5.0),
#  ('방기영', 'b28', 4.0),
#  ("'핵, 토 파스칼 킥", 'b10', 5.0),
#  ('Chris', 'b10', 5.0),
#  ('ando.Kumiko(yossy)', 'b10', 4.0),
#  ('정남선생', 'b10', 4.0),
#  ('허승우', 'b10', 5.0),
#  ('준호☆James or Junho', 'b10', 5.0),
#  ('건우', 'b10', 5.0),
#  ('배슐랭', 'b10', 5.0),
#  ('웨인(kojjab)', 'b10', 3.0),
#  ('박도숙', 'b10', 5.0),
#  ('🙂', 'b10', 4.0),
#  ('주재용', 'b10', 5.0),
#  ('밍터', 'b10', 3.0),
#  ('이정준', 'b10', 4.0),
#  ('₌₃۶⁼³ 👉호😎이👈 ۶⁼³₌₃', 'b10', 5.0),
#  ('YUJIN', 'b10', 5.0),
#  ('효현동', 'b10', 4.0),
#  ('肇遠', 'b10', 4.0),
#  ('금경령', 'b10', 5.0),
#  ('2020년 화이팅!', 'b10', 5.0),
#  ('키이라', 'b10', 4.0),
#  ('黃芝麻 황참깨', 'b10', 4.0),
#  ('H', 'b10', 5.0),
#  ('김유훈', 'b10', 5.0),
#  ('김재경', 'b10', 5.0),
#  ('복슬복슬알파카', 'b10', 4.0),
#  ('Benjamin', 'b10', 4.0),
#  ('MJay Ko 고 민정', 'b10', 4.0),
#  ('박서완', 'c512', 1.0),
#  ('카르르르', 'c512', 1.0),
#  ('백주', 'c512', 5.0),
#  ('🕵🏻\u200d♀️', 'c512', 5.0),
#  ('김태운', 'c512', 5.0),
#  ('고도리', 'c176', 1.0),
#  ('아리', 'c176', 3.0),
#  ('zzalex', 'c182', 1.0),
#  ('해정', 'c182', 1.0),
#  ('heybiblelee', 'c182', 1.0),
#  ('J.H', 'c182', 2.0),
#  ('MJay Ko 고 민정', 'c182', 3.0),
#  ('복슬복슬알파카', 'e611', 2.0),
#  ('강병권', 'g146', 3.0),
#  ('박지현', 'c149', 5.0),
#  ('matzipchaza', 'c149', 5.0),
#  ('구글맵', 'c149', 5.0),
#  ('나모', 'g317', 1.0),
#  ('.', 'f17', 5.0),
#  ('#', 'f17', 5.0),
#  ('도꼬', 'f231', 1.0),
#  ('안수민', 'f231', 5.0),
#  ('rlflqh', 'f231', 5.0),
#  ('츠츠3', 'f231', 5.0),
#  ('아르카타', 'f231', 5.0),
#  ('.', 'g1510', 1.0),
#  ('달군', 'g1510', 1.0),
#  ('Aiden', 'a810', 1.0),
#  ('김예리', 'b74', 5.0),
#  ('박진우', 'f10', 3.0),
#  ('yuta', 'd22', 2.0),
#  ('jh', 'c112', 4.0),
#  ('이혜진', 'c112', 1.0),
#  ('소우주', 'c112', 5.0),
#  ('뿅뿅', 'c112', 1.0),
#  ('손', 'e211', 4.0),
#  ('도민', 'e211', 4.0),
#  ('만두', 'e211', 3.0),
#  ('ㄱㅇㅅ', 'e211', 1.0),
#  ('Benjamin', 'b80', 4.0),
#  ('시영', 'f19', 5.0),
#  ('도서관', 'f19', 5.0),
#  ('도리', 'f19', 4.0),
#  ('kR', 'f19', 1.0),
#  ('ㅇㅈ', 'f1912', 5.0),
#  ('Sad', 'f1912', 1.0),
#  ('..', 'f1912', 1.0),
#  ('.', 'f1912', 1.0),
#  ('지영지', 'f26', 4.0),
#  ('쑤', 'f26', 5.0),
#  ('최송현', 'f26', 5.0),
#  ('감동하면 리뷰씀', 'f26', 5.0),
#  ('이진국', 'f26', 5.0),
#  ('K.G', 'f26', 5.0),
#  ('jsking', 'f26', 5.0),
#  ('정하연', 'f26', 4.0),
#  ('유창현', 'f26', 1.0),
#  ('☆홍염☆', 'f26', 1.0),
#  ('김재명', 'f26', 5.0),
#  ('JiN', 'f26', 5.0),
#  ('정자영', 'f26', 5.0),
#  ('2020년 화이팅!', 'b42', 5.0),
#  ('건우', 'b42', 5.0),
#  ('장은영', 'f200', 5.0),
#  ('임다은', 'f200', 5.0),
#  ('강 예동', 'f200', 5.0),
#  ('.', 'f200', 1.0),
#  ('콩이', 'f200', 2.0),
#  ('롤', 'g114', 5.0),
#  ('저 푸른 초원펭귄', 'g910', 5.0),
#  ('이승재', 'e811', 5.0),
#  ('하영', 'f238', 5.0),
#  ('깨끗한 물티슈', 'f238', 5.0),
#  ('.', 'f238', 5.0),
#  ('sSsay', 'f238', 5.0),
#  ('박현수', 'f238', 5.0),
#  ('송혁범', 'f238', 5.0),
#  ('하늘정원', 'f238', 5.0),
#  ('연주니', 'f238', 5.0),
#  ('젤리젤로', 'f238', 5.0),
#  ('Jasmine', 'f238', 5.0),
#  ('김원영', 'f238', 5.0),
#  ('신정민 비오', 'g113', 5.0),
#  ('러시아숲', 'b45', 1.0),
#  ('강연부', 'f207', 1.0),
#  ('하연', 'f207', 1.0),
#  ('잉왜또화내요', 'f207', 1.0),
#  ('딸기크림라떼', 'f207', 1.0),
#  ('노량진', 'f207', 1.0),
#  ('돌발소년', 'f207', 1.0),
#  ('오성환', 'a210', 1.0),
#  ('꾸웩', 'a210', 1.0),
#  ('신혜철', 'a210', 1.0),
#  ('your love is good to', 'a210', 1.0),
#  ('JUPITER', 'a210', 5.0),
#  ('인간은무엇으로사는가', 'c123', 5.0),
#  ('햄', 'd13', 1.0),
#  ('조현성', 'd13', 5.0),
#  ('이희원', 'f21', 1.0),
#  ('N지도피난민', 'f21', 5.0),
#  ('정예빈', 'f21', 5.0),
#  ('리커버리', 'b263', 5.0),
#  ('동휘맘', 'f81', 5.0),
#  ('공주', 'c183', 5.0),
#  ('밍', 'c183', 5.0),
#  ('ㅇㅇ', 'e610', 5.0),
#  ('냠냠냠', 'e610', 5.0),
#  ('wo', 'e610', 5.0),
#  ('ㅇㄷㅊ', 'e610', 1.0),
#  ('빵이조앙', 'f1714', 5.0),
#  ('vous', 'f1714', 3.0),
#  ('01', 'f1714', 2.0),
#  ('^-^', 'f1714', 5.0),
#  ('용드래곤', 'f1714', 5.0),
#  ('테이', 'c513', 5.0),
#  ('와인', 'c513', 5.0),
#  ('김수민', 'f253', 1.0),
#  ('...', 'f253', 1.0),
#  ('탱탱', 'b11', 5.0),
#  ('태영', 'b11', 5.0),
#  ('웨인(kojjab)', 'b11', 5.0),
#  ('양지연', 'b11', 3.0),
#  ('이영묵', 'b11', 4.0),
#  ('백여 종군', 'b11', 3.0),
#  ('석탄이아빠', 'b11', 5.0),
#  ('에이프릴', 'b11', 4.0),
#  ('소심한 물고기들', 'b11', 5.0),
#  ('볼륨매직', 'b11', 5.0),
#  ('Charming-Park', 'a412', 1.0),
#  ('DALDREAM', 'f75', 4.0),
#  ('프로혼밥러', 'c170', 1.0),
#  ('영인이', 'c170', 5.0),
#  ('호모루덴스', 'c170', 3.0),
#  ('-', 'c170', 3.0),
#  ('gmlsql99', 'c170', 1.0),
#  ('한다영', 'c170', 5.0),
#  ('♧히데뉨。', 'c170', 1.0),
#  ('내일은좋은일이생길거야', 'g1111', 4.0),
#  ('현선', 'f254', 2.0),
#  ('맛맛맛', 'f254', 2.0),
#  ('SSun.', 'f254', 4.0),
#  ('KITT', 'b16', 3.0),
#  ('wo', 'b16', 5.0),
#  ('롬', 'b16', 4.0),
#  ('ㅌㅇ', 'b16', 5.0),
#  ('크로스~^^', 'b16', 5.0),
#  ('박진우', 'b16', 5.0),
#  ('빠우', 'b16', 5.0),
#  ('ㅎㅅㅇ', 'b16', 4.0),
#  ('찌릿', 'b16', 1.0),
#  ('👀', 'b16', 4.0),
#  ('고독한 탐식가', 'b16', 3.0),
#  ('석우', 'b16', 5.0),
#  ('미락여행', 'b16', 5.0),
#  ('MJay Ko 고 민정', 'b16', 3.0),
#  ('김인규', 'b16', 3.0),
#  ('Charlie Jin', 'b16', 5.0),
#  ('규규', 'c514', 5.0),
#  ('Rsoe', 'c514', 1.0),
#  ('재이', 'f1713', 4.0),
#  ('존맛탱구리', 'f1713', 4.0),
#  ('Ms. Ssong', 'f1713', 3.0),
#  ('추운 베니', 'f1713', 3.0),
#  ('SSun.', 'f1713', 4.0),
#  ('Patrick', 'g140', 1.0),
#  ('신논현 네일한 나', 'c184', 5.0),
#  ('JL', 'c184', 1.0),
#  ('박광해', 'b2010', 5.0),
#  ('Trusta', 'b29', 3.0),
#  ('-----', 'b29', 5.0),
#  ('규빈', 'b29', 1.0),
#  ('marumongi', 'b29', 4.0),
#  ('ㅎ', 'b29', 1.0),
#  ('리커버리', 'b29', 5.0),
#  ('정기오', 'b29', 3.0),
#  ('최예나', 'b29', 5.0),
#  ('김석영', 'b29', 5.0),
#  ('김상동', 'b29', 3.0),
#  ('복슬복슬알파카', 'b29', 4.0),
#  ('MANGo', 'b29', 5.0),
#  ('혜진', 'g1912', 1.0),
#  ('쥴리', 'b20', 3.0),
#  ('유연우', 'b20', 5.0),
#  ('최규원', 'b20', 5.0),
#  ('jiaobaba', 'b20', 3.0),
#  ('오전필', 'b20', 5.0),
#  ('서슐랭', 'b20', 5.0),
#  ('개진철', 'b20', 5.0),
#  ('하성희', 'b20', 5.0),
#  ('김정심', 'b20', 4.0),
#  ('김재기(석수)', 'b20', 5.0),
#  ('조남범(효천)', 'b20', 5.0),
#  ('du_ub11', 'b20', 5.0),
#  ('윤정', 'b20', 5.0),
#  ('Kai', 'b20', 5.0),
#  ('ㅎㅅㅇ', 'b20', 2.0),
#  ('종워니(JW)', 'b20', 5.0),
#  ('장경순', 'b20', 5.0),
#  ('또또맘', 'b20', 4.0),
#  ('김정민', 'b20', 5.0),
#  ('🙂', 'b20', 5.0),
#  ('진실된 암행어사', 'b20', 5.0),
#  ('이창희', 'b20', 5.0),
#  ('윤선화', 'b20', 4.0),
#  ('미락여행', 'b20', 4.0),
#  ('웨인(kojjab)', 'b20', 5.0),
#  ('sbchoi', 'b20', 5.0),
#  ('밍터', 'b20', 4.0),
#  ('Sangmo', 'b20', 3.0),
#  ('KB이근미', 'b20', 4.0),
#  ('최홍기', 'b20', 4.0),
#  ('Choi Dong Sik', 'b20', 4.0),
#  ('pH', 'b20', 4.0),
#  ('黃芝麻 황참깨', 'b20', 4.0),
#  ('오대석', 'b20', 5.0),
#  ('이근만', 'b20', 4.0),
#  ('박민지', 'b20', 3.0),
#  ('설문규', 'b20', 5.0),
#  ('김귀성', 'b20', 4.0),
#  ('전주희', 'b20', 3.0),
#  ('건담이말을건담', 'f262', 5.0),
#  ('신이나', 'f262', 4.0),
#  ('강승은', 'f262', 4.0),
#  ('구름', 'f262', 4.0),
#  ('손오공', 'f262', 3.0),
#  ('멋진Joe', 'c710', 5.0),
#  ('멋진Joe', 'c710', 5.0),
#  ('재맹', 'g182', 1.0),
#  ('제야', 'a611', 1.0),
#  ('원 호', 'a611', 4.0),
#  ('레오폴드', 'a611', 1.0),
#  ('김형규', 'a611', 1.0),
#  ('용가리', 'a611', 1.0),
#  ('윤찬우', 'a611', 1.0),
#  ('여기별로', 'a611', 1.0),
#  ('zzzz', 'a611', 5.0),
#  ('두바쿠', 'a611', 5.0),
#  ('☘', 'e413', 5.0),
#  ('송명엽', 'e413', 5.0),
#  ('김근수', 'e413', 1.0),
#  ('나', 'e413', 1.0),
#  ('정재원', 'e413', 1.0),
#  ('ㅇㅎ', 'c179', 3.0),
#  ('서동현', 'c179', 2.0),
#  ('LJ', 'c179', 5.0),
#  ('Begbie', 'c179', 1.0),
#  ('elly', 'c179', 2.0),
#  ('영효닝~♥', 'f1510', 5.0),
#  ('VEnomonEY', 'f1510', 2.0),
#  ('또롱또로롱', 'e414', 5.0),
#  ('차의현', 'f43', 5.0),
#  ('출발', 'f43', 5.0),
#  ('수민', 'f43', 5.0),
#  ('별밤', 'f43', 5.0),
#  ('송영철', 'g185', 5.0),
#  ('돌아다님', 'g185', 4.0),
#  ('농노3', 'b27', 5.0),
#  ('박인우', 'b27', 1.0),
#  ('wow', 'b27', 5.0),
#  ('건우', 'b27', 3.0),
#  ('ksh', 'b27', 5.0),
#  ('Hyun', 'f265', 1.0),
#  ('이찬', 'g3213', 1.0),
#  ('츄', 'b18', 5.0),
#  ('wow', 'b18', 5.0),
#  ('tjqlfkqslwk', 'b18', 2.0),
#  ('김준성', 'b18', 5.0),
#  ('댕댕진', 'b18', 5.0),
#  ('랜턴', 'b18', 4.0),
#  ('ㅎㅅㅇ', 'b18', 4.0),
#  ('준호☆James or Junho', 'b18', 5.0),
#  ('유한영 예은수민맘', 'b18', 5.0),
#  ('정하연', 'b18', 5.0),
#  ('재명', 'b18', 5.0),
#  ('JB', 'b18', 5.0),
#  ('김재경', 'b18', 3.0),
#  ('박민지', 'b18', 3.0),
#  ('석우', 'b18', 5.0),
#  ('김관중(KwanJoong Kim)', 'b18', 2.0),
#  ('💋승권sk짱💋', 'b18', 5.0),
#  ('MJay Ko 고 민정', 'b18', 3.0),
#  ('공주', 'f2213', 5.0),
#  ('밍', 'f2213', 5.0),
#  ('원 호', 'a67', 4.0),
#  ('레오폴드', 'a67', 1.0),
#  ('김형규', 'a67', 1.0),
#  ('용가리', 'a67', 1.0),
#  ('정성영 Paul', 'a67', 3.0),
#  ('여기별로', 'a67', 1.0),
#  ('zzzz', 'a67', 5.0),
#  ('두바쿠', 'a67', 5.0),
#  ('Ss', 'c55', 1.0),
#  ('정원석', 'c55', 1.0),
#  ('윤지상', 'c55', 5.0),
#  ('최승희', 'g31', 4.0),
#  ('강희진', 'b1510', 5.0),
#  ('이채영', 'a93', 1.0),
#  ('이창렬', 'a93', 1.0),
#  ('.', 'a93', 1.0),
#  ('sUNg jONg gEUn', 'b911', 5.0),
#  ('박정재', 'b911', 5.0),
#  ('임종민', 'b911', 5.0),
#  ('김치볶음밥', 'c99', 5.0),
#  ('박진영', 'c99', 5.0),
#  ('Su', 'c99', 5.0),
#  ('해나', 'c99', 5.0),
#  ('민영', 'c99', 5.0),
#  ('냐냐', 'b112', 5.0),
#  ('누리는💓', 'b112', 5.0),
#  ('북북이', 'b112', 5.0),
#  ('이지혜', 'b112', 5.0),
#  ('정남선생', 'b112', 4.0),
#  ('유령작가', 'e105', 5.0),
#  ('hs🌴', 'b320', 5.0),
#  ('Lo샷ve', 'd211', 5.0),
#  ('김강봉', 'c52', 5.0),
#  ('‼️', 'c52', 5.0),
#  ('Kong', 'c52', 5.0),
#  ('데이지', 'c52', 3.0),
#  ('빼앰', 'f310', 5.0),
#  ('MAY', 'f310', 5.0),
#  ('크크크', 'f310', 5.0),
#  ('다다다', 'f2214', 2.0),
#  ('자양주민', 'f2214', 1.0),
#  ('믱', 'f2214', 1.0),
#  ('안경국', 'f2214', 5.0),
#  ('하람이', 'a60', 5.0),
#  ('신영종', 'a60', 3.0),
#  ('초밥좋아요', 'a60', 1.0),
#  ('ssoo', 'a60', 1.0),
#  ('솔아솔아', 'a60', 4.0),
#  ('김장환', 'b329', 5.0),
#  ('박영선', 'a69', 5.0),
#  ('전설', 'a69', 4.0),
#  ('ludo', 'a69', 1.0),
#  ('에이맨', 'a69', 1.0),
#  ('김건우', 'a69', 1.0),
#  ('ssuu', 'a69', 1.0),
#  ('seri414', 'a69', 1.0),
#  ('Lindsay.Lim.Michaela', 'g200', 5.0),
#  ('B', 'f2010', 1.0),
#  ('도영상', 'c64', 5.0),
#  ('정영옥', 'c64', 5.0),
#  ('아하', 'a56', 5.0),
#  ('빅토리아', 'a56', 5.0),
#  ('괭이', 'f114', 2.0),
#  ('희정', 'f114', 1.0),
#  ('이원석', 'f114', 1.0),
#  ('나며누기', 'e32', 1.0),
#  ('ㅋㅋㅋㅋ', 'e32', 1.0),
#  ('토리', 'e32', 2.0),
#  ('누렁', 'e32', 2.0),
#  ('제점수는요', 'g38', 5.0),
#  ('현민', 'g38', 3.0),
#  ('이오', 'g238', 1.0),
#  ('루루', 'g238', 1.0),
#  ('소풍', 'g238', 1.0),
#  ('MJay Ko 고 민정', 'b1714', 4.0),
#  ('상우', 'e35', 1.0),
#  ('혁신을 통한 지속성장!!!', 'e35', 5.0),
#  ('건담이말을건담', 'e35', 4.0),
#  ('always', 'e35', 1.0),
#  ('lotkyu', 'e35', 4.0),
#  ('Stanislav', 'a51', 5.0),
#  ('드미트리', 'a51', 5.0),
#  ('양형열', 'a51', 5.0),
#  ('여조로', 'f113', 5.0),
#  ('얏호', 'c63', 5.0),
#  ('민수', 'c63', 5.0),
#  ('오성환', 'a104', 1.0),
#  ('비얌', 'c97', 5.0),
#  ('카페메니아', 'c97', 2.0),
#  ('스카이라피스', 'c97', 5.0),
#  ('이상목', 'b311', 3.0),
#  ('바람과 나', 'b183', 5.0),
#  ('나', 'b183', 5.0),
#  ('lune', 'g53', 1.0),
#  ('Andy', 'f711', 3.0),
#  ('엽떡은 신당점', 'f711', 5.0),
#  ('이유리', 'c37', 5.0),
#  ('nuny', 'f147', 1.0),
#  ('이지', 'f147', 4.0),
#  ('愼其獨 로봇군단진재민ZINJAEMIN', 'f147', 5.0),
#  ('노랑', 'f147', 5.0),
#  ('복슬복슬알파카', 'f147', 3.0),
#  ('익명의 사람', 'g253', 2.0),
#  ('원국', 'g253', 3.0),
#  ('유혜빈', 'b513', 5.0),
#  ('hj', 'c1714', 3.0),
#  ('옴뇸뇸 :)', 'c1714', 5.0),
#  ('쥬잉', 'c1714', 5.0),
#  ('유령작가', 'e95', 5.0),
#  ('박시현', 'f178', 5.0),
#  ('귤', 'f178', 1.0),
#  ('젼', 'f178', 5.0),
#  ('김남호', 'g98', 5.0),
#  ('ㄹㅇ솔직평가', 'g98', 1.0),
#  ('정윤지', 'c1713', 5.0),
#  ('열애사진', 'b514', 5.0),
#  ('나은', 'e66', 5.0),
#  ('박수민', 'f2612', 5.0),
#  ('이해준', 'f2612', 5.0),
#  ('김태훈', 'f2612', 5.0),
#  ('jk Han', 'f2612', 5.0),
#  ('익명', 'e59', 1.0),
#  ('익명', 'e59', 5.0),
#  ('장꼭또', 'e59', 5.0),
#  ('박재만', 'e59', 5.0),
#  ('Minhyung', 'b1912', 5.0),
#  ('A', 'f182', 5.0),
#  ('박병연', 'f182', 1.0),
#  ('논리와팩트', 'f182', 1.0),
#  ('핑슐랭가이드', 'f182', 3.0),
#  ('kfc매니아', 'f182', 2.0),
#  ('ㄷㄹ', 'g96', 5.0),
#  ('솔', 'a1110', 1.0),
#  ('t', 'b146', 5.0),
#  ('JYK용선생', 'b146', 5.0),
#  ('마곡사랑08', 'b146', 5.0),
#  ('(율준♡)', 'g62', 1.0),
#  ('J', 'f512', 4.0),
#  ('장현', 'f512', 5.0),
#  ('박찬빈', 'f512', 1.0),
#  ('막가롱', 'f512', 2.0),
#  ('손혜린', 'f512', 5.0),
#  ('깅가라미', 'a34', 1.0),
#  ('deuxistt!!', 'a34', 2.0),
#  ('균면성실', 'a34', 1.0),
#  ('김남천', 'a34', 1.0),
#  ('제훈', 'a34', 1.0),
#  ('냠냠이', 'f176', 3.0),
#  ('eww', 'f176', 2.0),
#  ('j', 'f176', 2.0),
#  ('p', 'f176', 3.0),
#  ('냉철하게판단', 'f176', 4.0),
#  ('ㅋㅋㅋㅋ', 'g296', 5.0),
#  ('지원', 'b179', 5.0),
#  ('박병영', 'b179', 5.0),
#  ('소영', 'f149', 1.0),
#  ('냠냠이', 'f149', 4.0),
#  ('민정', 'f149', 5.0),
#  ('정인선', 'f149', 1.0),
#  ('내삶의술', 'f149', 5.0),
#  ('암바사', 'f149', 5.0),
#  ('꿀돌순이', 'f149', 5.0),
#  ('이경윤', 'f149', 5.0),
#  ('정유철', 'f149', 5.0),
#  ('미쉘', 'f149', 5.0),
#  ('불량주부', 'f149', 5.0),
#  ('김주영', 'b1312', 5.0),
#  ('아무개', 'a33', 2.0),
#  ('ㅇㅇ', 'f171', 5.0),
#  ('냉평', 'f171', 3.0),
#  ('FRW', 'f171', 2.0),
#  ('맛박사', 'f171', 5.0),
#  ('옴뇸뇸', 'f171', 5.0),
#  ('Jina', 'e57', 1.0),
#  ('숮2🍑', 'e57', 4.0),
#  ('흥칫', 'e57', 1.0),
#  ('임보람', 'e57', 5.0),
#  ('ㅇㅅㅇ', 'e57', 1.0),
#  ('라미', 'c1510', 5.0),
#  ('손', 'f185', 4.0),
#  ('도민', 'f185', 4.0),
#  ('만두', 'f185', 3.0),
#  ('ㄱㅇㅅ', 'f185', 1.0),
#  ('.', 'e68', 5.0),
#  ('태', 'e68', 1.0),
#  ('JkeM', 'e68', 5.0),
#  ('와사비까까', 'e68', 5.0),
#  ('랍스얍스', 'e68', 5.0),
#  ('허스키', 'g239', 1.0),
#  ('.', 'g39', 1.0),
#  ('아스라', 'g39', 5.0),
#  ('맛도사', 'g39', 1.0),
#  ('이름입력', 'g206', 4.0),
#  ('Marcellina', 'b122', 5.0),
#  ('현지훈', 'b310', 4.0),
#  ('ssong', 'b310', 5.0),
#  ('하루글라라', 'b310', 5.0),
#  ('인서아빠', 'b310', 5.0),
#  ('ㆍ', 'b310', 4.0),
#  ('폴인럽', 'e34', 5.0),
#  ('완사', 'e34', 5.0),
#  ('김동현', 'e34', 5.0),
#  ('방랑식객', 'e34', 5.0),
#  ('크림픽시', 'e34', 5.0),
#  ('장현', 'e34', 4.0),
#  ('.', 'e34', 2.0),
#  ('J', 'e34', 2.0),
#  ('드라프', 'e34', 5.0),
#  ('드라프', 'e34', 5.0),
#  ('kk345', 'e34', 5.0),
#  ('정무진', 'c62', 1.0),
#  ('봉쥬르', 'c62', 4.0),
#  ('Jason (양재훈)', 'c62', 5.0),
#  ('이반', 'c62', 1.0),
#  ('전정우', 'c62', 1.0),
#  ('이상훈', 'a105', 1.0),
#  ('하람이', 'a50', 5.0),
#  ('신영종', 'a50', 3.0),
#  ('초밥좋아요', 'a50', 1.0),
#  ('ssoo', 'a50', 1.0),
#  ('솔아솔아', 'a50', 4.0),
#  ('🙂', 'f112', 5.0),
#  ('원 호', 'a57', 4.0),
#  ('레오폴드', 'a57', 1.0),
#  ('김형규', 'a57', 1.0),
#  ('용가리', 'a57', 1.0),
#  ('정성영 Paul', 'a57', 3.0),
#  ('여기별로', 'a57', 1.0),
#  ('zzzz', 'a57', 5.0),
#  ('두바쿠', 'a57', 5.0),
#  ('이상훈', 'a102', 1.0),
#  ('김예림', 'f2011', 3.0),
#  ('희', 'f2011', 5.0),
#  ('이딴곳때문에로그인함', 'e33', 1.0),
#  ('정성수', 'g201', 5.0),
#  ('해진', 'c1110', 5.0),
#  ('호로록', 'c1110', 5.0),
#  ('ㅇㅅㅇ', 'c1110', 5.0),
#  ('.', 'c1110', 5.0),
#  ('시나비바', 'c1110', 1.0),
#  ('미니', 'c91', 5.0),
#  ('왕谕远', 'b910', 5.0),
#  ('기무지노상', 'g37', 2.0),
#  ('김태수', 'g37', 5.0),
#  ('박진우', 'd210', 4.0),
#  ('09_행정_승현', 'd210', 1.0),
#  ('Stanislav', 'a61', 5.0),
#  ('드미트리', 'a61', 5.0),
#  ('양형열', 'a61', 5.0),
#  ('황정태', 'c53', 5.0),
#  ('별', 'f311', 5.0),
#  ('ㅇ', 'f311', 5.0),
#  ('밍', 'a95', 5.0),
#  ('아이스크림', 'a95', 5.0),
#  ('먹방여행*^^*~~', 'a95', 5.0),
#  ('김건우', 'e104', 1.0),
#  ('Harin Harry Lee', 'e104', 2.0),
#  ('김대현', 'e104', 2.0),
#  ('자전거탄풍경', 'e104', 5.0),
#  ('영남', 'b321', 5.0),
#  ('유홍재', 'b113', 4.0),
#  ('뽄나', 'b113', 5.0),
#  ('MJay Ko 고 민정', 'b113', 3.0),
#  ('카카오러', 'b113', 2.0),
#  ('고카소', 'b113', 3.0),
#  ('박영선', 'a59', 5.0),
#  ('전설', 'a59', 4.0),
#  ('ludo', 'a59', 1.0),
#  ('에이맨', 'a59', 1.0),
#  ('김건우', 'a59', 1.0),
#  ('ssuu', 'a59', 1.0),
#  ('seri414', 'a59', 1.0),
#  ('이경준 Black', 'b114', 5.0),
#  ('다섯', 'e103', 3.0),
#  ('임관혁', 'e103', 5.0),
#  ('주연', 'e103', 5.0),
#  ('제롱', 'a92', 1.0),
#  ('하루', 'a92', 5.0),
#  ('lolyiu', 'a92', 1.0),
#  ('Jjojo', 'c54', 4.0),
#  ('.', 'c54', 1.0),
#  ('쥬잉', 'c54', 1.0),
#  ('Rom', 'c54', 1.0),
#  ('jj', 'c54', 5.0),
#  ('아하', 'a66', 5.0),
#  ('빅토리아', 'a66', 5.0),
#  ('김복순', 'f2212', 1.0),
#  ('양나영', 'f2212', 1.0),
#  ('박준렬', 'f2212', 1.0),
#  ('웹토리', 'b1511', 4.0),
#  ('펭수러버', 'g30', 1.0),
#  ('🙈', 'g30', 2.0),
#  ('김상영', 'c1511', 5.0),
#  ('duri', 'c1511', 5.0),
#  ('nanana', 'c1511', 5.0),
#  ('장승우', 'g90', 1.0),
#  ('김지원', 'g90', 5.0),
#  ('조성빈', 'g90', 5.0),
#  ('쏘다', 'f184', 5.0),
#  ('황인용', 'f184', 1.0),
#  ('단속반', 'f184', 1.0),
#  ('yeah', 'f184', 1.0),
#  ('박재용', 'f184', 3.0),
#  ('illusion', 'f184', 1.0),
#  ('성재', 'f184', 1.0),
#  ('복슬복슬알파카', 'f184', 5.0),
#  ('뭔들', 'f184', 2.0),
#  ('shine', 'a32', 1.0),
#  ('bcjhd', 'a32', 5.0),
#  ('정옥균', 'a32', 5.0),
#  ('cmtk', 'a32', 5.0),
#  ('뀰', 'f170', 1.0),
#  ('네오', 'f170', 1.0),
#  ('rot', 'f170', 1.0),
#  ('효기', 'f170', 4.0),
#  ('이유진', 'f170', 2.0),
#  ('Jun', 'f170', 3.0),
#  ('ㅇㅍㄱ', 'f170', 1.0),
#  ('JH', 'f170', 3.0),
#  ('최정규(Jaykay)', 'f170', 4.0),
#  ('정남선생', 'f170', 3.0),
#  ('SJWi', 'f170', 4.0),
#  ('유준명', 'f170', 4.0),
#  ('원미', 'f170', 4.0),
#  ('MoMo', 'f2410', 5.0),
#  ('박호용', 'g64', 5.0),
#  ('작지', 'e56', 5.0),
#  ('아이유', 'e56', 5.0),
#  ('somsa', 'e56', 5.0),
#  ('Google', 'e56', 5.0),
#  ('에스프레소&크림', 'e56', 5.0),
#  ('Ги Хён чхье', 'f514', 1.0),
#  ('Th', 'f514', 1.0),
#  ('김계승', 'f514', 1.0),
#  ('최정삼 designw', 'f514', 5.0),
#  ('최귀남', 'f514', 5.0),
#  ('세느', 'e69', 5.0),
#  ('익명', 'e69', 5.0),
#  ('쥐', 'e69', 5.0),
#  ('은빛여우', 'e69', 5.0),
#  ('오병진', 'e69', 5.0),
#  ('S', 'f513', 5.0),
#  ('댕댕이', 'f513', 5.0),
#  ('hs', 'f513', 5.0),
#  ('황다원', 'f513', 5.0),
#  ('폭시폭시베이베', 'f513', 1.0),
#  ('Circleframe', 'g63', 3.0),
#  ('이승형', 'g63', 5.0),
#  ('임검제', 'g63', 1.0),
#  ('끼끗', 'a35', 1.0),
#  ('준수', 'a35', 1.0),
#  ('임승균', 'a35', 1.0),
#  ('양ㄹㄹ', 'a35', 1.0),
#  ('지예서', 'a35', 1.0),
#  ('🍰', 'f177', 1.0),
#  ('MJay Ko 고 민정', 'f177', 3.0),
#  ('찬', 'f177', 5.0),
#  ('JA', 'f177', 5.0),
#  ('동동', 'f177', 1.0),
#  ('김현석', 'f183', 5.0),
#  ('.', 'f183', 4.0),
#  ('박세정베로니카', 'f183', 5.0),
#  ('김종건', 'f183', 5.0),
#  ('mh', 'f183', 5.0),
#  ('양혜원', 'f183', 5.0),
#  ('해당화', 'b147', 5.0),
#  ('AH', 'f148', 1.0),
#  ('감사', 'f148', 5.0),
#  ('손혜린', 'f148', 4.0),
#  ('지은', 'f148', 1.0),
#  ('1', 'f148', 1.0),
#  ('ㅂㄷㅁ', 'c38', 5.0),
#  ('hans', 'c38', 5.0),
#  ('전희영', 'c38', 5.0),
#  ('시저', 'c38', 5.0),
#  ('t', 'b1110', 5.0),
#  ('서재현', 'f2613', 5.0),
#  ('보라', 'f2613', 5.0),
#  ('엘리', 'f2613', 5.0),
#  ('안용준', 'f2613', 5.0),
#  ('범국', 'f2613', 5.0),
#  ('양혜진', 'e67', 5.0),
#  ('김명근 AnJo', 'g55', 3.0),
#  ('잠오는인생', 'c1712', 5.0),
#  ('아그마곰', 'c1712', 5.0),
#  ('마리사', 'c1712', 3.0),
#  ('명탐정', 'c1712', 1.0),
#  ('다섯', 'e93', 3.0),
#  ('임관혁', 'e93', 5.0),
#  ('주연', 'e93', 5.0),
#  ('쥑쥑', 'g2011', 1.0),
#  ('다영', 'e58', 5.0),
#  ('wow', 'b512', 5.0),
#  ('BOY', 'b512', 5.0),
#  ('천수', 'b512', 5.0),
#  ('김건우', 'e94', 1.0),
#  ('Harin Harry Lee', 'e94', 2.0),
#  ('김대현', 'e94', 2.0),
#  ('자전거탄풍경', 'e94', 5.0),
#  ('미식가', 'g52', 5.0),
#  ('max', 'g52', 1.0),
#  ('명세인', 'g52', 1.0),
#  ('hye', 'g52', 1.0),
#  ('여행', 'g52', 1.0),
#  ('지후니', 'f710', 5.0),
#  ('정유철', 'f2614', 5.0),
#  ('이하영', 'f2614', 2.0),
#  ('실버', 'e60', 5.0),
#  ('dkwiv', 'f146', 4.0),
#  ('조민영', 'f146', 4.0),
#  ('Yut222', 'f146', 4.0),
#  ('조북이', 'c36', 5.0),
#  ('김지해', 'g99', 1.0),
#  ('최영준', 'g99', 5.0),
#  ('허스키', 'g299', 1.0),
#  ('슈미', 'f179', 5.0),
#  ('예', 'f179', 5.0),
#  ('크어먼요', 'f179', 5.0),
#  ('dance', 'e89', 5.0),
#  ('keepgoing', 'e89', 5.0),
#  ('박희수', 'a19', 2.0),
#  ('유려', 'a19', 4.0),
#  ('simplysimon30', 'a19', 1.0),
#  ('🕵🏻\u200d♀️', 'a19', 4.0),
#  ('한님', 'g84', 5.0),
#  ('s', 'g84', 5.0),
#  ('도헌', 'f1611', 5.0),
#  ('HEEWON YU', 'f1611', 5.0),
#  ('율e', 'f1611', 5.0),
#  ('김영우', 'f1611', 5.0),
#  ('ssun', 'f1611', 5.0),
#  ('오현빈', 'f1611', 1.0),
#  ('신지섭', 'f1611', 1.0),
#  ('임정민', 'f1611', 5.0),
#  ('슬기', 'f1611', 5.0),
#  ('김기현', 'f1611', 5.0),
#  ('박정훈', 'f1611', 5.0),
#  ('떵손🙈', 'f1611', 5.0),
#  ('모아', 'f1611', 5.0),
#  ('disbw', 'f1611', 1.0),
#  ('@', 'f1611', 1.0),
#  ('SSun.', 'f1611', 4.0),
#  ('simplysimon30', 'f1611', 1.0),
#  ('dmdmdnd', 'f1611', 5.0),
#  ('김지현', 'f1611', 5.0),
#  ('장희정', 'f1611', 5.0),
#  ('심준우', 'f1611', 5.0),
#  ('이현주', 'f1611', 5.0),
#  ('김성은', 'f1611', 5.0),
#  ('서효원', 'f1611', 5.0),
#  ('강현지', 'f1611', 5.0),
#  ('임민선', 'f1611', 5.0),
#  ('김세희', 'f1611', 5.0),
#  ('최은별', 'f1611', 5.0),
#  ('이윤미', 'f1611', 5.0),
#  ('문은애', 'f1611', 5.0),
#  ('김혜란', 'f1611', 5.0),
#  ('oOo', 'f1611', 1.0),
#  ('오주현', 'f1611', 2.0),
#  ('Clare', 'f1611', 4.0),
#  ('roi', 'f1611', 5.0),
#  ('핑슐랭가이드', 'f1611', 5.0),
#  ('장은영', 'f190', 5.0),
#  ('임다은', 'f190', 5.0),
#  ('강 예동', 'f190', 5.0),
#  ('.', 'f190', 1.0),
#  ('콩이', 'f190', 2.0),
#  ('xxxx', 'c14', 4.0),
#  ('김다영', 'c14', 5.0),
#  ('가나다라마바사', 'c14', 5.0),
#  ('즐거운~~~', 'g284', 5.0),
#  ('덤벨', 'f164', 1.0),
#  ('찬', 'f164', 5.0),
#  ('쀼', 'f164', 1.0),
#  ('김재명', 'f164', 1.0),
#  ('애터미No.1', 'a26', 1.0),
#  ...]

# %%
ncf = cornac.models.recommender.Recommender('NeuMF')
ncf.early_stop
# Out:
# <bound method Recommender.early_stop of <cornac.models.recommender.Recommender object at 0x11cac1c50>>

# %%
import cornac
from cornac.eval_methods import RatioSplit

TOP_K = 30

# Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=ls,
    test_size=0.20,
    rating_threshold=1.0,
    seed=123,
    exclude_unknowns=True,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors=8,
    layers=[16, 8, 4],
    act_fn="tanh",
    learner="adam",
    num_epochs=200,
    batch_size=256,
    lr=0.001,
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0, 'patience':3}
)


# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 18025
# Number of items = 1388
# Number of ratings = 39360
# Max rating = nan
# Min rating = nan
# Global mean = nan
# ---
# Test data:
# Number of users = 4359
# Number of items = 524
# Number of ratings = 7127
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 18025
# Total items = 1388
#
# [NeuMF] Training started!
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 1348 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 241 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))

# %%
a = pd.DataFrame(neumf1.rank(1)).T

# %%
a.to_csv('../data/exxxx')

# %%
from keras.models import load_model

neumf1.save('neumf1.h5')
# Out:
# NeuMF model is saved to neumf1.h5/NeuMF/2020-06-12_16-27-40-024934.pkl
# Using TensorFlow backend.
# 'neumf1.h5/NeuMF/2020-06-12_16-27-40-024934.pkl'
