# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Neural Collaborative Filtering on DAC dataset.
#
# Neural Collaborative Filtering (NCF) is a well known recommendation algorithm that generalizes the matrix factorization problem with multi-layer perceptron.
#
# This notebook provides an example of how to utilize and evaluate NCF implementation in the `reco_utils`. We use a smaller dataset in this example to run NCF efficiently with GPU acceleration on a [Data Science Virtual Machine](https://azure.microsoft.com/en-gb/services/virtual-machines/data-science-virtual-machines/).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../")
import time
import pandas as pd
import tensorflow as tf

from reco_utils.recommender.ncf.ncf_singlenode import NCF
from reco_utils.recommender.ncf.dataset import Dataset as NCFDataset
from reco_utils.dataset import movielens
from reco_utils.common.notebook_utils import is_jupyter
from reco_utils.dataset.python_splitters import python_stratified_split
from reco_utils.evaluation.python_evaluation import (rmse, mae, rsquared, exp_var, map_at_k, ndcg_at_k, precision_at_k, 
                                                     recall_at_k, get_top_k_items)

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.6.10 |Anaconda, Inc.| (default, May  7 2020, 23:06:31)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas version: 0.25.3
# Tensorflow version: 1.15.0

# %% [markdown]
# Set the default parameters.

# %%
# top k items to recommend
TOP_K = 10

# Select MovieLens data size: 100k, 1m, 10m, or 20m
MOVIELENS_DATA_SIZE = '100k'

# Model parameters
EPOCHS = 50
BATCH_SIZE = 256

SEED = 42

# %% [markdown]
# ### 1. Load prepared data

# %%
df = pd.read_csv('../ncf_data.csv')
df.rename(columns = {'p_id' : 'itemID', 'u_id' : 'userID', 'u_rate' : 'rating'}, inplace = True)

# %%
pd.set_option('display.max_rows', 10)
df.drop_duplicates(['itemID', 'userID'], keep='last', inplace=True)

# %%
df = df.groupby('userID').filter(lambda x : len(x)> 10).copy()

# %%
df
# Out:
#       itemID      userID  rating
# 57       f27       young       1
# 186    f1712           .       5
# 197     f255           .       1
# 216      b17     복슬복슬알파카       4
# 274      b10     복슬복슬알파카       4
# ...      ...         ...     ...
# 61802    206    CanisHan       4
# 61803    560  PINKSHOW01       5
# 61804    560    MAKCHA79       4
# 61805    560      올리브521       5
# 61806    560      406대현김       5
#
# [16611 rows x 3 columns]

# %% [markdown]
# ### 2. Split the data using the stratified splitter provided in utilities

# %%
train, test = python_stratified_split(df, 0.8)

# %% [markdown]
# Generate an NCF dataset object from the data subsets.

# %%
data = NCFDataset(train=train, test=test, seed=SEED)

# %% [markdown]
# ### 3. Train the NCF model on the training data, and get the top-k recommendations for our testing data
#
# NCF accepts implicit feedback and generates prospensity of items to be recommended to users in the scale of 0 to 1. A recommended item list can then be generated based on the scores. Note that this quickstart notebook is using a smaller number of epochs to reduce time for training. As a consequence, the model performance will be slighlty deteriorated.

# %%
#50
#256
#42

model = NCF (
    n_users=data.n_users, 
    n_items=data.n_items,
    model_type="NeuMF",
    n_factors=4,
    layer_sizes=[16,8,4],
    n_epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    learning_rate=1e-3,
    verbose=10,
    seed=SEED
)

# %%
start_time = time.time()

model.fit(data)

train_time = time.time() - start_time

print("Took {} seconds for training.".format(train_time))
# Out:
# Took 22.828919887542725 seconds for training.

# %%
start_time = time.time()

users, items, preds = [], [], []
item = list(train.itemID.unique())
for user in train.userID.unique():
    user = [user] * len(item) 
    users.extend(user)
    items.extend(item)
    preds.extend(list(model.predict(user, item, is_list=True)))

all_predictions = pd.DataFrame(data={"userID": users, "itemID":items, "prediction":preds})

merged = pd.merge(train, all_predictions, on=["userID", "itemID"], how="outer")
all_predictions = merged[merged.rating.isnull()].drop('rating', axis=1)

test_time = time.time() - start_time
print("Took {} seconds for prediction.".format(test_time))
# Out:
# Took 0.6900091171264648 seconds for prediction.

# %% [markdown]
# ### 4. Evaluate how well NCF performs

# %% [markdown]
# The ranking metrics are used for evaluation.

# %%
eval_map = map_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_precision = precision_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_recall = recall_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_f1 = 2*(eval_precision*eval_recall)/(eval_precision+eval_recall)

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall,
      "F1Score@K:\t%f" % eval_f1,
      sep='\n')
# Out:
# MAP:	0.247087
# NDCG:	0.390923
# Precision@K:	0.241537
# Recall@K:	0.438293
# F1Score@K:	0.311442

# %%
eval_f1 = 2*(eval_precision*eval_recall)/(eval_precision+eval_recall)
eval_f1
# Out:
# 0.3114422871173871

# %%
####1
####user_id > 10
#MAP:	0.247087
#NDCG:	0.390923
#Precision@K:	0.241537
#Recall@K:	0.438293

####2
####user_id > 0
#MAP:	0.381576
#NDCG:	0.445280
#Precision@K:	0.086908
#Recall@K:	0.582482

# %%
if is_jupyter():
    # Record results with papermill for tests
    import papermill as pm
    pm.record("map", eval_map)
    pm.record("ndcg", eval_ndcg)
    pm.record("precision", eval_precision)
    pm.record("recall", eval_recall)
    pm.record("train_time", train_time)
    pm.record("test_time", test_time)
# Out:
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   after removing the cwd from sys.path.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   """
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   import sys
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   if __name__ == '__main__':

# %% [markdown]
# # NCF Cornac

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ncf_data.csv')
df.rename(columns = {'p_id' : 'itemID', 'u_id' : 'userID', 'u_rate' : 'rating'}, inplace = True)

# %%
df = df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
df
# Out:
#       itemID      userID  rating
# 57       f27       young       1
# 58       b43         박민지       3
# 145      b19    Benjamin       5
# 162      b21         설문규       5
# 186    f1712           .       5
# ...      ...         ...     ...
# 61802    206    CanisHan       4
# 61803    560  PINKSHOW01       5
# 61804    560    MAKCHA79       4
# 61805    560      올리브521       5
# 61806    560      406대현김       5
#
# [19290 rows x 3 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#        index itemID      userID  rating
# 0         57    f27       young       1
# 1         58    b43         박민지       3
# 2        145    b19    Benjamin       5
# 3        162    b21         설문규       5
# 4        186  f1712           .       5
# ...      ...    ...         ...     ...
# 19285  61802    206    CanisHan       4
# 19286  61803    560  PINKSHOW01       5
# 19287  61804    560    MAKCHA79       4
# 19288  61805    560      올리브521       5
# 19289  61806    560      406대현김       5
#
# [19290 rows x 4 columns]

# %%
ls=[]
for i in range (0,len(df)):
    new_tuple = (df['userID'][i], df['itemID'][i], df['rating'][i])
    ls.append(new_tuple)

# %%
ls
# Out:
# [('young', 'f27', 1),
#  ('박민지', 'b43', 3),
#  ('Benjamin', 'b19', 5),
#  ('설문규', 'b21', 5),
#  ('.', 'f1712', 5),
#  ('.', 'f255', 1),
#  ('밍터', 'b17', 2),
#  ('복슬복슬알파카', 'b17', 4),
#  ('복슬복슬알파카', 'b17', 4),
#  ('복슬복슬알파카', 'b17', 4),
#  ('밍터', 'b10', 3),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('MJay Ko 고 민정', 'c182', 3),
#  ('복슬복슬알파카', 'e611', 2),
#  ('.', 'f17', 5),
#  ('.', 'g1510', 1),
#  ('Benjamin', 'b80', 4),
#  ('.', 'f1912', 1),
#  ('.', 'f200', 1),
#  ('.', 'f238', 5),
#  ('ㅇㅇ', 'e610', 5),
#  ('MJay Ko 고 민정', 'b16', 3),
#  ('복슬복슬알파카', 'b29', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('박민지', 'b18', 3),
#  ('MJay Ko 고 민정', 'b18', 3),
#  ('MJay Ko 고 민정', 'b18', 3),
#  ('.', 'a93', 1),
#  ('MJay Ko 고 민정', 'b1714', 4),
#  ('복슬복슬알파카', 'f147', 3),
#  ('J', 'f512', 4),
#  ('ㅇㅇ', 'f171', 5),
#  ('.', 'e68', 5),
#  ('.', 'g39', 1),
#  ('.', 'e34', 2),
#  ('J', 'e34', 2),
#  ('.', 'c1110', 5),
#  ('MJay Ko 고 민정', 'b113', 3),
#  ('.', 'c54', 1),
#  ('복슬복슬알파카', 'f184', 5),
#  ('MJay Ko 고 민정', 'f177', 3),
#  ('.', 'f183', 4),
#  ('.', 'f190', 1),
#  ('지니', 'b153', 4),
#  ('.', 'g41', 2),
#  ('.', 'e313', 1),
#  ('ㅇㅇ', 'e20', 5),
#  ('지니', 'a44', 3),
#  ('ㅇㅇ', 'e27', 1),
#  ('.', 'g224', 5),
#  ('.', 'g78', 1),
#  ('지니', 'b163', 4),
#  ('ㅇㅇ', 'f1413', 1),
#  ('ㅇㅇ', 'e44', 5),
#  ('J', 'e44', 1),
#  ('지니', 'b2910', 4),
#  ('.', 'a27', 1),
#  ('복슬복슬알파카', 'c41', 4),
#  ('지니', 'a314', 3),
#  ('Benjamin', 'a87', 3),
#  ('복슬복슬알파카', 'c46', 3),
#  ('J', 'e26', 5),
#  ('.', 'g213', 1),
#  ('.', 'f2512', 1),
#  ('J', 'f2114', 4),
#  ('.', 'f2114', 5),
#  ('.', 'f214', 4),
#  ('복슬복슬알파카', 'b51', 5),
#  ('J', 'c1611', 1),
#  ('.', 'f51', 1),
#  ('.', 'f51', 5),
#  ('박민지', 'f2513', 5),
#  ('.', 'f215', 5),
#  ('복슬복슬알파카', 'b61', 5),
#  ('.', 'g2710', 1),
#  ('.', 'f41', 1),
#  ('.', 'f41', 5),
#  ('.', 'b13', 5),
#  ('MJay Ko 고 민정', 'b13', 3),
#  ('MJay Ko 고 민정', 'b13', 3),
#  ('MJay Ko 고 민정', 'b13', 3),
#  ('MJay Ko 고 민정', 'e612', 3),
#  ('.', 'c172', 1),
#  ('.', 'b14', 4),
#  ('밍터', 'b14', 4),
#  ('Sangmo', 'b14', 4),
#  ('sbchoi', 'b14', 5),
#  ('박민지', 'b15', 3),
#  ('MJay Ko 고 민정', 'b15', 4),
#  ('Benjamin', 'b15', 4),
#  ('Benjamin', 'b15', 4),
#  ('지니', 'f1710', 5),
#  ('지니', 'f1710', 5),
#  ('설문규', 'b12', 5),
#  ('ㅇㅇ', 'f1513', 1),
#  ('설문규', 'b24', 5),
#  ('.', 'd21', 1),
#  ('복슬복슬알파카', 'd21', 2),
#  ('밍터', 'b70', 3),
#  ('지니', 'a213', 4),
#  ('.', 'f2412', 1),
#  ('ㅇㅇ', 'e54', 5),
#  ('J', 'e54', 1),
#  ('복슬복슬알파카', 'c51', 4),
#  ('복슬복슬알파카', 'c56', 3),
#  ('MJay Ko 고 민정', 'b312', 3),
#  ('박민지', 'f2413', 5),
#  ('.', 'g51', 2),
#  ('.', 'f2012', 1),
#  ('ㅇㅇ', 'e39', 5),
#  ('지니', 'e24', 5),
#  ('지니', 'e24', 5),
#  ('.', 'a78', 5),
#  ('.', 'c44', 1),
#  ('Benjamin', 'a82', 3),
#  ('.', 'e113', 5),
#  ('복슬복슬알파카', 'f1612', 4),
#  ('.', 'g287', 1),
#  ('설문규', 'b161', 5),
#  ('J', 'f1812', 1),
#  ('박민지', 'c74', 5),
#  ('.', 'e311', 1),
#  ('복슬복슬알파카', 'c73', 5),
#  ('.', 'g1410', 1),
#  ('.', 'a15', 5),
#  ('복슬복슬알파카', 'f157', 3),
#  ('ㅇㅇ', 'c29', 1),
#  ('설문규', 'b151', 5),
#  ('.', 'c167', 3),
#  ('J', 'f412', 4),
#  ('복슬복슬알파카', 'c160', 4),
#  ('.', 'c169', 2),
#  ('MJay Ko 고 민정', 'b414', 3),
#  ('MJay Ko 고 민정', 'c1614', 3),
#  ('J', 'f216', 1),
#  ('.', 'f220', 5),
#  ('박민지', 'b31', 3),
#  ('MJay Ko 고 민정', 'b1214', 3),
#  ('.', 'f245', 1),
#  ('.', 'c166', 4),
#  ('H L', '223', 4),
#  ('JJJY_Mom', '223', 5),
#  ('민석 권', '223', 4),
#  ('flyingdonutx100', '223', 5),
#  ('가드너송', '237', 5),
#  ('Alpertbyun', '237', 3),
#  ('Traveling Foodie', '237', 5),
#  ('gingertea', '237', 5),
#  ('형근 김', '237', 4),
#  ('pic_bd', '237', 4),
#  ('Joon K', '237', 5),
#  ('muzicrabeat', '237', 4),
#  ('JUSEONG Y', '237', 3),
#  ('용마사', '237', 4),
#  ('J J', '237', 4),
#  ('duck3222', '237', 3),
#  ('Urizia J', '237', 5),
#  ('올리브521', '237', 5),
#  ('으헤헤헤헹', '237', 5),
#  ('shinhee', '237', 5),
#  ('nayepp', '237', 4),
#  ('파도피아노', '237', 5),
#  ('bjh3676', '237', 3),
#  ('livia941', '237', 3),
#  ('PINKSHOW01', '237', 4),
#  ('진규 이', '237', 4),
#  ('Hyang00', '237', 4),
#  ('406대현김', '237', 5),
#  ('mkla1004', '237', 4),
#  ('reverb83', '237', 2),
#  ('집시747', '237', 4),
#  ('everlsk', '237', 4),
#  ('nekoyang h', '237', 5),
#  ('chunglang', '237', 4),
#  ('sodal00', '237', 4),
#  ('만옥이네', '237', 4),
#  ('2875rosa', '237', 4),
#  ('공부를하자', '237', 5),
#  ('nanal78878', '237', 3),
#  ('차씨', '237', 4),
#  ('이안팍', '237', 4),
#  ('eoto34', '237', 5),
#  ('ddneverland', '237', 3),
#  ('주니네', '237', 4),
#  ('togbuss', '237', 5),
#  ('sang cheol h', '237', 5),
#  ('goodtripgo', '237', 3),
#  ('christina7542', '237', 4),
#  ('Bintang27', '237', 4),
#  ('LG_Kay', '237', 4),
#  ('Sam', '237', 5),
#  ('Prinster A', '237', 4),
#  ('minimize940314', '237', 3),
#  ('Mike54BU', '237', 5),
#  ('Watu2014', '237', 5),
#  ('juou', '551', 3),
#  ('팜므파탈캣', '551', 1),
#  ('JUSEONG Y', '551', 3),
#  ('JAEMIN S', '551', 4),
#  ('nkpd00', '551', 4),
#  ('OISEAU_K', '551', 4),
#  ('Relax825963', '592', 4),
#  ('지연 최', '592', 5),
#  ('ahirity', '592', 4),
#  ('daheey2017', '592', 5),
#  ('종춘 이', '592', 4),
#  ('sanrio2018', '592', 5),
#  ('407yjj', '592', 5),
#  ('Kylie Park', '592', 4),
#  ('양명수', '592', 4),
#  ('gingertea', '592', 4),
#  ('경경 팍', '592', 5),
#  ('pic_bd', '592', 4),
#  ('Hyuck Joon Lee', '592', 4),
#  ('희영 장', '592', 5),
#  ('Joon K', '592', 5),
#  ('SangChul H', '592', 4),
#  ('Lucy L', '592', 4),
#  ('czdy', '592', 4),
#  ('juou', '592', 3),
#  ('섬아저씨', '592', 4),
#  ('muzicrabeat', '592', 3),
#  ('missgoooo', '592', 4),
#  ('hojung S', '592', 5),
#  ('Walkerxoxo', '592', 4),
#  ('jiyeonk158', '592', 5),
#  ('Donghye PARK', '592', 4),
#  ('JUSEONG Y', '592', 5),
#  ('Loem', '592', 4),
#  ('gunyoungy', '592', 5),
#  ('kyuseon', '592', 4),
#  ('nanal78878', '592', 4),
#  ('ayul1', '592', 5),
#  ('ᄌ ᄀ', '592', 4),
#  ('ruze0201', '592', 4),
#  ('용마사', '592', 4),
#  ('Bora Y', '592', 5),
#  ('Chocogodiva', '592', 5),
#  ('cece7474', '592', 3),
#  ('younggoung', '592', 5),
#  ('jisu kim', '592', 3),
#  ('Jelsomina', '592', 3),
#  ('Hyewon P', '592', 4),
#  ('KBR57', '592', 4),
#  ('Ju-yeon Y', '592', 4),
#  ('ambition93', '592', 4),
#  ('성희 소', '592', 5),
#  ('dkfma0657', '592', 5),
#  ('지은김2018', '592', 5),
#  ('유이717', '592', 5),
#  ('apple1368', '592', 3),
#  ('수진 이', '592', 3),
#  ('메가마일', '592', 4),
#  ('민영 송', '592', 4),
#  ('KYUNGHEE J', '592', 4),
#  ('마노', '592', 5),
#  ('yusoooooo', '592', 4),
#  ('Stereos', '592', 3),
#  ('은숙 박', '592', 5),
#  ('강한여자', '592', 4),
#  ('lao717', '592', 4),
#  ('은지 김', '592', 3),
#  ('Queen3839', '592', 4),
#  ('백호50', '592', 3),
#  ('decreekr', '592', 4),
#  ('신똘', '592', 2),
#  ('윤희 조', '592', 5),
#  ('modudada', '592', 3),
#  ('미영 김', '592', 5),
#  ('alaco3', '592', 5),
#  ('천막족', '592', 4),
#  ('Boa K', '592', 4),
#  ('a_ral_laa', '592', 5),
#  ('bonghwa', '592', 4),
#  ('kkh2254', '592', 4),
#  ('선화 김', '592', 3),
#  ('눈에서레이져빔', '592', 5),
#  ('수수 김', '592', 5),
#  ('MI SUK', '592', 4),
#  ('junheemin', '592', 4),
#  ('고등어2015', '592', 3),
#  ('하영 이', '592', 5),
#  ('Hot6', '592', 5),
#  ('qberwy', '592', 5),
#  ('Fontainebleaus', '592', 4),
#  ('코스트너', '592', 5),
#  ('Yuyumi85', '592', 4),
#  ('짱짱짱', '592', 4),
#  ('duck3222', '592', 5),
#  ('형근 김', '592', 4),
#  ('slow1717', '592', 4),
#  ('메이링', '592', 4),
#  ('으헤헤헤헹', '592', 5),
#  ('DragonT', '592', 4),
#  ('양남댁', '592', 5),
#  ('으르렁멍멍', '592', 4),
#  ('Hanjjang', '592', 5),
#  ('공공활동', '592', 5),
#  ('deuxhan', '592', 4),
#  ('연화 이', '592', 4),
#  ('연쥬쥬', '592', 4),
#  ('712yeeunl', '592', 4),
#  ('richardpN4937UU', '592', 3),
#  ('문용 이', '592', 5),
#  ('투덜스머프', '592', 4),
#  ('미선정2016', '592', 5),
#  ('kiju98', '592', 4),
#  ('파도피아노', '592', 4),
#  ('yeonhwal2016', '592', 4),
#  ('떠나볼래', '592', 3),
#  ('soul8486', '592', 5),
#  ('dongwookl28', '592', 5),
#  ('mithuki', '592', 5),
#  ('springspring404', '592', 5),
#  ('원이와민이', '592', 4),
#  ('사자비', '592', 4),
#  ('Jacque S', '592', 3),
#  ('아이언맨66', '592', 5),
#  ('펭귄뒷구르기', '592', 5),
#  ('Yooni', '592', 3),
#  ('은경 김', '592', 4),
#  ('밀키롤', '592', 5),
#  ('양선미', '592', 5),
#  ('Urizia J', '592', 4),
#  ('lkimsoyeonl', '592', 5),
#  ('miyani0613', '592', 3),
#  ('LOVESSU', '592', 4),
#  ('livia941', '592', 4),
#  ('vstellav', '592', 4),
#  ('클레오', '592', 3),
#  ('trigonotis', '592', 5),
#  ('리엘라', '592', 4),
#  ('dddaisy1', '592', 4),
#  ('묘롱이', '592', 4),
#  ('GivsUsAHint', '592', 5),
#  ('123SDF', '592', 4),
#  ('바람과함께살빠지다', '592', 5),
#  ('406대현김', '592', 5),
#  ('bjh3676', '592', 5),
#  ('떼류니', '592', 4),
#  ('M5610BJdavidl', '592', 4),
#  ('reembom', '592', 4),
#  ('sodal00', '592', 4),
#  ('soobok', '592', 4),
#  ('Eunjung L', '592', 3),
#  ('자몽쥬스00', '592', 5),
#  ('핀란드', '592', 3),
#  ('hana', '592', 4),
#  ('진규 이', '592', 3),
#  ('sashenka78', '592', 5),
#  ('mhs0922', '592', 5),
#  ('ComiNyang', '592', 4),
#  ('아곰e', '592', 4),
#  ('리나 최', '592', 5),
#  ('Hanbyeol Koo', '592', 3),
#  ('solmarutimsd', '592', 5),
#  ('밍키멍멍', '592', 5),
#  ('로미네', '592', 4),
#  ('774nan', '592', 4),
#  ('inwooy', '592', 2),
#  ('Design1005', '592', 5),
#  ('Jiyoon Y', '592', 5),
#  ('Hot6', '592', 5),
#  ('드래거', '592', 4),
#  ('은주 김', '592', 3),
#  ('쥬쥬쥬', '592', 4),
#  ('ssh5252', '592', 5),
#  ('뇽아', '592', 5),
#  ('everlsk', '592', 5),
#  ('ohohcanada', '592', 5),
#  ('진경 서', '592', 5),
#  ('nekoyang h', '592', 2),
#  ('다님', '592', 5),
#  ('쑤야', '592', 5),
#  ('수진 이', '592', 5),
#  ('닭장', '592', 4),
#  ('ahye0ng', '592', 5),
#  ('김쉘리', '592', 5),
#  ('Realsong', '592', 3),
#  ('abulapia', '592', 4),
#  ('울끈불끈차차차', '592', 5),
#  ('tieteam', '592', 1),
#  ('jaeunjanah', '592', 4),
#  ('1kim2parks', '592', 5),
#  ('여행자나나', '592', 3),
#  ('say895', '592', 4),
#  ('귀티멜로디', '592', 5),
#  ('멍미s2', '592', 5),
#  ('코코', '592', 5),
#  ('lkimsoyeonl', '592', 5),
#  ('jjbar', '592', 4),
#  ('은빛나 이', '592', 5),
#  ('만옥이네', '592', 4),
#  ('뽀오', '592', 5),
#  ('Heui Ho K', '592', 4),
#  ('zhzh89', '592', 3),
#  ('Cestlavie1976', '592', 3),
#  ('으스므', '592', 3),
#  ('owerea', '592', 3),
#  ('놀아놀아', '592', 5),
#  ('serendipity0a0', '592', 3),
#  ('마카롱', '592', 3),
#  ('호호홍홍홍', '592', 4),
#  ('2875rosa', '592', 4),
#  ('jinna', '592', 4),
#  ('시간은흐르고', '592', 4),
#  ('yukib973', '592', 5),
#  ('SONGHEE L', '592', 4),
#  ('코코', '592', 5),
#  ('주니룩스', '592', 4),
#  ('Shawn Lee', '592', 4),
#  ('공부를하자', '592', 4),
#  ('롬롬', '592', 4),
#  ('shigemura3', '592', 5),
#  ('여행좋아1', '592', 4),
#  ('e송', '592', 3),
#  ('H849PQ_', '592', 4),
#  ('에르프', '592', 4),
#  ('이안팍', '592', 4),
#  ('chunglang', '592', 4),
#  ('Doogangs', '592', 3),
#  ('redinoct', '592', 4),
#  ('쏘쏘양', '592', 4),
#  ('채예지', '592', 5),
#  ('Redboom10', '592', 4),
#  ('ank5022', '592', 5),
#  ('SimonLee88', '592', 2),
#  ('christina7542', '592', 4),
#  ('앗싸강인원', '592', 5),
#  ('nldogbert', '592', 5),
#  ('Space_Bunny_Dolphin', '592', 5),
#  ('coriks65', '592', 3),
#  ('soemr', '592', 3),
#  ('NaeDas', '592', 4),
#  ('amooali', '592', 5),
#  ('JacquelineMa', '592', 3),
#  ('Yoinji J', '592', 3),
#  ('Pawan C', '592', 5),
#  ('Vanessa L', '592', 5),
#  ('gazzillion', '592', 5),
#  ('dt3012', '592', 5),
#  ('Jessica R', '592', 3),
#  ('Mdecker17', '592', 4),
#  ('Patrisha A', '592', 1),
#  ('Muji', '592', 4),
#  ('Esther S', '592', 4),
#  ('Leo H', '592', 4),
#  ('DevourTheWorld', '592', 2),
#  ('maria', '592', 4),
#  ('Amelie Heise', '592', 4),
#  ('leel20', '592', 3),
#  ('Yi Lin E', '592', 1),
#  ('Hitmi', '592', 4),
#  ('John B', '592', 4),
#  ('deeann315', '592', 5),
#  ('Amy W', '592', 3),
#  ('Sim A', '592', 4),
#  ('Yong Kian Tan', '592', 4),
#  ('Hidayah AJ', '592', 4),
#  ('LiketoeatCincinnati', '592', 4),
#  ('Lynn G', '592', 3),
#  ('ChunChunMaru', '592', 3),
#  ('sunnydien', '592', 5),
#  ('theschuay86', '592', 3),
#  ('foxegurl266', '592', 3),
#  ('lottamatilda', '592', 3),
#  ('James N', '592', 4),
#  ('Stephen Leung 吃喝玩樂', '592', 5),
#  ('John S', '592', 1),
#  ('1canadianbear', '592', 4),
#  ('yoodh', '592', 4),
#  ('Lucymilby', '592', 1),
#  ('Pepe_masa', '592', 5),
#  ('Jonathan G', '592', 3),
#  ('Stephen G', '592', 4),
#  ('Ricardo G', '592', 4),
#  ('Ирина Ц', '592', 3),
#  ('Scott M', '592', 3),
#  ('deejay90210', '592', 5),
#  ('nedveddenise', '592', 2),
#  ('Alice C', '592', 3),
#  ('lemoncoke07', '592', 5),
#  ('HKeater', '592', 3),
#  ('Taimarie82', '592', 1),
#  ('BNandishB', '592', 4),
#  ('FDW87', '592', 3),
#  ('Daniel K', '592', 5),
#  ('iicydreams', '592', 4),
#  ('Noora Maimani', '592', 4),
#  ('Alex', '592', 5),
#  ('Surhi P', '592', 4),
#  ('Basspirate', '592', 5),
#  ('KelvinOngKB', '592', 5),
#  ('MrsBellot', '592', 5),
#  ('Peter Chee', '592', 4),
#  ('Chris A', '592', 5),
#  ('KEVINHWANG', '592', 5),
#  ('Esther C', '592', 5),
#  ('Timothy Jung Si... Y', '592', 3),
#  ('TamiRisoen', '592', 1),
#  ('Erin W', '592', 4),
#  ('faizaladibhassan', '592', 4),
#  ('GachGal', '592', 2),
#  ('urbancomplexx', '592', 5),
#  ('Kathy S', '592', 4),
#  ('Shunmusica', '592', 5),
#  ('minimize940314', '592', 3),
#  ('Prinster A', '592', 3),
#  ('AutumnRain1988', '592', 4),
#  ('Rohan F', '592', 2),
#  ('Emily', '592', 5),
#  ('Kathleen L', '592', 4),
#  ('Brenton K', '592', 4),
#  ('fairuz f', '592', 4),
#  ('John B', '592', 4),
#  ('TravelTaoSG', '592', 5),
#  ('beehappy86', '592', 5),
#  ('Abigail O', '592', 4),
#  ('blinkboxtraveler', '592', 3),
#  ('Travelove58', '592', 3),
#  ('Chris A', '592', 5),
#  ('young', '592', 4),
#  ('sunshine-for-four', '592', 4),
#  ('julesandheath', '592', 3),
#  ('faithjvp25', '592', 3),
#  ('noworries2000', '592', 4),
#  ('MisheruT', '592', 4),
#  ('kimahrikku', '592', 3),
#  ('polinak236', '592', 2),
#  ('Watu2014', '592', 4),
#  ('Diana Y', '592', 4),
#  ('vlogg', '747', 5),
#  ('Kylie Park', '784', 4),
#  ('EDGAR.S', '784', 5),
#  ('H L', '784', 3),
#  ('한기 문', '784', 5),
#  ('SOULSEOUL', '784', 5),
#  ('Joon K', '784', 4),
#  ('PINKSHOW01', '784', 5),
#  ('evita002', '784', 4),
#  ('Sung Chan L', '784', 4),
#  ('juou', '784', 4),
#  ('Walkerxoxo', '784', 5),
#  ('Chocogodiva', '784', 5),
#  ('Yellow_Windmill', '784', 5),
#  ('형근 김', '784', 5),
#  ('apeach11', '784', 4),
#  ('봉기 문', '784', 4),
#  ('Stafin_Kim', '784', 4),
#  ('민석 권', '784', 4),
#  ('장두현', '784', 5),
#  ('kiju98', '784', 5),
#  ('아이언맨66', '784', 5),
#  ('호밀빵', '784', 4),
#  ('GivsUsAHint', '784', 5),
#  ('떼류니', '784', 5),
#  ('everlsk', '784', 5),
#  ('inthesub', '784', 4),
#  ('seoulyoung', '784', 5),
#  ('reverb83', '784', 5),
#  ('Eunjung L', '784', 5),
#  ('jjbar', '784', 4),
#  ('lkimsoyeonl', '784', 5),
#  ('SCY', '784', 5),
#  ('john y', '784', 3),
#  ('nanal78878', '784', 3),
#  ('kkh2254', '784', 5),
#  ('bahajia', '784', 4),
#  ('Romy870226', '784', 4),
#  ('parky77', '784', 5),
#  ('junfff', '784', 3),
#  ('sang cheol h', '784', 5),
#  ('Bintang27', '784', 4),
#  ('Jon L', '784', 5),
#  ('Sam', '784', 4),
#  ('ILoveFoodComa', '784', 4),
#  ('joycey0707', '784', 3),
#  ('Alice C', '784', 3),
#  ('chesterchandler', '784', 3),
#  ('Simon J', '784', 5),
#  ('Shanneen C', '784', 5),
#  ('Emil_Yumin', '784', 3),
#  ('kimahrikku', '784', 4),
#  ('King Kwa Zulu', '784', 5),
#  ('Danott', '784', 2),
#  ('David G', '784', 5),
#  ('Saranger', '784', 5),
#  ('edisupp s', '784', 4),
#  ('Diane D', '784', 4),
#  ('Zolike78', '784', 5),
#  ('ProfAllison', '784', 4),
#  ('mnn17', '784', 5),
#  ('Yoinji J', '784', 4),
#  ('Joon K', '790', 4),
#  ('Sejin Ahn', '169', 5),
#  ('봉기 문', '169', 5),
#  ('J J', '169', 3),
#  ('gingertea', '169', 5),
#  ('pic_bd', '169', 4),
#  ('천막족', '169', 3),
#  ('Andrew_Snail', '169', 2),
#  ('JUSEONG Y', '169', 5),
#  ('gunyoungy', '169', 5),
#  ('마노', '169', 5),
#  ('썬샤', '169', 5),
#  ('Traveling Foodie', '169', 5),
#  ('ᄌ ᄀ', '169', 4),
#  ('luvvparis', '169', 4),
#  ('용마사', '169', 4),
#  ('Queen3839', '169', 5),
#  ('쥬쥬쥬', '169', 5),
#  ('Yellow_Windmill', '169', 1),
#  ('파랑나비', '169', 4),
#  ('yusoooooo', '169', 4),
#  ('choichoi123', '169', 4),
#  ('lao717', '169', 5),
#  ('진인 이2fg5dtuk', '169', 3),
#  ('민석 권', '169', 4),
#  ('junheemin', '169', 5),
#  ('qberwy', '169', 5),
#  ('yangcho0311', '169', 5),
#  ('Karl-Styner', '169', 4),
#  ('dongwookl28', '169', 4),
#  ('투덜스머프', '169', 5),
#  ('HAPPINESSWISHER', '169', 5),
#  ('사자비', '169', 3),
#  ('DREAMING_dream', '169', 4),
#  ('마카롱', '169', 4),
#  ('DragonT', '169', 4),
#  ('livia941', '169', 3),
#  ('nanal78878', '169', 4),
#  ('여행가자구요', '169', 5),
#  ('bjh3676', '169', 5),
#  ('sunnyje', '169', 4),
#  ('406대현김', '169', 5),
#  ('inthesub', '169', 4),
#  ('Hanbyeol Koo', '169', 3),
#  ('waytoLiah', '169', 5),
#  ('reverb83', '169', 2),
#  ('PINKSHOW01', '169', 4),
#  ('chunglang', '169', 4),
#  ('nayepp', '169', 4),
#  ('Romy870226', '169', 4),
#  ('Moonkyu K', '169', 5),
#  ('이안팍', '169', 4),
#  ('jjbar', '169', 4),
#  ('만옥이네', '169', 4),
#  ('니콜라06', '169', 4),
#  ('znzl', '169', 4),
#  ('주니룩스', '169', 3),
#  ('SCY', '169', 5),
#  ('TOPTEN93', '169', 3),
#  ('주니네', '169', 3),
#  ('マッキネン', '169', 3),
#  ('ksn0w', '169', 3),
#  ('BillNabilah', '169', 4),
#  ('Oldjack', '169', 4),
#  ('LG_Kay', '169', 4),
#  ('L. Lee', '169', 5),
#  ('thetravellingfugu', '169', 4),
#  ('Malcolm', '169', 3),
#  ('Kasia Z', '169', 5),
#  ('mikeadey72', '169', 4),
#  ('Mdecker17', '169', 4),
#  ('NYDEB55', '169', 5),
#  ('Sam', '169', 5),
#  ('DevourTheWorld', '169', 3),
#  ('LASeoulGuy', '169', 4),
#  ('SMLove226', '169', 3),
#  ('Honey2Star', '169', 3),
#  ('HEESUN H', '169', 5),
#  ('Donna B', '169', 5),
#  ('Ricardo G', '169', 4),
#  ('Natttsss', '169', 4),
#  ('Shunmusica', '169', 5),
#  ('Joey M', '169', 3),
#  ('minimize940314', '169', 3),
#  ('MateEeMa', '169', 3),
#  ('Mina Bashier Bosimin', '169', 5),
#  ('mnn17', '169', 3),
#  ('polinak236', '169', 3),
#  ('Joon K', '83', 4),
#  ('BillNabilah', '83', 5),
#  ('Lynns98816', '83', 4),
#  ('ILoveFoodComa', '83', 4),
#  ('Quack H', '83', 4),
#  ('snoopy419', '68', 4),
#  ('정명진', '68', 5),
#  ('HelenaGuerra', '68', 3),
#  ('407yjj', '828', 3),
#  ('sweetchocho', '828', 5),
#  ('sanrio2018', '828', 3),
#  ('jihye L', '828', 3),
#  ('Lucy L', '828', 5),
#  ('형근 김', '828', 5),
#  ('yusoooooo', '828', 4),
#  ('n2cc', '828', 5),
#  ('ㅡ모모ㅡ', '828', 4),
#  ('JUSEONG Y', '828', 4),
#  ('클레오', '828', 4),
#  ('kyuseon', '828', 5),
#  ('ayul1', '828', 5),
#  ('ᄌ ᄀ', '828', 4),
#  ('Bora Y', '828', 3),
#  ('luvvparis', '828', 4),
#  ('hongs925', '828', 4),
#  ('Chocogodiva', '828', 5),
#  ('Ju-yeon Y', '828', 4),
#  ('ambition93', '828', 4),
#  ('Seohyeong J', '828', 4),
#  ('dkfma0657', '828', 5),
#  ('HelloPYO', '828', 3),
#  ('강한여자', '828', 4),
#  ('마노', '828', 5),
#  ('Stereos', '828', 3),
#  ('lao717', '828', 4),
#  ('apeach11', '828', 4),
#  ('Euphem_Korea', '828', 4),
#  ('kkh2254', '828', 4),
#  ('수수 김', '828', 4),
#  ('눈에서레이져빔', '828', 4),
#  ('owerea', '828', 5),
#  ('qberwy', '828', 5),
#  ('jay600', '828', 4),
#  ('코스트너', '828', 5),
#  ('Yuyumi85', '828', 5),
#  ('유이717', '828', 4),
#  ('duck3222', '828', 5),
#  ('형근 김', '828', 5),
#  ('soobok', '828', 4),
#  ('으헤헤헤헹', '828', 5),
#  ('주빈', '828', 3),
#  ('YJ Lee', '828', 5),
#  ('양남댁', '828', 5),
#  ('chunglang', '828', 4),
#  ('연화 이', '828', 3),
#  ('희승 윤', '828', 5),
#  ('정원 신', '828', 5),
#  ('Karl-Styner', '828', 4),
#  ('투덜스머프', '828', 5),
#  ('떠나볼래', '828', 3),
#  ('MOA S', '828', 3),
#  ('파도피아노', '828', 4),
#  ('mithuki', '828', 5),
#  ('Yooni', '828', 3),
#  ('hyomin78', '828', 5),
#  ('유이717', '828', 4),
#  ('livia941', '828', 3),
#  ('양선미', '828', 5),
#  ('hjk8427_', '828', 5),
#  ('리엘라', '828', 3),
#  ('ssanggi', '828', 5),
#  ('여행가자구요', '828', 4),
#  ('진규 이', '828', 3),
#  ('바람과함께살빠지다', '828', 4),
#  ('리나 최', '828', 3),
#  ('자몽쥬스00', '828', 4),
#  ('곰다섯마리', '828', 4),
#  ('ComiNyang', '828', 5),
#  ('아곰e', '828', 4),
#  ('solmarutimsd', '828', 5),
#  ('진경 서', '828', 3),
#  ('Jiyoon Y', '828', 5),
#  ('드래거', '828', 3),
#  ('뇽아', '828', 5),
#  ('everlsk', '828', 5),
#  ('sdc0503', '828', 4),
#  ('시간은흐르고', '828', 4),
#  ('ahye0ng', '828', 5),
#  ('SANTANIM', '828', 4),
#  ('김쉘리', '828', 5),
#  ('이안팍', '828', 4),
#  ('H849PQ_', '828', 4),
#  ('say895', '828', 5),
#  ('jjbar', '828', 4),
#  ('Cestlavie1976', '828', 4),
#  ('SONGHEE L', '828', 4),
#  ('alfo5', '828', 5),
#  ('으스므', '828', 3),
#  ('2875rosa', '828', 3),
#  ('lkimsoyeonl', '828', 5),
#  ('롬롬', '828', 3),
#  ('nayepp', '828', 3),
#  ('공부를하자', '828', 5),
#  ('nanal78878', '828', 4),
#  ('차씨', '828', 4),
#  ('죠이어', '828', 5),
#  ('eoto34', '828', 5),
#  ('redinoct', '828', 4),
#  ('sang cheol h', '828', 4),
#  ('ank5022', '828', 4),
#  ('yipjcs88', '828', 5),
#  ('Karen M', '828', 3),
#  ('Emil_Yumin', '828', 4),
#  ('Quang Kiet Le', '828', 3),
#  ('Elizabeth M', '828', 5),
#  ('mariedesjardins', '828', 4),
#  ('Ken V', '828', 5),
#  ('K1 R', '828', 4),
#  ('KEVINHWANG', '828', 5),
#  ('TamiRisoen', '828', 5),
#  ('Beth K', '828', 4),
#  ('Kathy S', '828', 4),
#  ('edisupp s', '828', 2),
#  ('minimize940314', '828', 5),
#  ('AutumnRain1988', '828', 5),
#  ('Robert P', '828', 5),
#  ('noworries2000', '828', 4),
#  ('SandyAmanda', '828', 4),
#  ('Jaewook Lim in Seoul', '6', 4),
#  ('Junho', '6', 3),
#  ('봉기 문', '54', 4),
#  ('Jiyoun', '54', 3),
#  ('Gino Gin', '54', 5),
#  ('ahirity', '54', 4),
#  ('Relax825963', '54', 5),
#  ('Traveling Foodie', '54', 3),
#  ('Roah_CA', '54', 3),
#  ('gingertea', '54', 5),
#  ('J J', '54', 4),
#  ('Kat', '54', 4),
#  ('L. Lee', '54', 5),
#  ('Mesy', '54', 4),
#  ('JHL', '1358', 4),
#  ('vlogg', '814', 5),
#  ('JHL', '357', 4),
#  ('HAEJIN JUN', '419', 5),
#  ('AHN按 A', '419', 4),
#  ('lordauch', '419', 4),
#  ('42bryant', '419', 3),
#  ('kiju98', '419', 5),
#  ('강한여자', '419', 4),
#  ('Charlie5150', '419', 5),
#  ('sungshin248', '419', 4),
#  ('Wanimyo', '419', 4),
#  ('죠이어', '419', 4),
#  ('LASeoulGuy', '419', 5),
#  ('Hidayah AJ', '419', 5),
#  ('yangcho0311', '1167', 4),
#  ('민석 권', '1167', 3),
#  ('soobok', '1167', 4),
#  ('whiskers16', '1167', 3),
#  ('Eunjung L', '1167', 3),
#  ('AHN按 A', '418', 4),
#  ('종춘 이', '418', 3),
#  ('407yjj', '418', 5),
#  ('Kylie Park', '418', 4),
#  ('lim', '418', 5),
#  ('194ren', '418', 4),
#  ('양명수', '418', 5),
#  ('gingertea', '418', 5),
#  ('EJ K', '418', 5),
#  ('jieun kim', '418', 5),
#  ('Yoonjung C', '418', 5),
#  ('seongeun y', '418', 5),
#  ('희영 장', '418', 4),
#  ('봉기 문', '418', 4),
#  ('Mikyung J', '418', 5),
#  ('Izzy169', '418', 5),
#  ('zzanzini', '418', 5),
#  ('봉기 문', '418', 4),
#  ('choichoi123', '418', 5),
#  ('heefeel', '418', 4),
#  ('nanal78878', '418', 4),
#  ('ruze0201', '418', 4),
#  ('jinlee0201', '418', 5),
#  ('Jelsomina', '418', 4),
#  ('Hyewon P', '418', 5),
#  ('Ju-yeon Y', '418', 5),
#  ('dkfma0657', '418', 5),
#  ('Seon Na G', '418', 3),
#  ('EDGAR.S', '418', 5),
#  ('메가마일', '418', 5),
#  ('Stereos', '418', 3),
#  ('902', '418', 5),
#  ('시리우드', '418', 4),
#  ('백호50', '418', 4),
#  ('천막족', '418', 4),
#  ('눈에서레이져빔', '418', 5),
#  ('봉기 문', '418', 5),
#  ('flyingdonutx100', '418', 5),
#  ('whechon', '418', 5),
#  ('민준 최', '418', 5),
#  ('kkobuk', '418', 5),
#  ('cxoco', '418', 5),
#  ('ㅡ모모ㅡ', '418', 3),
#  ('ssm_00', '418', 5),
#  ('Sarang', '418', 5),
#  ('강한여자', '418', 4),
#  ('byounghwas', '418', 5),
#  ('투덜스머프', '418', 4),
#  ('yhj9072', '418', 4),
#  ('떠나볼래', '418', 3),
#  ('공공활동', '418', 5),
#  ('파도피아노', '418', 5),
#  ('chunglang', '418', 4),
#  ('사자비', '418', 4),
#  ('wis지니', '418', 5),
#  ('하얀구름', '418', 4),
#  ('Urizia J', '418', 5),
#  ('DREAMING_dream', '418', 4),
#  ('으헤헤헤헹', '418', 5),
#  ('lulu0257', '418', 5),
#  ('Hyeyoung S', '418', 4),
#  ('윤미 김', '418', 4),
#  ('livia941', '418', 4),
#  ('HyeonnyKim', '418', 4),
#  ('rose o', '418', 5),
#  ('dddaisy1', '418', 4),
#  ('정팔이', '418', 5),
#  ('soobok', '418', 4),
#  ('진규 이', '418', 4),
#  ('bjh3676', '418', 5),
#  ('jay600', '418', 5),
#  ('sodal00', '418', 5),
#  ('yangcho0311', '418', 5),
#  ('406대현김', '418', 5),
#  ('영원바라보다', '418', 5),
#  ('난이언니', '418', 5),
#  ('solmarutimsd', '418', 5),
#  ('Danny_S_starrr', '418', 4),
#  ...]

# %%
import cornac
from cornac.eval_methods import RatioSplit


# Load the Amazon Clothing  dataset, and binarise ratings using cornac.data.Reader
feedback = ls

# Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=feedback,
    test_size=0.2,
    rating_threshold=1.0,
    seed=123,
    exclude_unknowns=True,
    verbose=True,
)

# Instantiate the recommender models to be compared
# gmf = cornac.models.GMF(
#     num_factors=8,
#     num_epochs=10,
#     learner="adam",
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
# )
# mlp = cornac.models.MLP(
#     layers=[64, 32, 16, 8],
#     act_fn="tanh",
#     learner="adam",
#     num_epochs=10,
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
# )

neumf1 = cornac.models.NeuMF(
    num_factors=4,
    layers=[16,8,4],
    act_fn="tanh",
    learner="adam",
    num_epochs=50,
    batch_size=256,
    lr=1e-3,
    num_neg=50,
    seed=123,
)
# neumf2 = cornac.models.NeuMF(
#     name="NeuMF_pretrained",
#     learner="adam",
#     num_epochs=10,
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
#     num_factors=gmf.num_factors,
#     layers=mlp.layers,
#     act_fn=mlp.act_fn,
# ).pretrain(gmf, mlp)

# Instantiate evaluation metrics
ndcg_10 = cornac.metrics.NDCG(k=10)
pre_10 = cornac.metrics.Precision(k=10)
rec_10 = cornac.metrics.Recall(k=10)
f_10 = cornac.metrics.FMeasure(k=10)

# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf1],
    metrics=[ndcg_10,pre_10, rec_10, f_10],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 1045
# Number of items = 501
# Number of ratings = 14975
# Max rating = 5.0
# Min rating = 1.0
# Global mean = 4.2
# ---
# Test data:
# Number of users = 983
# Number of items = 274
# Number of ratings = 3783
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 1045
# Total items = 501
#
# [NeuMF] Training started!
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 457 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 35 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
