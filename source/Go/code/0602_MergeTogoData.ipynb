# %%
import pandas as pd;
seoul = pd.read_csv('./togo_new2.csv')
seoul
# Out:
#                         name location  category  \
# 0                    봉은사(서울)      강남구       1.0
# 1                     최순우 옛집      성북구       1.0
# 2                        덕수궁       중구       1.0
# 3     국립민속박물관&국립민속박물관 어린이박물관      종로구       1.0
# 4                        창경궁      종로구       1.0
# ...                      ...      ...       ...
# 1350             금강제화 (종로지점)      종로구       4.0
# 1351              금강제화 영등포본점     영등포구       4.0
# 1352       프리스비(Frisbee) 홍대점      마포구       4.0
# 1353               금강제화 명동본점       중구       4.0
# 1354                스토리지북앤필름      용산구       4.0
#
#                                                  tags   reviews  \
# 0               #가족여행#관광지#교과서속여행#당일치기여행#봉은사(서울)#사찰&산사     0.csv
# 1              #관광지#근대한옥#기념관#아이와함께#역사#역사문화재#역사속#역사속으로     1.csv
# 2     #15_16한국관광100선#17_18한국관광100선#19_20한국관광100선#가족여행     2.csv
# 3                                                #관광지     3.csv
# ...

# %%
import os
for i in os.listdir("./kakao_places"):
    print(i)
    get_df = pd.read_csv(f'./kakao_places/{i}')
    df = pd.concat([df, get_df])
# Out:
# kakao_places_g.csv
# kakao_places_f.csv
# kakao_places_d.csv
# kakao_places_e.csv
# kakao_places_a.csv
# kakao_places_b.csv
# kakao_places_c.csv
# .ipynb_checkpoints
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-ebf81fd87acc> in <module>
#       2 for i in os.listdir("./kakao_places"):
#       3     print(i)
# ----> 4     get_df = pd.read_csv(f'./kakao_places/{i}')
#       5     df = pd.concat([df, get_df])
#
# ...

# %%
df
# Out:
#                                            address category  \
# 0                        서울 마포구 포은로 67 2층 (우)04017        g
# 1                서울 송파구 동남로 147 수동빌딩 지하1층 (우)05827        g
# 2                      서울 강남구 강남대로118길 19 (우)06119        g
# 3    서울 송파구 법원로4길 10 힐스테이트에코문정 지하1층 B106호 (우)05855        g
# 4                    서울 송파구 올림픽로32길 13 3층 (우)05543        g
# ..                                             ...      ...
# 164                        서울 종로구 성균관로 12 (우)03074        c
# 165                   서울 은평구 연서로27길 17 3층 (우)03333        c
# 166                    서울 강동구 양재대로128길 14 (우)05302        c
# 167                  서울 강남구 강남대로102길 13-8 (우)06123        c
# 168                     서울 광진구 능동로 302 3층 (우)04985        c
#
#                                                link          open_day  \
# 0      https://place.map.kakao.com/78187711#comment               NaN
# 1     https://place.map.kakao.com/349474814#comment               NaN
# ...
