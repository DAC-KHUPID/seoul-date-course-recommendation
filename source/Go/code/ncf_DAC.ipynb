# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Neural Collaborative Filtering on DAC dataset.
#
# Neural Collaborative Filtering (NCF) is a well known recommendation algorithm that generalizes the matrix factorization problem with multi-layer perceptron.
#
# This notebook provides an example of how to utilize and evaluate NCF implementation in the `reco_utils`. We use a smaller dataset in this example to run NCF efficiently with GPU acceleration on a [Data Science Virtual Machine](https://azure.microsoft.com/en-gb/services/virtual-machines/data-science-virtual-machines/).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../")
import time
import pandas as pd
import tensorflow as tf

from reco_utils.recommender.ncf.ncf_singlenode import NCF
from reco_utils.recommender.ncf.dataset import Dataset as NCFDataset
from reco_utils.dataset import movielens
from reco_utils.common.notebook_utils import is_jupyter
from reco_utils.dataset.python_splitters import python_stratified_split
from reco_utils.evaluation.python_evaluation import (rmse, mae, rsquared, exp_var, map_at_k, ndcg_at_k, precision_at_k, 
                                                     recall_at_k, get_top_k_items)

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.6.10 |Anaconda, Inc.| (default, May  7 2020, 23:06:31)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas version: 0.25.3
# Tensorflow version: 1.15.0

# %% [markdown]
# Set the default parameters.

# %%
# top k items to recommend
TOP_K = 10

# Select MovieLens data size: 100k, 1m, 10m, or 20m
MOVIELENS_DATA_SIZE = '100k'

# Model parameters
EPOCHS = 50
BATCH_SIZE = 256

SEED = 42

# %% [markdown]
# ### 1. Load prepared data

# %%
df = pd.read_csv('../ncf_data.csv')
df.rename(columns = {'p_id' : 'itemID', 'u_id' : 'userID', 'u_rate' : 'rating'}, inplace = True)

# %%
pd.set_option('display.max_rows', 10)
df.drop_duplicates(['itemID', 'userID'], keep='last', inplace=True)

# %%
df = df.groupby('userID').filter(lambda x : len(x)> 10).copy()

# %%
df[df['userID'] == '진규 이']
# Out:
#        index itemID userID  rating
# 244     3650    237   진규 이       4
# 427     4320    592   진규 이       3
# 832     5370    828   진규 이       3
# 990     5789    418   진규 이       4
# 1537    7196    591   진규 이       4
# 2052    8773    341   진규 이       4
# 2476   11450      4   진규 이       4
# 3050   12524    225   진규 이       4
# 3419   13562      0   진규 이       3
# 3654   14119   1404   진규 이       4
# 4077   15055      1   진규 이       2
# 4279   15421    595   진규 이       4
# 4674   16430    556   진규 이       4
# 5361   18349     79   진규 이       4
# 5678   19103      2   진규 이       4
# 5878   19542    757   진규 이       4
# 6156   20899    596   진규 이       4
# 6649   22426   1059   진규 이       3
# 6864   23149     23   진규 이       4
# 6991   23392     22   진규 이       4
# 7366   24637    280   진규 이       4
# 7487   24876    121   진규 이       4
# 7928   26180     34   진규 이       4
# 8326   27413    492   진규 이       4
# 8664   28241    685   진규 이       4
# 8883   28862    120   진규 이       4
# 9684   31106    441   진규 이       2
# 9919   31532    251   진규 이       2
# 10025  31815    872   진규 이       3
# 10280  32822     26   진규 이       5
# 10855  35642    244   진규 이       4
# 10988  35993    881   진규 이       4
# 11105  36193    499   진규 이       4
# 12112  38830    105   진규 이       4
# 12589  39842   1446   진규 이       4
# 12959  43664   1136   진규 이       4
# 13178  44241    460   진규 이       4
# 13207  44297    851   진규 이       4
# 13324  44538    110   진규 이       4
# 13512  44923    702   진규 이       4
# 14181  46464    311   진규 이       4
# 14627  47233    661   진규 이       4
# 14988  48224    772   진규 이       4
# 15412  49546    410   진규 이       4
# 15660  50067    439   진규 이       3
# 16100  51726     74   진규 이       4
# 16290  52341   1344   진규 이       4
# 16698  53259    598   진규 이       4
# 17350  56095    823   진규 이       4
# 17853  57540    572   진규 이       4
# 18156  58578   1169   진규 이       4
# 18255  58768    167   진규 이       5
# 18544  59493    213   진규 이       4
# 18917  60709    159   진규 이       3

# %% [markdown]
# ### 2. Split the data using the stratified splitter provided in utilities

# %%
train, test = python_stratified_split(df, 0.8)

# %% [markdown]
# Generate an NCF dataset object from the data subsets.

# %%
data = NCFDataset(train=train, test=test, seed=SEED)

# %% [markdown]
# ### 3. Train the NCF model on the training data, and get the top-k recommendations for our testing data
#
# NCF accepts implicit feedback and generates prospensity of items to be recommended to users in the scale of 0 to 1. A recommended item list can then be generated based on the scores. Note that this quickstart notebook is using a smaller number of epochs to reduce time for training. As a consequence, the model performance will be slighlty deteriorated.

# %%
#50
#256
#42

model = NCF (
    n_users=data.n_users, 
    n_items=data.n_items,
    model_type="NeuMF",
    n_factors=4,
    layer_sizes=[16,8,4],
    n_epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    learning_rate=1e-3,
    verbose=10,
    seed=SEED
)

# %%
start_time = time.time()

model.fit(data)

train_time = time.time() - start_time

print("Took {} seconds for training.".format(train_time))
# Out:
# Took 22.828919887542725 seconds for training.

# %%
start_time = time.time()

users, items, preds = [], [], []
item = list(train.itemID.unique())
for user in train.userID.unique():
    user = [user] * len(item) 
    users.extend(user)
    items.extend(item)
    preds.extend(list(model.predict(user, item, is_list=True)))

all_predictions = pd.DataFrame(data={"userID": users, "itemID":items, "prediction":preds})

merged = pd.merge(train, all_predictions, on=["userID", "itemID"], how="outer")
all_predictions = merged[merged.rating.isnull()].drop('rating', axis=1)

test_time = time.time() - start_time
print("Took {} seconds for prediction.".format(test_time))
# Out:
# Took 0.6900091171264648 seconds for prediction.

# %% [markdown]
# ### 4. Evaluate how well NCF performs

# %% [markdown]
# The ranking metrics are used for evaluation.

# %%
eval_map = map_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_precision = precision_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_recall = recall_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K)
eval_f1 = 2*(eval_precision*eval_recall)/(eval_precision+eval_recall)

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall,
      "F1Score@K:\t%f" % eval_f1,
      sep='\n')
# Out:
# MAP:	0.247087
# NDCG:	0.390923
# Precision@K:	0.241537
# Recall@K:	0.438293
# F1Score@K:	0.311442

# %%
eval_f1 = 2*(eval_precision*eval_recall)/(eval_precision+eval_recall)
eval_f1
# Out:
# 0.3114422871173871

# %%
####1
####user_id > 10
#MAP:	0.247087
#NDCG:	0.390923
#Precision@K:	0.241537
#Recall@K:	0.438293

####2
####user_id > 0
#MAP:	0.381576
#NDCG:	0.445280
#Precision@K:	0.086908
#Recall@K:	0.582482

# %%
if is_jupyter():
    # Record results with papermill for tests
    import papermill as pm
    pm.record("map", eval_map)
    pm.record("ndcg", eval_ndcg)
    pm.record("precision", eval_precision)
    pm.record("recall", eval_recall)
    pm.record("train_time", train_time)
    pm.record("test_time", test_time)
# Out:
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   after removing the cwd from sys.path.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   """
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   import sys
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   if __name__ == '__main__':

# %% [markdown]
# # NCF Cornac

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ncf_data.csv')
df.rename(columns = {'p_id' : 'itemID', 'u_id' : 'userID', 'u_rate' : 'rating'}, inplace = True)

# %%
df = df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
df[df['userID'] == '진규 이']
# Out:
#       itemID userID  rating
# 3650     237   진규 이       4
# 4320     592   진규 이       3
# 5370     828   진규 이       3
# 5789     418   진규 이       4
# 7196     591   진규 이       4
# 8773     341   진규 이       4
# 11450      4   진규 이       4
# 12524    225   진규 이       4
# 13562      0   진규 이       3
# 14119   1404   진규 이       4
# 15055      1   진규 이       2
# 15421    595   진규 이       4
# 16430    556   진규 이       4
# 18349     79   진규 이       4
# 19103      2   진규 이       4
# 19542    757   진규 이       4
# 20899    596   진규 이       4
# 22426   1059   진규 이       3
# 23149     23   진규 이       4
# 23392     22   진규 이       4
# 24637    280   진규 이       4
# 24876    121   진규 이       4
# 26180     34   진규 이       4
# 27413    492   진규 이       4
# 28241    685   진규 이       4
# 28862    120   진규 이       4
# 31106    441   진규 이       2
# 31532    251   진규 이       2
# 31815    872   진규 이       3
# 32822     26   진규 이       5
# 35642    244   진규 이       4
# 35993    881   진규 이       4
# 36193    499   진규 이       4
# 38830    105   진규 이       4
# 39842   1446   진규 이       4
# 43664   1136   진규 이       4
# 44241    460   진규 이       4
# 44297    851   진규 이       4
# 44538    110   진규 이       4
# 44923    702   진규 이       4
# 46464    311   진규 이       4
# 47233    661   진규 이       4
# 48224    772   진규 이       4
# 49546    410   진규 이       4
# 50067    439   진규 이       3
# 51726     74   진규 이       4
# 52341   1344   진규 이       4
# 53259    598   진규 이       4
# 56095    823   진규 이       4
# 57540    572   진규 이       4
# 58578   1169   진규 이       4
# 58768    167   진규 이       5
# 59493    213   진규 이       4
# 60709    159   진규 이       3

# %%
df.reset_index(inplace=True)
df
# Out:
#        index itemID      userID  rating
# 0          0   f239   batoo2000       5
# 1          1   f239  Woongs Lee       5
# 2          2   f239         박우석       5
# 3          3   f239         EOS       5
# 4          4   f239         ㅎㅈㅊ       4
# ...      ...    ...         ...     ...
# 61803  61803    560  PINKSHOW01       5
# 61804  61804    560    MAKCHA79       4
# 61805  61805    560      올리브521       5
# 61806  61806    560      406대현김       5
# 61807  61807    560    dianne c       3
#
# [61808 rows x 4 columns]

# %%
ls=[]
for i in range (0,len(df)):
    new_tuple = (df['userID'][i], df['itemID'][i], df['rating'][i])
    ls.append(new_tuple)

# %%
ls
# Out:
# [('batoo2000', 'f239', 5),
#  ('Woongs Lee', 'f239', 5),
#  ('박우석', 'f239', 5),
#  ('EOS', 'f239', 5),
#  ('ㅎㅈㅊ', 'f239', 4),
#  ('한효선', 'b209', 4),
#  ('백지현', 'e810', 3),
#  ('uni', 'e810', 1),
#  ('Hannah-Gahee U♥', 'a211', 5),
#  ('김세미', 'a211', 5),
#  ('쑨꿍', 'a211', 5),
#  ('제주벼', 'a211', 2),
#  ('혜진', 'a211', 5),
#  ('L', 'a211', 2),
#  ('작은배', 'a211', 1),
#  ('jw', 'a211', 1),
#  ('정원', 'a211', 5),
#  ('꿀벌', 'a211', 1),
#  ('바지우', 'a211', 1),
#  ('fjhndklhvnkl', 'a211', 5),
#  ('eodeoddl', 'a211', 5),
#  ('나상준', 'a211', 5),
#  ('문수', 'a211', 5),
#  ('ㅎㅎ', 'a211', 5),
#  ('김진영', 'a211', 5),
#  ('이동훈', 'a211', 5),
#  ('서수진', 'a211', 1),
#  ('안영준', 'a211', 1),
#  ('ryu', 'a211', 1),
#  ('볼링마니아', 'a211', 1),
#  ('시닝', 'a211', 1),
#  ('ryu', 'a211', 1),
#  ('볼링마니아', 'a211', 1),
#  ('시닝', 'a211', 1),
#  ('zjffltmxj', 'a211', 1),
#  ('영원관세법인', 'a211', 1),
#  ('이정근', 'a211', 5),
#  ('카카카', 'a211', 5),
#  ('비호', 'a211', 1),
#  ('자의식', 'a211', 3),
#  ('쥴리', 'b44', 3),
#  ('2020년 화이팅!', 'b44', 5),
#  ('DAAS', 'b44', 5),
#  ('윤오', 'f206', 5),
#  ('용이', 'f206', 5),
#  ('김가현', 'f20', 5),
#  ('태찌', 'f20', 3),
#  ('솔직한평가', 'g112', 5),
#  ('chloe', 'g112', 5),
#  ('노웅철', 'g112', 5),
#  ('김철호', 'g112', 5),
#  ('개금장', 'g112', 5),
#  ('아닌건 아니다', 'b88', 1),
#  ('장원혁', 'g327', 1),
#  ('륜하', 'g115', 5),
#  ('뽁뽁이', 'd15', 5),
#  ('은경이', 'd15', 5),
#  ('young', 'f27', 1),
#  ('박민지', 'b43', 3),
#  ('ㅇㅎ', 'f201', 3),
#  ('김현진', 'f201', 5),
#  ('권세윤', 'f201', 5),
#  ('Equity', 'f201', 2),
#  ('김혜진', 'a811', 5),
#  ('예옹', 'f208', 1),
#  ('황영주', 'f208', 1),
#  ('현', 'f208', 1),
#  ('motive', 'f208', 2),
#  ('서재원', 'f208', 2),
#  ('박성인', 'e210', 1),
#  ('이현정', 'e210', 5),
#  ('다다다', 'e210', 4),
#  ('만경이', 'e210', 4),
#  ('평점가', 'e210', 3),
#  ('구름별', 'g311', 5),
#  ('전성배', 'g311', 5),
#  ('지정현', 'g311', 5),
#  ('KM', 'g123', 1),
#  ('김미희', 'g123', 5),
#  ('dawon', 'g123', 5),
#  ('ㄱㄱㅑ', 'f237', 3),
#  ('고먐미', 'c113', 1),
#  ('홍', 'c113', 3),
#  ('이수광', 'c113', 5),
#  ('686', 'f29', 4),
#  ('류정진', 'f16', 5),
#  ('HG', 'f16', 5),
#  ('영수운', 'f16', 5),
#  ('JY', 'f16', 5),
#  ('뭔데말해바', 'f16', 5),
#  ('나먄아니면되', 'd24', 2),
#  ('영더', 'd24', 1),
#  ('으에엥', 'd24', 1),
#  ('뿌애애애', 'd24', 1),
#  ('뿌애애애', 'd24', 1),
#  ('다라', 'c114', 1),
#  ('짠티항', 'c114', 5),
#  ('전대운(lucas)', 'c114', 4),
#  ('신논현 네일한 나', 'f230', 5),
#  ('JL', 'f230', 1),
#  ('김소라', 'b72', 5),
#  ('이제현', 'b72', 5),
#  ('용성', 'g124', 1),
#  ('호두과자', 'b2410', 2),
#  ('piazza', 'b2410', 1),
#  ('별맘', 'b86', 3),
#  ('Jae-Gyung Ahn', 'b200', 5),
#  ('서슐랭', 'b200', 4),
#  ('hb', 'b200', 4),
#  ('최재혁', 'b200', 5),
#  ('허남열', 'g1313', 5),
#  ('서연', 'f42', 5),
#  ('태', 'f42', 1),
#  ('박우진', 'b26', 5),
#  ('망구루', 'b26', 5),
#  ('정은정', 'b26', 2),
#  ('flower', 'b26', 3),
#  ('H', 'b26', 5),
#  ('달님', 'b26', 5),
#  ('fff', 'b26', 5),
#  ('Utd_Batistuta', 'b26', 5),
#  ('김진우', 'b26', 5),
#  ('^^', 'f264', 1),
#  ('김초설', 'g184', 5),
#  ('빵가루', 'f1511', 5),
#  ('쎄쎄주인', 'f1511', 5),
#  ('영히', 'f1511', 5),
#  ('보리차', 'f1511', 5),
#  ('0', 'g514', 1),
#  ('괭이', 'g514', 1),
#  ('빈', 'g514', 2),
#  ('전미선', 'g514', 4),
#  ('박철홍 🗣곰돌이 👥', 'b19', 5),
#  ('M', 'b19', 1),
#  ('상엽', 'b19', 1),
#  ('😋', 'b19', 5),
#  ('Mr.Rhee', 'b19', 5),
#  ('강대형', 'b19', 3),
#  ('apple_00', 'b19', 4),
#  ('김레볼', 'b19', 5),
#  ('별맘', 'b19', 5),
#  ('정훈', 'b19', 5),
#  ('Anh Bình', 'b19', 5),
#  ('루루', 'b19', 5),
#  ('박봉옥(ㅇㅎㄹㄷㅇ~)', 'b19', 5),
#  ('Benjamin', 'b19', 5),
#  ('Mori-AN', 'f89', 5),
#  ('s링', 'f89', 5),
#  ('슛돌이', 'f89', 5),
#  ('리커버리', 'b253', 5),
#  ('맛집탐험가', 'g513', 4),
#  ('HEYBUE', 'g513', 5),
#  ('가양', 'e412', 5),
#  ('꾸', 'e412', 1),
#  ('달', 'e412', 1),
#  ('강지수', 'e412', 1),
#  ('호잇', 'e412', 5),
#  ('(...)', 'b21', 5),
#  ('시욱♡시헌 맘', 'b21', 5),
#  ('kh. k.s.', 'b21', 4),
#  ('정남선생', 'b21', 4),
#  ('키이라', 'b21', 5),
#  ('설문규', 'b21', 5),
#  ('국민짱지', 'b21', 1),
#  ('엉터리타자', 'c711', 5),
#  ('ansunjung', 'c711', 5),
#  ('므ㅏ', 'f263', 4),
#  ('렬이', 'f263', 4),
#  ('민이', 'f45', 5),
#  ('불만많은꿀꿀이', 'c147', 5),
#  ('s', 'c147', 5),
#  ('빼앰', 'g1314', 3),
#  ('보름달', 'a610', 4),
#  ('Woods', 'a610', 2),
#  ('우유', 'a610', 3),
#  ('뿌따따', 'a610', 1),
#  ('ㄱ. jeong', 'a610', 2),
#  ('PhLOx', 'c178', 4),
#  ('이정아', 'c178', 5),
#  ('강민구', 'c178', 5),
#  ('한동원', 'g141', 1),
#  ('김고은', 'f1712', 5),
#  ('맛집만 리뷰쓰는편', 'f1712', 5),
#  ('gogi', 'f1712', 4),
#  ('zzzini', 'f1712', 3),
#  ('밥맹이', 'f1712', 3),
#  ('.', 'f1712', 5),
#  ('문', 'f1712', 5),
#  ('Y', 'b291', 1),
#  ('Charming-Park', 'a414', 1),
#  ('~.~', 'f73', 2),
#  ('최윤영', 'f73', 5),
#  ('신유리', 'f73', 1),
#  ('배추김치', 'f73', 2),
#  ('열음', 'f255', 1),
#  ('💟', 'f255', 1),
#  ('alliwannado', 'f255', 1),
#  ('.', 'f255', 1),
#  ('고양이', 'f255', 5),
#  ('평점가', 'f255', 3),
#  ('용', 'b17', 5),
#  ('포티노', 'b17', 5),
#  ('윤혁', 'b17', 5),
#  ('밍터', 'b17', 2),
#  ('김찬호', 'b17', 5),
#  ('tkhsjr', 'b17', 4),
#  ('복슬복슬알파카', 'b17', 4),
#  ('nujay', 'b17', 3),
#  ('Lucida', 'b17', 4),
#  ('이승현_데이빗', 'b17', 5),
#  ('tkhsjr', 'b17', 4),
#  ('복슬복슬알파카', 'b17', 4),
#  ('nujay', 'b17', 3),
#  ('Lucida', 'b17', 4),
#  ('이승현_데이빗', 'b17', 5),
#  ('tkhsjr', 'b17', 4),
#  ('복슬복슬알파카', 'b17', 4),
#  ('nujay', 'b17', 3),
#  ('Lucida', 'b17', 4),
#  ('이승현_데이빗', 'b17', 5),
#  ('wow', 'b28', 5),
#  ('little prince', 'b28', 5),
#  ('언제나 맑음', 'b28', 5),
#  ('이하닮', 'b28', 5),
#  ('2020년 화이팅!', 'b28', 5),
#  ('방기영', 'b28', 4),
#  ("'핵, 토 파스칼 킥", 'b10', 5),
#  ('Chris', 'b10', 5),
#  ('ando.Kumiko(yossy)', 'b10', 4),
#  ('정남선생', 'b10', 4),
#  ('허승우', 'b10', 5),
#  ('준호☆James or Junho', 'b10', 5),
#  ('건우', 'b10', 5),
#  ('배슐랭', 'b10', 5),
#  ('웨인(kojjab)', 'b10', 3),
#  ('박도숙', 'b10', 5),
#  ('🙂', 'b10', 4),
#  ('주재용', 'b10', 5),
#  ('밍터', 'b10', 3),
#  ('이정준', 'b10', 4),
#  ('₌₃۶⁼³ 👉호😎이👈 ۶⁼³₌₃', 'b10', 5),
#  ('YUJIN', 'b10', 5),
#  ('효현동', 'b10', 4),
#  ('肇遠', 'b10', 4),
#  ('금경령', 'b10', 5),
#  ('2020년 화이팅!', 'b10', 5),
#  ('키이라', 'b10', 4),
#  ('黃芝麻 황참깨', 'b10', 4),
#  ('H', 'b10', 5),
#  ('김유훈', 'b10', 5),
#  ('김재경', 'b10', 5),
#  ('키이라', 'b10', 4),
#  ('黃芝麻 황참깨', 'b10', 4),
#  ('H', 'b10', 5),
#  ('김유훈', 'b10', 5),
#  ('김재경', 'b10', 5),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('복슬복슬알파카', 'b10', 4),
#  ('Benjamin', 'b10', 4),
#  ('MJay Ko 고 민정', 'b10', 4),
#  ('박서완', 'c512', 1),
#  ('카르르르', 'c512', 1),
#  ('백주', 'c512', 5),
#  ('🕵🏻\u200d♀️', 'c512', 5),
#  ('김태운', 'c512', 5),
#  ('고도리', 'c176', 1),
#  ('아리', 'c176', 3),
#  ('zzalex', 'c182', 1),
#  ('해정', 'c182', 1),
#  ('heybiblelee', 'c182', 1),
#  ('J.H', 'c182', 2),
#  ('MJay Ko 고 민정', 'c182', 3),
#  ('복슬복슬알파카', 'e611', 2),
#  ('강병권', 'g146', 3),
#  ('박지현', 'c149', 5),
#  ('matzipchaza', 'c149', 5),
#  ('구글맵', 'c149', 5),
#  ('나모', 'g317', 1),
#  ('.', 'f17', 5),
#  ('#', 'f17', 5),
#  ('도꼬', 'f231', 1),
#  ('안수민', 'f231', 5),
#  ('rlflqh', 'f231', 5),
#  ('츠츠3', 'f231', 5),
#  ('아르카타', 'f231', 5),
#  ('.', 'g1510', 1),
#  ('달군', 'g1510', 1),
#  ('Aiden', 'a810', 1),
#  ('김예리', 'b74', 5),
#  ('박진우', 'f10', 3),
#  ('yuta', 'd22', 2),
#  ('jh', 'c112', 4),
#  ('이혜진', 'c112', 1),
#  ('소우주', 'c112', 5),
#  ('뿅뿅', 'c112', 1),
#  ('손', 'e211', 4),
#  ('도민', 'e211', 4),
#  ('만두', 'e211', 3),
#  ('ㄱㅇㅅ', 'e211', 1),
#  ('Benjamin', 'b80', 4),
#  ('시영', 'f19', 5),
#  ('도서관', 'f19', 5),
#  ('도리', 'f19', 4),
#  ('kR', 'f19', 1),
#  ('ㅇㅈ', 'f1912', 5),
#  ('Sad', 'f1912', 1),
#  ('..', 'f1912', 1),
#  ('.', 'f1912', 1),
#  ('지영지', 'f26', 4),
#  ('쑤', 'f26', 5),
#  ('최송현', 'f26', 5),
#  ('감동하면 리뷰씀', 'f26', 5),
#  ('이진국', 'f26', 5),
#  ('K.G', 'f26', 5),
#  ('jsking', 'f26', 5),
#  ('정하연', 'f26', 4),
#  ('유창현', 'f26', 1),
#  ('☆홍염☆', 'f26', 1),
#  ('김재명', 'f26', 5),
#  ('JiN', 'f26', 5),
#  ('정자영', 'f26', 5),
#  ('2020년 화이팅!', 'b42', 5),
#  ('건우', 'b42', 5),
#  ('장은영', 'f200', 5),
#  ('임다은', 'f200', 5),
#  ('강 예동', 'f200', 5),
#  ('.', 'f200', 1),
#  ('콩이', 'f200', 2),
#  ('롤', 'g114', 5),
#  ('저 푸른 초원펭귄', 'g910', 5),
#  ('이승재', 'e811', 5),
#  ('하영', 'f238', 5),
#  ('깨끗한 물티슈', 'f238', 5),
#  ('.', 'f238', 5),
#  ('sSsay', 'f238', 5),
#  ('박현수', 'f238', 5),
#  ('송혁범', 'f238', 5),
#  ('하늘정원', 'f238', 5),
#  ('연주니', 'f238', 5),
#  ('젤리젤로', 'f238', 5),
#  ('Jasmine', 'f238', 5),
#  ('김원영', 'f238', 5),
#  ('신정민 비오', 'g113', 5),
#  ('러시아숲', 'b45', 1),
#  ('강연부', 'f207', 1),
#  ('하연', 'f207', 1),
#  ('잉왜또화내요', 'f207', 1),
#  ('딸기크림라떼', 'f207', 1),
#  ('노량진', 'f207', 1),
#  ('돌발소년', 'f207', 1),
#  ('오성환', 'a210', 1),
#  ('꾸웩', 'a210', 1),
#  ('신혜철', 'a210', 1),
#  ('your love is good to', 'a210', 1),
#  ('JUPITER', 'a210', 5),
#  ('인간은무엇으로사는가', 'c123', 5),
#  ('햄', 'd13', 1),
#  ('조현성', 'd13', 5),
#  ('이희원', 'f21', 1),
#  ('N지도피난민', 'f21', 5),
#  ('정예빈', 'f21', 5),
#  ('리커버리', 'b263', 5),
#  ('동휘맘', 'f81', 5),
#  ('공주', 'c183', 5),
#  ('밍', 'c183', 5),
#  ('ㅇㅇ', 'e610', 5),
#  ('냠냠냠', 'e610', 5),
#  ('wo', 'e610', 5),
#  ('ㅇㄷㅊ', 'e610', 1),
#  ('빵이조앙', 'f1714', 5),
#  ('vous', 'f1714', 3),
#  ('1', 'f1714', 2),
#  ('^-^', 'f1714', 5),
#  ('용드래곤', 'f1714', 5),
#  ('테이', 'c513', 5),
#  ('와인', 'c513', 5),
#  ('김수민', 'f253', 1),
#  ('...', 'f253', 1),
#  ('탱탱', 'b11', 5),
#  ('태영', 'b11', 5),
#  ('웨인(kojjab)', 'b11', 5),
#  ('양지연', 'b11', 3),
#  ('이영묵', 'b11', 4),
#  ('백여 종군', 'b11', 3),
#  ('석탄이아빠', 'b11', 5),
#  ('에이프릴', 'b11', 4),
#  ('소심한 물고기들', 'b11', 5),
#  ('볼륨매직', 'b11', 5),
#  ('Charming-Park', 'a412', 1),
#  ('DALDREAM', 'f75', 4),
#  ('프로혼밥러', 'c170', 1),
#  ('영인이', 'c170', 5),
#  ('호모루덴스', 'c170', 3),
#  ('-', 'c170', 3),
#  ('gmlsql99', 'c170', 1),
#  ('한다영', 'c170', 5),
#  ('♧히데뉨。', 'c170', 1),
#  ('내일은좋은일이생길거야', 'g1111', 4),
#  ('현선', 'f254', 2),
#  ('맛맛맛', 'f254', 2),
#  ('SSun.', 'f254', 4),
#  ('KITT', 'b16', 3),
#  ('wo', 'b16', 5),
#  ('롬', 'b16', 4),
#  ('ㅌㅇ', 'b16', 5),
#  ('크로스~^^', 'b16', 5),
#  ('박진우', 'b16', 5),
#  ('빠우', 'b16', 5),
#  ('ㅎㅅㅇ', 'b16', 4),
#  ('찌릿', 'b16', 1),
#  ('👀', 'b16', 4),
#  ('고독한 탐식가', 'b16', 3),
#  ('석우', 'b16', 5),
#  ('미락여행', 'b16', 5),
#  ('MJay Ko 고 민정', 'b16', 3),
#  ('김인규', 'b16', 3),
#  ('Charlie Jin', 'b16', 5),
#  ('규규', 'c514', 5),
#  ('Rsoe', 'c514', 1),
#  ('재이', 'f1713', 4),
#  ('존맛탱구리', 'f1713', 4),
#  ('Ms. Ssong', 'f1713', 3),
#  ('추운 베니', 'f1713', 3),
#  ('SSun.', 'f1713', 4),
#  ('Patrick', 'g140', 1),
#  ('신논현 네일한 나', 'c184', 5),
#  ('JL', 'c184', 1),
#  ('박광해', 'b2010', 5),
#  ('Trusta', 'b29', 3),
#  ('-----', 'b29', 5),
#  ('규빈', 'b29', 1),
#  ('marumongi', 'b29', 4),
#  ('ㅎ', 'b29', 1),
#  ('리커버리', 'b29', 5),
#  ('정기오', 'b29', 3),
#  ('최예나', 'b29', 5),
#  ('김석영', 'b29', 5),
#  ('김상동', 'b29', 3),
#  ('복슬복슬알파카', 'b29', 4),
#  ('MANGo', 'b29', 5),
#  ('혜진', 'g1912', 1),
#  ('쥴리', 'b20', 3),
#  ('유연우', 'b20', 5),
#  ('최규원', 'b20', 5),
#  ('jiaobaba', 'b20', 3),
#  ('오전필', 'b20', 5),
#  ('서슐랭', 'b20', 5),
#  ('개진철', 'b20', 5),
#  ('하성희', 'b20', 5),
#  ('김정심', 'b20', 4),
#  ('김재기(석수)', 'b20', 5),
#  ('조남범(효천)', 'b20', 5),
#  ('du_ub11', 'b20', 5),
#  ('윤정', 'b20', 5),
#  ('Kai', 'b20', 5),
#  ('ㅎㅅㅇ', 'b20', 2),
#  ('종워니(JW)', 'b20', 5),
#  ('장경순', 'b20', 5),
#  ('또또맘', 'b20', 4),
#  ('김정민', 'b20', 5),
#  ('🙂', 'b20', 5),
#  ('진실된 암행어사', 'b20', 5),
#  ('이창희', 'b20', 5),
#  ('윤선화', 'b20', 4),
#  ('미락여행', 'b20', 4),
#  ('웨인(kojjab)', 'b20', 5),
#  ('진실된 암행어사', 'b20', 5),
#  ('이창희', 'b20', 5),
#  ('윤선화', 'b20', 4),
#  ('미락여행', 'b20', 4),
#  ('웨인(kojjab)', 'b20', 5),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('Choi Dong Sik', 'b20', 4),
#  ('pH', 'b20', 4),
#  ('黃芝麻 황참깨', 'b20', 4),
#  ('오대석', 'b20', 5),
#  ('이근만', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('김귀성', 'b20', 4),
#  ('전주희', 'b20', 3),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('Choi Dong Sik', 'b20', 4),
#  ('pH', 'b20', 4),
#  ('黃芝麻 황참깨', 'b20', 4),
#  ('오대석', 'b20', 5),
#  ('이근만', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('김귀성', 'b20', 4),
#  ('전주희', 'b20', 3),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('Choi Dong Sik', 'b20', 4),
#  ('pH', 'b20', 4),
#  ('黃芝麻 황참깨', 'b20', 4),
#  ('오대석', 'b20', 5),
#  ('이근만', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('김귀성', 'b20', 4),
#  ('전주희', 'b20', 3),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('Choi Dong Sik', 'b20', 4),
#  ('pH', 'b20', 4),
#  ('黃芝麻 황참깨', 'b20', 4),
#  ('오대석', 'b20', 5),
#  ('이근만', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('김귀성', 'b20', 4),
#  ('전주희', 'b20', 3),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('Choi Dong Sik', 'b20', 4),
#  ('pH', 'b20', 4),
#  ('黃芝麻 황참깨', 'b20', 4),
#  ('오대석', 'b20', 5),
#  ('이근만', 'b20', 4),
#  ('박민지', 'b20', 3),
#  ('설문규', 'b20', 5),
#  ('김귀성', 'b20', 4),
#  ('전주희', 'b20', 3),
#  ('sbchoi', 'b20', 5),
#  ('밍터', 'b20', 4),
#  ('Sangmo', 'b20', 3),
#  ('KB이근미', 'b20', 4),
#  ('최홍기', 'b20', 4),
#  ('건담이말을건담', 'f262', 5),
#  ('신이나', 'f262', 4),
#  ('강승은', 'f262', 4),
#  ('구름', 'f262', 4),
#  ('손오공', 'f262', 3),
#  ('멋진Joe', 'c710', 5),
#  ('멋진Joe', 'c710', 5),
#  ('재맹', 'g182', 1),
#  ('제야', 'a611', 1),
#  ('원 호', 'a611', 4),
#  ('레오폴드', 'a611', 1),
#  ('김형규', 'a611', 1),
#  ('용가리', 'a611', 1),
#  ('윤찬우', 'a611', 1),
#  ('여기별로', 'a611', 1),
#  ('zzzz', 'a611', 5),
#  ('두바쿠', 'a611', 5),
#  ('☘', 'e413', 5),
#  ('송명엽', 'e413', 5),
#  ('김근수', 'e413', 1),
#  ('나', 'e413', 1),
#  ('정재원', 'e413', 1),
#  ('ㅇㅎ', 'c179', 3),
#  ('서동현', 'c179', 2),
#  ('LJ', 'c179', 5),
#  ('Begbie', 'c179', 1),
#  ('elly', 'c179', 2),
#  ('영효닝~♥', 'f1510', 5),
#  ('VEnomonEY', 'f1510', 2),
#  ('또롱또로롱', 'e414', 5),
#  ('차의현', 'f43', 5),
#  ('출발', 'f43', 5),
#  ('수민', 'f43', 5),
#  ('별밤', 'f43', 5),
#  ('송영철', 'g185', 5),
#  ('돌아다님', 'g185', 4),
#  ('농노3', 'b27', 5),
#  ('박인우', 'b27', 1),
#  ('wow', 'b27', 5),
#  ('건우', 'b27', 3),
#  ('ksh', 'b27', 5),
#  ('Hyun', 'f265', 1),
#  ('이찬', 'g3213', 1),
#  ('츄', 'b18', 5),
#  ('wow', 'b18', 5),
#  ('tjqlfkqslwk', 'b18', 2),
#  ('김준성', 'b18', 5),
#  ('댕댕진', 'b18', 5),
#  ('랜턴', 'b18', 4),
#  ('ㅎㅅㅇ', 'b18', 4),
#  ('준호☆James or Junho', 'b18', 5),
#  ('유한영 예은수민맘', 'b18', 5),
#  ('정하연', 'b18', 5),
#  ('랜턴', 'b18', 4),
#  ('ㅎㅅㅇ', 'b18', 4),
#  ('준호☆James or Junho', 'b18', 5),
#  ('유한영 예은수민맘', 'b18', 5),
#  ('정하연', 'b18', 5),
#  ('재명', 'b18', 5),
#  ('JB', 'b18', 5),
#  ('김재경', 'b18', 3),
#  ('박민지', 'b18', 3),
#  ('석우', 'b18', 5),
#  ('김관중(KwanJoong Kim)', 'b18', 2),
#  ('💋승권sk짱💋', 'b18', 5),
#  ('MJay Ko 고 민정', 'b18', 3),
#  ('김관중(KwanJoong Kim)', 'b18', 2),
#  ('💋승권sk짱💋', 'b18', 5),
#  ('MJay Ko 고 민정', 'b18', 3),
#  ('공주', 'f2213', 5),
#  ('밍', 'f2213', 5),
#  ('원 호', 'a67', 4),
#  ('레오폴드', 'a67', 1),
#  ('김형규', 'a67', 1),
#  ('용가리', 'a67', 1),
#  ('정성영 Paul', 'a67', 3),
#  ('여기별로', 'a67', 1),
#  ('zzzz', 'a67', 5),
#  ('두바쿠', 'a67', 5),
#  ('Ss', 'c55', 1),
#  ('정원석', 'c55', 1),
#  ('윤지상', 'c55', 5),
#  ('최승희', 'g31', 4),
#  ('강희진', 'b1510', 5),
#  ('이채영', 'a93', 1),
#  ('이창렬', 'a93', 1),
#  ('.', 'a93', 1),
#  ('sUNg jONg gEUn', 'b911', 5),
#  ('박정재', 'b911', 5),
#  ('임종민', 'b911', 5),
#  ('김치볶음밥', 'c99', 5),
#  ('박진영', 'c99', 5),
#  ('Su', 'c99', 5),
#  ('해나', 'c99', 5),
#  ('민영', 'c99', 5),
#  ('냐냐', 'b112', 5),
#  ('누리는💓', 'b112', 5),
#  ('북북이', 'b112', 5),
#  ('이지혜', 'b112', 5),
#  ('정남선생', 'b112', 4),
#  ('유령작가', 'e105', 5),
#  ('hs🌴', 'b320', 5),
#  ('Lo샷ve', 'd211', 5),
#  ('김강봉', 'c52', 5),
#  ('‼️', 'c52', 5),
#  ('Kong', 'c52', 5),
#  ('데이지', 'c52', 3),
#  ('빼앰', 'f310', 5),
#  ('MAY', 'f310', 5),
#  ('크크크', 'f310', 5),
#  ('다다다', 'f2214', 2),
#  ('자양주민', 'f2214', 1),
#  ('믱', 'f2214', 1),
#  ('안경국', 'f2214', 5),
#  ('하람이', 'a60', 5),
#  ('신영종', 'a60', 3),
#  ('초밥좋아요', 'a60', 1),
#  ('ssoo', 'a60', 1),
#  ('솔아솔아', 'a60', 4),
#  ('김장환', 'b329', 5),
#  ('박영선', 'a69', 5),
#  ('전설', 'a69', 4),
#  ('ludo', 'a69', 1),
#  ('에이맨', 'a69', 1),
#  ('김건우', 'a69', 1),
#  ('ssuu', 'a69', 1),
#  ('seri414', 'a69', 1),
#  ('Lindsay.Lim.Michaela', 'g200', 5),
#  ('B', 'f2010', 1),
#  ('도영상', 'c64', 5),
#  ('정영옥', 'c64', 5),
#  ('아하', 'a56', 5),
#  ('빅토리아', 'a56', 5),
#  ('괭이', 'f114', 2),
#  ('희정', 'f114', 1),
#  ('이원석', 'f114', 1),
#  ('나며누기', 'e32', 1),
#  ('ㅋㅋㅋㅋ', 'e32', 1),
#  ('토리', 'e32', 2),
#  ('누렁', 'e32', 2),
#  ('제점수는요', 'g38', 5),
#  ('현민', 'g38', 3),
#  ('이오', 'g238', 1),
#  ('루루', 'g238', 1),
#  ('소풍', 'g238', 1),
#  ('MJay Ko 고 민정', 'b1714', 4),
#  ('상우', 'e35', 1),
#  ('혁신을 통한 지속성장!!!', 'e35', 5),
#  ('건담이말을건담', 'e35', 4),
#  ('always', 'e35', 1),
#  ('lotkyu', 'e35', 4),
#  ('Stanislav', 'a51', 5),
#  ('드미트리', 'a51', 5),
#  ('양형열', 'a51', 5),
#  ('여조로', 'f113', 5),
#  ('얏호', 'c63', 5),
#  ('민수', 'c63', 5),
#  ('오성환', 'a104', 1),
#  ('비얌', 'c97', 5),
#  ('카페메니아', 'c97', 2),
#  ('스카이라피스', 'c97', 5),
#  ('이상목', 'b311', 3),
#  ('바람과 나', 'b183', 5),
#  ('나', 'b183', 5),
#  ('lune', 'g53', 1),
#  ('Andy', 'f711', 3),
#  ('엽떡은 신당점', 'f711', 5),
#  ('이유리', 'c37', 5),
#  ('nuny', 'f147', 1),
#  ('이지', 'f147', 4),
#  ('愼其獨 로봇군단진재민ZINJAEMIN', 'f147', 5),
#  ('노랑', 'f147', 5),
#  ('복슬복슬알파카', 'f147', 3),
#  ('익명의 사람', 'g253', 2),
#  ('원국', 'g253', 3),
#  ('유혜빈', 'b513', 5),
#  ('hj', 'c1714', 3),
#  ('옴뇸뇸 :)', 'c1714', 5),
#  ('쥬잉', 'c1714', 5),
#  ('유령작가', 'e95', 5),
#  ('박시현', 'f178', 5),
#  ('귤', 'f178', 1),
#  ('젼', 'f178', 5),
#  ('김남호', 'g98', 5),
#  ('ㄹㅇ솔직평가', 'g98', 1),
#  ('정윤지', 'c1713', 5),
#  ('열애사진', 'b514', 5),
#  ('나은', 'e66', 5),
#  ('박수민', 'f2612', 5),
#  ('이해준', 'f2612', 5),
#  ('김태훈', 'f2612', 5),
#  ('jk Han', 'f2612', 5),
#  ('익명', 'e59', 1),
#  ('익명', 'e59', 5),
#  ('장꼭또', 'e59', 5),
#  ('박재만', 'e59', 5),
#  ('Minhyung', 'b1912', 5),
#  ('A', 'f182', 5),
#  ('박병연', 'f182', 1),
#  ('논리와팩트', 'f182', 1),
#  ('핑슐랭가이드', 'f182', 3),
#  ('kfc매니아', 'f182', 2),
#  ('ㄷㄹ', 'g96', 5),
#  ('솔', 'a1110', 1),
#  ('t', 'b146', 5),
#  ('JYK용선생', 'b146', 5),
#  ('마곡사랑08', 'b146', 5),
#  ('(율준♡)', 'g62', 1),
#  ('J', 'f512', 4),
#  ('장현', 'f512', 5),
#  ('박찬빈', 'f512', 1),
#  ('막가롱', 'f512', 2),
#  ('손혜린', 'f512', 5),
#  ('깅가라미', 'a34', 1),
#  ('deuxistt!!', 'a34', 2),
#  ('균면성실', 'a34', 1),
#  ('김남천', 'a34', 1),
#  ('제훈', 'a34', 1),
#  ('냠냠이', 'f176', 3),
#  ('eww', 'f176', 2),
#  ('j', 'f176', 2),
#  ('p', 'f176', 3),
#  ('냉철하게판단', 'f176', 4),
#  ('ㅋㅋㅋㅋ', 'g296', 5),
#  ('지원', 'b179', 5),
#  ('박병영', 'b179', 5),
#  ('소영', 'f149', 1),
#  ('냠냠이', 'f149', 4),
#  ('민정', 'f149', 5),
#  ('정인선', 'f149', 1),
#  ('내삶의술', 'f149', 5),
#  ('암바사', 'f149', 5),
#  ('꿀돌순이', 'f149', 5),
#  ('이경윤', 'f149', 5),
#  ('정유철', 'f149', 5),
#  ('미쉘', 'f149', 5),
#  ('불량주부', 'f149', 5),
#  ('김주영', 'b1312', 5),
#  ('아무개', 'a33', 2),
#  ('ㅇㅇ', 'f171', 5),
#  ('냉평', 'f171', 3),
#  ('FRW', 'f171', 2),
#  ('맛박사', 'f171', 5),
#  ('옴뇸뇸', 'f171', 5),
#  ('Jina', 'e57', 1),
#  ('숮2🍑', 'e57', 4),
#  ('흥칫', 'e57', 1),
#  ('임보람', 'e57', 5),
#  ('ㅇㅅㅇ', 'e57', 1),
#  ('라미', 'c1510', 5),
#  ('손', 'f185', 4),
#  ('도민', 'f185', 4),
#  ('만두', 'f185', 3),
#  ('ㄱㅇㅅ', 'f185', 1),
#  ('.', 'e68', 5),
#  ('태', 'e68', 1),
#  ('JkeM', 'e68', 5),
#  ('와사비까까', 'e68', 5),
#  ('랍스얍스', 'e68', 5),
#  ('허스키', 'g239', 1),
#  ('.', 'g39', 1),
#  ('아스라', 'g39', 5),
#  ('맛도사', 'g39', 1),
#  ('이름입력', 'g206', 4),
#  ('Marcellina', 'b122', 5),
#  ('현지훈', 'b310', 4),
#  ('ssong', 'b310', 5),
#  ('하루글라라', 'b310', 5),
#  ('인서아빠', 'b310', 5),
#  ('ㆍ', 'b310', 4),
#  ('폴인럽', 'e34', 5),
#  ('완사', 'e34', 5),
#  ('김동현', 'e34', 5),
#  ('방랑식객', 'e34', 5),
#  ('크림픽시', 'e34', 5),
#  ('장현', 'e34', 4),
#  ('.', 'e34', 2),
#  ('J', 'e34', 2),
#  ('드라프', 'e34', 5),
#  ('드라프', 'e34', 5),
#  ('kk345', 'e34', 5),
#  ('정무진', 'c62', 1),
#  ('봉쥬르', 'c62', 4),
#  ('Jason (양재훈)', 'c62', 5),
#  ('이반', 'c62', 1),
#  ('전정우', 'c62', 1),
#  ('이상훈', 'a105', 1),
#  ('하람이', 'a50', 5),
#  ('신영종', 'a50', 3),
#  ('초밥좋아요', 'a50', 1),
#  ('ssoo', 'a50', 1),
#  ('솔아솔아', 'a50', 4),
#  ('🙂', 'f112', 5),
#  ('원 호', 'a57', 4),
#  ('레오폴드', 'a57', 1),
#  ('김형규', 'a57', 1),
#  ('용가리', 'a57', 1),
#  ('정성영 Paul', 'a57', 3),
#  ('여기별로', 'a57', 1),
#  ('zzzz', 'a57', 5),
#  ('두바쿠', 'a57', 5),
#  ('이상훈', 'a102', 1),
#  ('김예림', 'f2011', 3),
#  ('희', 'f2011', 5),
#  ('이딴곳때문에로그인함', 'e33', 1),
#  ('정성수', 'g201', 5),
#  ('해진', 'c1110', 5),
#  ('호로록', 'c1110', 5),
#  ('ㅇㅅㅇ', 'c1110', 5),
#  ('.', 'c1110', 5),
#  ('시나비바', 'c1110', 1),
#  ('미니', 'c91', 5),
#  ('왕谕远', 'b910', 5),
#  ('기무지노상', 'g37', 2),
#  ('김태수', 'g37', 5),
#  ('박진우', 'd210', 4),
#  ('09_행정_승현', 'd210', 1),
#  ('Stanislav', 'a61', 5),
#  ('드미트리', 'a61', 5),
#  ('양형열', 'a61', 5),
#  ('황정태', 'c53', 5),
#  ('별', 'f311', 5),
#  ('ㅇ', 'f311', 5),
#  ('밍', 'a95', 5),
#  ('아이스크림', 'a95', 5),
#  ('먹방여행*^^*~~', 'a95', 5),
#  ('김건우', 'e104', 1),
#  ('Harin Harry Lee', 'e104', 2),
#  ('김대현', 'e104', 2),
#  ('자전거탄풍경', 'e104', 5),
#  ('영남', 'b321', 5),
#  ('유홍재', 'b113', 4),
#  ('뽄나', 'b113', 5),
#  ('MJay Ko 고 민정', 'b113', 3),
#  ('카카오러', 'b113', 2),
#  ('고카소', 'b113', 3),
#  ('박영선', 'a59', 5),
#  ('전설', 'a59', 4),
#  ('ludo', 'a59', 1),
#  ('에이맨', 'a59', 1),
#  ('김건우', 'a59', 1),
#  ('ssuu', 'a59', 1),
#  ('seri414', 'a59', 1),
#  ('이경준 Black', 'b114', 5),
#  ('다섯', 'e103', 3),
#  ('임관혁', 'e103', 5),
#  ('주연', 'e103', 5),
#  ('제롱', 'a92', 1),
#  ('하루', 'a92', 5),
#  ('lolyiu', 'a92', 1),
#  ('Jjojo', 'c54', 4),
#  ('.', 'c54', 1),
#  ('쥬잉', 'c54', 1),
#  ('Rom', 'c54', 1),
#  ('jj', 'c54', 5),
#  ('아하', 'a66', 5),
#  ('빅토리아', 'a66', 5),
#  ('김복순', 'f2212', 1),
#  ('양나영', 'f2212', 1),
#  ('박준렬', 'f2212', 1),
#  ('웹토리', 'b1511', 4),
#  ('펭수러버', 'g30', 1),
#  ('🙈', 'g30', 2),
#  ('김상영', 'c1511', 5),
#  ('duri', 'c1511', 5),
#  ('nanana', 'c1511', 5),
#  ('장승우', 'g90', 1),
#  ('김지원', 'g90', 5),
#  ('조성빈', 'g90', 5),
#  ('쏘다', 'f184', 5),
#  ('황인용', 'f184', 1),
#  ('단속반', 'f184', 1),
#  ('yeah', 'f184', 1),
#  ('박재용', 'f184', 3),
#  ('illusion', 'f184', 1),
#  ('성재', 'f184', 1),
#  ('복슬복슬알파카', 'f184', 5),
#  ('뭔들', 'f184', 2),
#  ('shine', 'a32', 1),
#  ('bcjhd', 'a32', 5),
#  ('정옥균', 'a32', 5),
#  ('cmtk', 'a32', 5),
#  ('뀰', 'f170', 1),
#  ('네오', 'f170', 1),
#  ('rot', 'f170', 1),
#  ('효기', 'f170', 4),
#  ('이유진', 'f170', 2),
#  ('Jun', 'f170', 3),
#  ('ㅇㅍㄱ', 'f170', 1),
#  ('JH', 'f170', 3),
#  ('최정규(Jaykay)', 'f170', 4),
#  ('정남선생', 'f170', 3),
#  ('SJWi', 'f170', 4),
#  ('유준명', 'f170', 4),
#  ('원미', 'f170', 4),
#  ('MoMo', 'f2410', 5),
#  ('박호용', 'g64', 5),
#  ('작지', 'e56', 5),
#  ('아이유', 'e56', 5),
#  ('somsa', 'e56', 5),
#  ('Google', 'e56', 5),
#  ('에스프레소&크림', 'e56', 5),
#  ('Ги Хён чхье', 'f514', 1),
#  ('Th', 'f514', 1),
#  ('김계승', 'f514', 1),
#  ('최정삼 designw', 'f514', 5),
#  ('최귀남', 'f514', 5),
#  ('세느', 'e69', 5),
#  ('익명', 'e69', 5),
#  ('쥐', 'e69', 5),
#  ('은빛여우', 'e69', 5),
#  ('오병진', 'e69', 5),
#  ('S', 'f513', 5),
#  ('댕댕이', 'f513', 5),
#  ('hs', 'f513', 5),
#  ('황다원', 'f513', 5),
#  ('폭시폭시베이베', 'f513', 1),
#  ...]

# %%
import cornac
from cornac.eval_methods import RatioSplit


# Load the Amazon Clothing  dataset, and binarise ratings using cornac.data.Reader
feedback = ls

# Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=feedback,
    test_size=0.2,
    rating_threshold=1.0,
    seed=123,
    exclude_unknowns=True,
    verbose=True,
)

# Instantiate the recommender models to be compared
# gmf = cornac.models.GMF(
#     num_factors=8,
#     num_epochs=10,
#     learner="adam",
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
# )
# mlp = cornac.models.MLP(
#     layers=[64, 32, 16, 8],
#     act_fn="tanh",
#     learner="adam",
#     num_epochs=10,
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
# )

neumf1 = cornac.models.NeuMF(
    num_factors=4,
    layers=[32,16,8,4],
    act_fn="tanh",
    learner="adam",
    num_epochs=10,
    batch_size=256,
    lr=1e-3,
    num_neg=50,
    seed=123,
)
# neumf2 = cornac.models.NeuMF(
#     name="NeuMF_pretrained",
#     learner="adam",
#     num_epochs=10,
#     batch_size=256,
#     lr=0.001,
#     num_neg=50,
#     seed=123,
#     num_factors=gmf.num_factors,
#     layers=mlp.layers,
#     act_fn=mlp.act_fn,
# ).pretrain(gmf, mlp)

# Instantiate evaluation metrics
ndcg_10 = cornac.metrics.NDCG(k=10)
pre_10 = cornac.metrics.Precision(k=10)
rec_10 = cornac.metrics.Recall(k=10)
f_10 = cornac.metrics.FMeasure(k=10)

# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf1],
    metrics=[ndcg_10,pre_10, rec_10, f_10],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 18362
# Number of items = 1428
# Number of ratings = 48705
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 4.2
# ---
# Test data:
# Number of users = 5345
# Number of items = 563
# Number of ratings = 9738
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 18362
# Total items = 1428
#
# [NeuMF] Training started!
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 741 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages/cornac/data/dataset.py:361: UserWarning: 52 duplicated observations are removed!
#   warnings.warn("%d duplicated observations are removed!" % dup_count)
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# [NeuMF] Evaluation started!
# HBox(children=(FloatProgress(value=0.0, description='Ranking', max=5345.0, style=ProgressStyle(description_wid…
# TEST:
# ...
#       |  F1@10 | NDCG@10 | Precision@10 | Recall@10 | Train (s) | Test (s)
# ----- + ------ + ------- + ------------ + --------- + --------- + --------
# NeuMF | 0.0939 |  0.1899 |       0.0580 |    0.3513 |  681.6755 |   5.7344

# %%
a = pd.DataFrame(neumf1.rank(1)).T

# %%
a.to_csv('../data/exxxx')

# %%
from keras.models import load_model

neumf1.save('neumf1.h5')
# Out:
# NeuMF model is saved to neumf1.h5/NeuMF/2020-06-12_16-27-40-024934.pkl
# Using TensorFlow backend.
# 'neumf1.h5/NeuMF/2020-06-12_16-27-40-024934.pkl'

# %%
pip install keras
# Out:
# Collecting keras
#   Using cached Keras-2.3.1-py2.py3-none-any.whl (377 kB)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (1.18.1)
# Requirement already satisfied: h5py in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (1.1.2)
# Requirement already satisfied: pyyaml in /Users/ryeonju/miniconda3/envs/reco_base/lib/python3.6/site-packages (from keras) (5.3.1)
# Installing collected packages: keras
# Successfully installed keras-2.3.1
# Note: you may need to restart the kernel to use updated packages.
