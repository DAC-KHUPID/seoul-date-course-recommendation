# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cornac
from cornac.eval_methods import RatioSplit
from cornac.hyperopt import Continuous, Discrete, RandomSearch
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 추천할 top k개의 장소
TOP_K = 10

# %%
data_df = pd.read_csv('../data/score_board.csv')

# %%
data_df
# Out:
#                u_id  p_id rating
# 0                *2   121    4.5
# 1          -채여니영화평-   287    4.0
# 2          -채여니영화평-   414    3.5
# 3          -채여니영화평-   271    3.5
# 4          -채여니영화평-   264    5.0
# 5          -채여니영화평-   606    3.5
# 6          -채여니영화평-   262    3.5
# 7          -채여니영화평-   526    5.0
# 8          -채여니영화평-    45    4.0
# 9          -채여니영화평-   255    5.0
# 10         -채여니영화평-   250    4.5
# 11         -채여니영화평-    37    4.5
# 12         -채여니영화평-   645    3.0
# 13         -채여니영화평-   248    4.5
# 14         -채여니영화평-   239    3.5
# 15         -채여니영화평-    49    3.5
# 16         -채여니영화평-   236    3.5
# 17         -채여니영화평-   643    5.0
# 18         -채여니영화평-   234    3.5
# 19         -채여니영화평-   540    2.0
# 20         -채여니영화평-   543    5.0
# 21         -채여니영화평-   227    3.0
# 22         -채여니영화평-    53    3.5
# 23         -채여니영화평-    82    3.5
# 24         -채여니영화평-   223    4.0
# 25         -채여니영화평-   295    3.5
# 26         -채여니영화평-    35    3.5
# 27         -채여니영화평-   405    3.5
# 28         -채여니영화평-   404    4.5
# 29         -채여니영화평-   619    4.0
# ...             ...   ...    ...
# 29768        euni77   166    NaN
# 29769        euni77   150    NaN
# 29770        euni77    45    NaN
# 29771        euni77    22    NaN
# 29772  irene96jeong   286    NaN
# 29773  irene96jeong   262    NaN
# 29774  irene96jeong   221    NaN
# 29775  irene96jeong   182    NaN
# 29776  irene96jeong   178    NaN
# 29777  irene96jeong   166    NaN
# 29778  irene96jeong   150    NaN
# 29779  irene96jeong   125    NaN
# 29780          Koot   286    NaN
# 29781          Koot   262    NaN
# 29782          Koot   166    NaN
# 29783          Koot   150    NaN
# 29784          Koot   125    NaN
# 29785          Koot    45    NaN
# 29786          Koot    22    NaN
# 29787          Koot    13    NaN
# 29788          Koot    12    NaN
# 29789    2019100861   166    NaN
# 29790    2019100861   150    NaN
# 29791       Uynibus   286    NaN
# 29792       Uynibus    13    NaN
# 29793      dpwls258   286    NaN
# 29794             쥬   286    NaN
# 29795             쥬   205    NaN
# 29796             쥬   166    NaN
# 29797             쥬   150    NaN
#
# [29798 rows x 3 columns]

# %%
data_df['rating'].value_counts()
# Out:
# 4.0      6287
# 3.5      5430
# 3.0      4748
# 5.0      3055
# 4.5      2846
# 2.5      2555
# 2.0      2150
# 1.5       896
# 1.0       855
# 0.5       738
# 보고싶어요     121
# 보는중         2
# Name: rating, dtype: int64

# %%
data_df = data_df[data_df['rating']!='보고싶어요']
data_df = data_df[data_df['rating']!='보는중']
data_df['rating'] = data_df['rating'].astype('float')
data_df = data_df.rename({'u_id':'userID','p_id':'itemID'},axis=1)
data_df = data_df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
data_df = data_df.fillna(5)

# %%
data = [tuple(x) for x in data_df.values]
data
# Out:
# [('-채여니영화평-', 287, 4.0),
#  ('-채여니영화평-', 414, 3.5),
#  ('-채여니영화평-', 271, 3.5),
#  ('-채여니영화평-', 264, 5.0),
#  ('-채여니영화평-', 606, 3.5),
#  ('-채여니영화평-', 262, 3.5),
#  ('-채여니영화평-', 526, 5.0),
#  ('-채여니영화평-', 45, 4.0),
#  ('-채여니영화평-', 255, 5.0),
#  ('-채여니영화평-', 250, 4.5),
#  ('-채여니영화평-', 37, 4.5),
#  ('-채여니영화평-', 645, 3.0),
#  ('-채여니영화평-', 248, 4.5),
#  ('-채여니영화평-', 239, 3.5),
#  ('-채여니영화평-', 49, 3.5),
#  ('-채여니영화평-', 236, 3.5),
#  ('-채여니영화평-', 643, 5.0),
#  ('-채여니영화평-', 234, 3.5),
#  ('-채여니영화평-', 540, 2.0),
#  ('-채여니영화평-', 543, 5.0),
#  ('-채여니영화평-', 227, 3.0),
#  ('-채여니영화평-', 53, 3.5),
#  ('-채여니영화평-', 82, 3.5),
#  ('-채여니영화평-', 223, 4.0),
#  ('-채여니영화평-', 295, 3.5),
#  ('-채여니영화평-', 35, 3.5),
#  ('-채여니영화평-', 405, 3.5),
#  ('-채여니영화평-', 404, 4.5),
#  ('-채여니영화평-', 619, 4.0),
#  ('-채여니영화평-', 455, 4.0),
#  ('-채여니영화평-', 456, 3.5),
#  ('-채여니영화평-', 98, 4.5),
#  ('-채여니영화평-', 462, 2.5),
#  ('-채여니영화평-', 616, 3.0),
#  ('-채여니영화평-', 615, 5.0),
#  ('-채여니영화평-', 477, 3.0),
#  ('-채여니영화평-', 651, 2.0),
#  ('-채여니영화평-', 22, 3.5),
#  ('-채여니영화평-', 614, 3.5),
#  ('-채여니영화평-', 329, 4.0),
#  ('-채여니영화평-', 492, 3.5),
#  ('-채여니영화평-', 324, 5.0),
#  ('-채여니영화평-', 320, 4.0),
#  ('-채여니영화평-', 612, 4.0),
#  ('-채여니영화평-', 318, 4.0),
#  ('-채여니영화평-', 625, 5.0),
#  ('-채여니영화평-', 653, 4.5),
#  ('-채여니영화평-', 113, 3.5),
#  ('-채여니영화평-', 481, 4.0),
#  ('-채여니영화평-', 222, 4.0),
#  ('-채여니영화평-', 415, 3.5),
#  ('-채여니영화평-', 197, 4.0),
#  ('-채여니영화평-', 601, 4.0),
#  ('-채여니영화평-', 599, 3.5),
#  ('-채여니영화평-', 220, 4.0),
#  ('-채여니영화평-', 67, 4.5),
#  ('-채여니영화평-', 211, 4.0),
#  ('-채여니영화평-', 597, 3.5),
#  ('-채여니영화평-', 214, 5.0),
#  ('-채여니영화평-', 568, 2.0),
#  ('-채여니영화평-', 56, 4.5),
#  ('-채여니영화평-', 430, 3.5),
#  ('-채여니영화평-', 594, 3.5),
#  ('-채여니영화평-', 207, 3.5),
#  ('11', 578, 2.5),
#  ('11', 356, 1.0),
#  ('11', 667, 1.5),
#  ('11', 502, 0.5),
#  ('11', 569, 4.0),
#  ('11', 389, 3.0),
#  ('11', 391, 4.0),
#  ('11', 520, 1.5),
#  ('11', 398, 0.5),
#  ('11', 332, 1.5),
#  ('11', 574, 0.5),
#  ('11', 204, 0.5),
#  ('11', 645, 1.5),
#  ('A24', 382, 3.5),
#  ('A24', 490, 4.5),
#  ('A24', 577, 3.0),
#  ('A24', 224, 3.5),
#  ('A24', 322, 3.5),
#  ('A24', 473, 3.5),
#  ('A24', 472, 5.0),
#  ('A24', 569, 4.0),
#  ('A24', 549, 3.0),
#  ('A24', 511, 2.5),
#  ('A24', 554, 2.5),
#  ('A24', 367, 4.0),
#  ('A24', 465, 2.0),
#  ('A24', 336, 3.0),
#  ('A24', 6, 2.0),
#  ('A24', 540, 4.0),
#  ('A24', 664, 4.0),
#  ('A24', 151, 3.0),
#  ('A24', 581, 3.0),
#  ('A24', 456, 2.0),
#  ('A24', 617, 2.5),
#  ('A24', 435, 2.5),
#  ('A24', 484, 4.0),
#  ('A24', 349, 3.5),
#  ('Aeri', 268, 3.5),
#  ('Aeri', 251, 4.0),
#  ('Aeri', 72, 4.5),
#  ('Aeri', 160, 3.0),
#  ('Aeri', 259, 5.0),
#  ('Aeri', 207, 4.0),
#  ('Aeri', 277, 4.0),
#  ('Aeri', 77, 4.0),
#  ('Aeri', 292, 5.0),
#  ('Aeri', 230, 3.5),
#  ('Aeri', 229, 4.5),
#  ('Aeri', 147, 3.5),
#  ('Aeri', 106, 4.5),
#  ('Aeri', 225, 4.5),
#  ('Aeri', 97, 3.5),
#  ('Aeri', 89, 4.0),
#  ('Aeri', 145, 3.5),
#  ('Aeri', 177, 5.0),
#  ('Arcturus', 396, 4.0),
#  ('Arcturus', 646, 3.0),
#  ('Arcturus', 537, 4.0),
#  ('Arcturus', 153, 4.5),
#  ('Arcturus', 134, 5.0),
#  ('Arcturus', 553, 4.0),
#  ('Arcturus', 390, 4.0),
#  ('Arcturus', 318, 4.5),
#  ('Arcturus', 206, 4.5),
#  ('Arcturus', 215, 4.5),
#  ('Arcturus', 410, 4.0),
#  ('Arcturus', 400, 1.0),
#  ('Arcturus', 450, 2.5),
#  ('Arcturus', 350, 4.0),
#  ('Arcturus', 630, 3.0),
#  ('Arcturus', 275, 1.0),
#  ('Arcturus', 207, 4.0),
#  ('Arcturus', 269, 4.0),
#  ('Arcturus', 547, 4.0),
#  ('Arcturus', 171, 4.5),
#  ('Arcturus', 645, 3.5),
#  ('Arcturus', 427, 3.0),
#  ('Arcturus', 326, 5.0),
#  ('Arcturus', 312, 2.5),
#  ('Arcturus', 616, 4.0),
#  ('Arcturus', 600, 3.5),
#  ('AyoungAlice', 460, 4.5),
#  ('AyoungAlice', 667, 4.5),
#  ('AyoungAlice', 404, 3.5),
#  ('AyoungAlice', 414, 4.5),
#  ('AyoungAlice', 651, 0.5),
#  ('AyoungAlice', 601, 4.5),
#  ('AyoungAlice', 430, 4.0),
#  ('AyoungAlice', 584, 0.5),
#  ('AyoungAlice', 254, 2.0),
#  ('AyoungAlice', 606, 3.0),
#  ('BHW', 595, 2.0),
#  ('BHW', 12, 3.0),
#  ('BHW', 1, 2.0),
#  ('BHW', 451, 3.5),
#  ('BHW', 199, 3.0),
#  ('BHW', 154, 2.0),
#  ('BHW', 66, 3.0),
#  ('BHW', 483, 3.0),
#  ('BHW', 431, 3.5),
#  ('BHW', 587, 2.5),
#  ('BHW', 363, 2.5),
#  ('BHW', 4, 3.5),
#  ('BeNeo', 454, 4.0),
#  ('BeNeo', 654, 1.0),
#  ('BeNeo', 390, 4.5),
#  ('BeNeo', 279, 3.5),
#  ('BeNeo', 413, 1.0),
#  ('BeNeo', 589, 4.0),
#  ('BeNeo', 207, 2.0),
#  ('BeNeo', 342, 5.0),
#  ('BeNeo', 212, 2.0),
#  ('BeNeo', 611, 4.0),
#  ('BeNeo', 312, 3.0),
#  ('BeNeo', 432, 3.5),
#  ('BeNeo', 503, 2.5),
#  ('BeNeo', 398, 2.5),
#  ('BeNeo', 586, 5.0),
#  ('BeNeo', 610, 2.5),
#  ('BeNeo', 556, 3.0),
#  ('BeNeo', 431, 2.5),
#  ('BeNeo', 564, 4.5),
#  ('BeNeo', 270, 3.5),
#  ('BeNeo', 294, 4.5),
#  ('BeNeo', 319, 3.5),
#  ('BeNeo', 593, 0.5),
#  ('Ben', 193, 3.0),
#  ('Ben', 423, 3.0),
#  ('Ben', 424, 2.0),
#  ('Ben', 86, 3.5),
#  ('Ben', 308, 2.5),
#  ('Ben', 419, 3.0),
#  ('Ben', 418, 3.0),
#  ('Ben', 352, 3.0),
#  ('Ben', 421, 3.0),
#  ('Ben', 420, 3.5),
#  ('Ben', 176, 3.0),
#  ('Ben', 422, 3.0),
#  ('Ben', 525, 3.0),
#  ('Ben', 473, 3.5),
#  ('BonseokKoo', 326, 3.5),
#  ('BonseokKoo', 102, 4.0),
#  ('BonseokKoo', 328, 3.5),
#  ('BonseokKoo', 191, 1.5),
#  ('BonseokKoo', 164, 1.5),
#  ('BonseokKoo', 465, 1.5),
#  ('BonseokKoo', 365, 4.5),
#  ('BonseokKoo', 170, 3.0),
#  ('BonseokKoo', 660, 5.0),
#  ('BonseokKoo', 373, 5.0),
#  ('BonseokKoo', 616, 3.5),
#  ('BonseokKoo', 364, 2.5),
#  ('BonseokKoo', 190, 5.0),
#  ('BonseokKoo', 577, 3.5),
#  ('BonseokKoo', 322, 4.0),
#  ('BonseokKoo', 137, 3.0),
#  ('BonseokKoo', 18, 3.0),
#  ('BonseokKoo', 14, 4.5),
#  ('BonseokKoo', 329, 3.0),
#  ('BonseokKoo', 27, 2.0),
#  ('BonseokKoo', 15, 2.5),
#  ('BonseokKoo', 325, 3.0),
#  ('BonseokKoo', 109, 4.0),
#  ('BonseokKoo', 324, 3.5),
#  ('BonseokKoo', 492, 4.5),
#  ('BonseokKoo', 16, 3.5),
#  ('BonseokKoo', 579, 3.5),
#  ('BonseokKoo', 655, 2.5),
#  ('BonseokKoo', 166, 3.5),
#  ('BonseokKoo', 192, 2.5),
#  ('BonseokKoo', 367, 4.5),
#  ('BonseokKoo', 469, 4.0),
#  ('BonseokKoo', 171, 4.5),
#  ('BonseokKoo', 327, 4.5),
#  ('BonseokKoo', 89, 4.5),
#  ('BonseokKoo', 133, 3.0),
#  ('BonseokKoo', 193, 3.5),
#  ('BonseokKoo', 491, 5.0),
#  ('BonseokKoo', 581, 3.5),
#  ('BonseokKoo', 437, 4.0),
#  ('BonseokKoo', 165, 3.0),
#  ('BonseokKoo', 69, 3.5),
#  ('BonseokKoo', 564, 3.0),
#  ('BonseokKoo', 62, 3.0),
#  ('BonseokKoo', 330, 3.0),
#  ('BonseokKoo', 635, 5.0),
#  ('BonseokKoo', 189, 4.5),
#  ('BonseokKoo', 185, 4.0),
#  ('BonseokKoo', 476, 3.0),
#  ('BonseokKoo', 176, 2.5),
#  ('BonseokKoo', 477, 3.5),
#  ('BonseokKoo', 184, 3.5),
#  ('BonseokKoo', 177, 4.5),
#  ('BonseokKoo', 88, 4.0),
#  ('BonseokKoo', 106, 4.0),
#  ('BonseokKoo', 178, 3.0),
#  ('BonseokKoo', 24, 5.0),
#  ('BonseokKoo', 658, 1.5),
#  ('BonseokKoo', 20, 3.5),
#  ('BonseokKoo', 349, 3.0),
#  ('BonseokKoo', 135, 4.5),
#  ('BonseokKoo', 347, 2.5),
#  ('BonseokKoo', 569, 4.5),
#  ('BonseokKoo', 624, 5.0),
#  ('BonseokKoo', 65, 3.0),
#  ('BonseokKoo', 657, 3.5),
#  ('BonseokKoo', 181, 3.5),
#  ('BonseokKoo', 346, 4.5),
#  ('BonseokKoo', 345, 2.5),
#  ('BonseokKoo', 23, 2.5),
#  ('BonseokKoo', 343, 3.5),
#  ('BonseokKoo', 480, 4.0),
#  ('BonseokKoo', 633, 5.0),
#  ('BonseokKoo', 338, 4.5),
#  ('BonseokKoo', 475, 4.5),
#  ('BonseokKoo', 565, 2.0),
#  ('BonseokKoo', 172, 3.0),
#  ('BonseokKoo', 489, 5.0),
#  ('BonseokKoo', 188, 4.0),
#  ('BonseokKoo', 361, 3.0),
#  ('BonseokKoo', 78, 4.0),
#  ('BonseokKoo', 26, 3.5),
#  ('BonseokKoo', 488, 5.0),
#  ('BonseokKoo', 576, 3.0),
#  ('BonseokKoo', 19, 4.0),
#  ('BonseokKoo', 566, 3.0),
#  ('BonseokKoo', 659, 4.5),
#  ('BonseokKoo', 334, 4.0),
#  ('BonseokKoo', 335, 1.5),
#  ('BonseokKoo', 173, 3.5),
#  ('BonseokKoo', 134, 5.0),
#  ('BonseokKoo', 359, 5.0),
#  ('BonseokKoo', 575, 4.5),
#  ('BonseokKoo', 567, 4.5),
#  ('BonseokKoo', 336, 1.5),
#  ('BonseokKoo', 68, 2.0),
#  ('BonseokKoo', 186, 3.5),
#  ('BonseokKoo', 431, 4.0),
#  ('BonseokKoo', 25, 3.5),
#  ('BonseokKoo', 187, 3.5),
#  ('BonseokKoo', 572, 3.5),
#  ('BonseokKoo', 115, 2.0),
#  ('BonseokKoo', 321, 2.5),
#  ('BonseokKoo', 265, 4.0),
#  ('BonseokKoo', 218, 4.5),
#  ('BonseokKoo', 548, 3.5),
#  ('BonseokKoo', 263, 5.0),
#  ('BonseokKoo', 525, 2.5),
#  ('BonseokKoo', 44, 4.5),
#  ('BonseokKoo', 606, 3.0),
#  ('BonseokKoo', 524, 5.0),
#  ('BonseokKoo', 260, 3.5),
#  ('BonseokKoo', 258, 4.5),
#  ('BonseokKoo', 45, 3.0),
#  ('BonseokKoo', 256, 4.5),
#  ('BonseokKoo', 547, 4.5),
#  ('BonseokKoo', 254, 3.5),
#  ('BonseokKoo', 530, 3.5),
#  ('BonseokKoo', 253, 4.0),
#  ('BonseokKoo', 646, 3.0),
#  ('BonseokKoo', 217, 3.0),
#  ('BonseokKoo', 549, 2.5),
#  ('BonseokKoo', 266, 4.5),
#  ('BonseokKoo', 0, 4.0),
#  ('BonseokKoo', 519, 2.5),
#  ('BonseokKoo', 272, 4.5),
#  ('BonseokKoo', 520, 2.0),
#  ('BonseokKoo', 93, 2.5),
#  ('BonseokKoo', 271, 3.0),
#  ('BonseokKoo', 214, 4.0),
#  ('BonseokKoo', 41, 3.5),
#  ('BonseokKoo', 551, 1.5),
#  ('BonseokKoo', 648, 4.5),
#  ('BonseokKoo', 268, 4.5),
#  ('BonseokKoo', 522, 3.0),
#  ('BonseokKoo', 523, 2.5),
#  ('BonseokKoo', 56, 3.0),
#  ('BonseokKoo', 121, 3.5),
#  ('BonseokKoo', 216, 3.5),
#  ('BonseokKoo', 43, 3.5),
#  ('BonseokKoo', 251, 4.5),
#  ('BonseokKoo', 46, 4.5),
#  ('BonseokKoo', 80, 2.0),
#  ('BonseokKoo', 602, 2.5),
#  ('BonseokKoo', 543, 3.5),
#  ('BonseokKoo', 239, 3.5),
#  ('BonseokKoo', 238, 3.5),
#  ('BonseokKoo', 669, 3.5),
#  ('BonseokKoo', 52, 3.0),
#  ('BonseokKoo', 229, 5.0),
#  ('BonseokKoo', 237, 3.5),
#  ('BonseokKoo', 50, 3.5),
#  ('BonseokKoo', 541, 5.0),
#  ('BonseokKoo', 235, 3.5),
#  ('BonseokKoo', 539, 4.5),
#  ('BonseokKoo', 234, 4.0),
#  ('BonseokKoo', 126, 3.5),
#  ('BonseokKoo', 540, 2.0),
#  ('BonseokKoo', 233, 4.0),
#  ('BonseokKoo', 232, 4.5),
#  ('BonseokKoo', 643, 5.0),
#  ('BonseokKoo', 241, 3.0),
#  ('BonseokKoo', 607, 3.5),
#  ('BonseokKoo', 82, 2.5),
#  ('BonseokKoo', 243, 1.0),
#  ('BonseokKoo', 250, 4.0),
#  ('BonseokKoo', 54, 3.5),
#  ('BonseokKoo', 546, 5.0),
#  ('BonseokKoo', 128, 4.0),
#  ('BonseokKoo', 545, 3.5),
#  ('BonseokKoo', 605, 1.0),
#  ('BonseokKoo', 224, 3.5),
#  ('BonseokKoo', 47, 4.0),
#  ('BonseokKoo', 248, 2.5),
#  ('BonseokKoo', 533, 4.0),
#  ('BonseokKoo', 225, 3.5),
#  ('BonseokKoo', 247, 4.0),
#  ('BonseokKoo', 127, 4.0),
#  ('BonseokKoo', 246, 3.0),
#  ('BonseokKoo', 53, 2.5),
#  ('BonseokKoo', 226, 3.5),
#  ('BonseokKoo', 48, 3.5),
#  ('BonseokKoo', 242, 3.0),
#  ('BonseokKoo', 640, 3.5),
#  ('BonseokKoo', 274, 4.0),
#  ('BonseokKoo', 518, 1.0),
#  ('BonseokKoo', 310, 2.0),
#  ('BonseokKoo', 200, 1.5),
#  ('BonseokKoo', 131, 3.0),
#  ('BonseokKoo', 308, 4.5),
#  ('BonseokKoo', 306, 5.0),
#  ('BonseokKoo', 559, 2.5),
#  ('BonseokKoo', 304, 2.5),
#  ('BonseokKoo', 201, 3.5),
#  ('BonseokKoo', 202, 2.0),
#  ('BonseokKoo', 558, 3.5),
#  ('BonseokKoo', 114, 3.5),
#  ('BonseokKoo', 303, 3.5),
#  ('BonseokKoo', 203, 3.5),
#  ('BonseokKoo', 600, 4.0),
#  ('BonseokKoo', 301, 3.5),
#  ('BonseokKoo', 300, 4.5),
#  ('BonseokKoo', 130, 3.0),
#  ('BonseokKoo', 199, 4.0),
#  ('BonseokKoo', 116, 3.5),
#  ('BonseokKoo', 86, 3.5),
#  ('BonseokKoo', 113, 3.5),
#  ('BonseokKoo', 320, 3.5),
#  ('BonseokKoo', 495, 3.0),
#  ('BonseokKoo', 29, 4.0),
#  ('BonseokKoo', 194, 2.0),
#  ('BonseokKoo', 562, 4.0),
#  ('BonseokKoo', 654, 1.5),
#  ('BonseokKoo', 318, 4.5),
#  ('BonseokKoo', 30, 4.5),
#  ('BonseokKoo', 317, 4.0),
#  ('BonseokKoo', 196, 5.0),
#  ('BonseokKoo', 561, 2.5),
#  ('BonseokKoo', 132, 3.5),
#  ('BonseokKoo', 621, 4.5),
#  ('BonseokKoo', 316, 3.0),
#  ('BonseokKoo', 637, 3.5),
#  ('BonseokKoo', 31, 3.5),
#  ('BonseokKoo', 653, 4.5),
#  ('BonseokKoo', 499, 3.0),
#  ('BonseokKoo', 494, 3.0),
#  ('BonseokKoo', 506, 5.0),
#  ('BonseokKoo', 507, 2.5),
#  ('BonseokKoo', 38, 2.5),
#  ('BonseokKoo', 285, 4.5),
#  ('BonseokKoo', 283, 4.0),
#  ('BonseokKoo', 210, 4.5),
#  ('BonseokKoo', 281, 0.5),
#  ('BonseokKoo', 553, 3.5),
#  ('BonseokKoo', 39, 4.0),
#  ('BonseokKoo', 552, 4.5),
#  ('BonseokKoo', 649, 3.0),
#  ('BonseokKoo', 212, 3.5),
#  ('BonseokKoo', 517, 4.5),
#  ('BonseokKoo', 277, 4.5),
#  ('BonseokKoo', 276, 3.0),
#  ('BonseokKoo', 129, 4.5),
#  ('BonseokKoo', 213, 5.0),
#  ('BonseokKoo', 275, 2.0),
#  ('BonseokKoo', 57, 1.5),
#  ('BonseokKoo', 79, 3.0),
#  ('BonseokKoo', 204, 2.5),
#  ('BonseokKoo', 58, 4.0),
#  ('BonseokKoo', 288, 4.5),
#  ('BonseokKoo', 297, 4.5),
#  ('BonseokKoo', 205, 2.5),
#  ('BonseokKoo', 84, 3.5),
#  ('BonseokKoo', 296, 1.5),
#  ('BonseokKoo', 295, 2.5),
#  ('BonseokKoo', 509, 2.5),
#  ('BonseokKoo', 556, 3.5),
#  ('BonseokKoo', 36, 3.0),
#  ('BonseokKoo', 59, 2.5),
#  ('BonseokKoo', 206, 5.0),
#  ('BonseokKoo', 294, 3.5),
#  ('BonseokKoo', 292, 5.0),
#  ('BonseokKoo', 639, 4.0),
#  ('BonseokKoo', 207, 4.0),
#  ('BonseokKoo', 37, 3.5),
#  ('BonseokKoo', 626, 3.0),
#  ('BonseokKoo', 289, 4.5),
#  ('BonseokKoo', 208, 5.0),
#  ('BonseokKoo', 71, 4.5),
#  ('BonseokKoo', 63, 2.0),
#  ('BonseokKoo', 665, 4.0),
#  ('BonseokKoo', 620, 3.5),
#  ('BonseokKoo', 585, 1.0),
#  ('BonseokKoo', 589, 3.5),
#  ('BonseokKoo', 144, 3.5),
#  ('BonseokKoo', 13, 5.0),
#  ('BonseokKoo', 451, 4.0),
#  ('BonseokKoo', 398, 3.5),
#  ('BonseokKoo', 583, 5.0),
#  ('BonseokKoo', 77, 4.5),
#  ('BonseokKoo', 408, 0.5),
#  ('BonseokKoo', 142, 4.0),
#  ('BonseokKoo', 161, 2.5),
#  ('BonseokKoo', 153, 3.5),
#  ('BonseokKoo', 452, 2.0),
#  ('BonseokKoo', 155, 2.0),
#  ('BonseokKoo', 380, 4.5),
#  ('BonseokKoo', 9, 4.5),
#  ('BonseokKoo', 8, 3.5),
#  ('BonseokKoo', 462, 3.0),
#  ('BonseokKoo', 456, 2.0),
#  ('BonseokKoo', 91, 1.0),
#  ('BonseokKoo', 11, 3.5),
#  ('BonseokKoo', 149, 2.0),
#  ('BonseokKoo', 459, 3.0),
#  ('BonseokKoo', 412, 3.5),
#  ('BonseokKoo', 147, 4.0),
#  ('BonseokKoo', 447, 3.5),
#  ('BonseokKoo', 463, 4.0),
#  ('BonseokKoo', 7, 4.0),
#  ('BonseokKoo', 396, 4.5),
#  ('BonseokKoo', 590, 4.5),
#  ('BonseokKoo', 630, 2.5),
#  ('BonseokKoo', 160, 4.0),
#  ('BonseokKoo', 622, 5.0),
#  ('BonseokKoo', 440, 3.5),
#  ('BonseokKoo', 150, 4.0),
#  ('BonseokKoo', 98, 3.5),
#  ('BonseokKoo', 387, 3.5),
#  ('BonseokKoo', 383, 3.0),
#  ('BonseokKoo', 662, 4.0),
#  ('BonseokKoo', 409, 3.0),
#  ('BonseokKoo', 157, 2.5),
#  ('BonseokKoo', 593, 3.0),
#  ('BonseokKoo', 76, 4.0),
#  ('BonseokKoo', 584, 2.5),
#  ('BonseokKoo', 158, 4.5),
#  ('BonseokKoo', 90, 4.0),
#  ('BonseokKoo', 595, 3.5),
#  ('BonseokKoo', 582, 2.5),
#  ('BonseokKoo', 159, 3.5),
#  ('BonseokKoo', 92, 2.5),
#  ('BonseokKoo', 99, 1.5),
#  ('BonseokKoo', 97, 4.0),
#  ('BonseokKoo', 163, 3.0),
#  ('BonseokKoo', 143, 4.5),
#  ('BonseokKoo', 386, 2.5),
#  ('BonseokKoo', 667, 3.5),
#  ('BonseokKoo', 592, 4.0),
#  ('BonseokKoo', 4, 4.0),
#  ('BonseokKoo', 100, 2.5),
#  ('BonseokKoo', 72, 4.5),
#  ('BonseokKoo', 139, 4.5),
#  ('BonseokKoo', 145, 4.0),
#  ('BonseokKoo', 586, 3.5),
#  ('BonseokKoo', 414, 2.5),
#  ('BonseokKoo', 458, 4.0),
#  ('BonseokKoo', 631, 3.5),
#  ('BonseokKoo', 6, 2.0),
#  ('BonseokKoo', 392, 4.0),
#  ('Brill', 358, 4.5),
#  ('Brill', 635, 4.0),
#  ('Brill', 537, 4.0),
#  ('Brill', 429, 2.0),
#  ('Brill', 231, 3.5),
#  ('Brill', 489, 4.0),
#  ('Brill', 522, 3.0),
#  ('Brill', 437, 3.5),
#  ('Brill', 600, 4.0),
#  ('Brill', 390, 3.5),
#  ('Brill', 461, 3.0),
#  ('Brill', 666, 3.0),
#  ('Brill', 359, 4.5),
#  ('Brill', 512, 3.5),
#  ('Brisa', 407, 3.5),
#  ('Brisa', 204, 1.5),
#  ('Brisa', 241, 3.5),
#  ('Brisa', 214, 3.5),
#  ('Brisa', 598, 2.5),
#  ('Brisa', 265, 3.5),
#  ('Brisa', 607, 3.5),
#  ('Brisa', 603, 3.0),
#  ('Brisa', 427, 3.0),
#  ('Brisa', 180, 4.0),
#  ('Brisa', 398, 2.0),
#  ('Brisa', 506, 4.0),
#  ('Brisa', 296, 3.0),
#  ('Brisa', 533, 4.0),
#  ('CHAEYOOE', 160, 3.0),
#  ('CHAEYOOE', 624, 4.5),
#  ('CHAEYOOE', 215, 3.5),
#  ('CHAEYOOE', 192, 2.0),
#  ('CHAEYOOE', 36, 3.0),
#  ('CHAEYOOE', 522, 2.5),
#  ('CHAEYOOE', 181, 3.0),
#  ('CHAEYOOE', 232, 3.5),
#  ('CHAEYOOE', 586, 3.0),
#  ('CHAEYOOE', 629, 3.5),
#  ('CHAEYOOE', 492, 3.5),
#  ('CHAEYOOE', 128, 3.5),
#  ('CHAEYOOE', 118, 4.0),
#  ('CHAEYOOE', 628, 4.0),
#  ('CHAEYOOE', 340, 4.5),
#  ('CHAEYOOE', 228, 3.0),
#  ('CHAEYOOE', 250, 3.5),
#  ('CHAEYOOE', 203, 2.5),
#  ('CHAEYOOE', 172, 2.0),
#  ('CHAEYOOE', 88, 3.0),
#  ('CHAEYOOE', 135, 3.0),
#  ('CHAEYOOE', 43, 3.0),
#  ('CHAEYOOE', 29, 3.5),
#  ('CHAEYOOE', 132, 3.5),
#  ('CHAEYOOE', 267, 3.0),
#  ('CHAEYOOE', 265, 3.5),
#  ('CHAEYOOE', 121, 3.0),
#  ('CHAEYOOE', 436, 3.5),
#  ('CHAEYOOE', 116, 3.5),
#  ('CHAEYOOE', 537, 3.5),
#  ('CHAEYOOE', 83, 3.5),
#  ('CHAEYOOE', 142, 4.0),
#  ('CHAEYOOE', 523, 2.0),
#  ('CHAEYOOE', 24, 4.5),
#  ('CHAEYOOE', 580, 2.5),
#  ('CHAEYOOE', 100, 2.0),
#  ('CHAEYOOE', 216, 2.5),
#  ('CHAEYOOE', 189, 4.0),
#  ('CHAEYOOE', 210, 4.0),
#  ('CHAEYOOE', 528, 3.5),
#  ('CHAEYOOE', 122, 2.5),
#  ('CHAEYOOE', 365, 4.0),
#  ('CHAEYOOE', 9, 4.0),
#  ('CHAEYOOE', 242, 3.0),
#  ('CHAEYOOE', 113, 3.0),
#  ('CHAEYOOE', 157, 2.0),
#  ('CHAEYOOE', 129, 3.5),
#  ('CHAEYOOE', 175, 3.0),
#  ('CHAEYOOE', 39, 4.0),
#  ('CHAEYOOE', 592, 4.0),
#  ('CHAEYOOE', 120, 3.0),
#  ('CHAEYOOE', 126, 2.5),
#  ('CHAEYOOE', 535, 3.5),
#  ('CHAEYOOE', 143, 3.5),
#  ('CHAEYOOE', 367, 4.0),
#  ('CHAEYOOE', 26, 3.0),
#  ('CHAEYOOE', 127, 2.5),
#  ('CHAEYOOE', 57, 2.0),
#  ('CHAEYOOE', 230, 3.5),
#  ('CHAEYOOE', 177, 3.0),
#  ('CHAEYOOE', 49, 2.0),
#  ('CHAEYOOE', 565, 1.0),
#  ('CHAEYOOE', 76, 4.0),
#  ('CHAEYOOE', 47, 3.0),
#  ('CHAEYOOE', 71, 4.5),
#  ('CHAEYOOE', 239, 2.5),
#  ('CHAEYOOE', 209, 5.0),
#  ('CHAEYOOE', 214, 3.5),
#  ('CHAEYOOE', 200, 1.0),
#  ('CHAEYOOE', 308, 3.5),
#  ('CINEX', 431, 4.0),
#  ('CINEX', 3, 3.5),
#  ('CINEX', 381, 0.5),
#  ('CINEX', 513, 4.0),
#  ('CINEX', 452, 1.0),
#  ('CINEX', 41, 4.0),
#  ('CINEX', 554, 0.5),
#  ('CINEX', 334, 3.0),
#  ('CINEX', 335, 2.5),
#  ('CINEX', 557, 3.5),
#  ('CMKworld', 100, 3.0),
#  ('CMKworld', 305, 3.0),
#  ('CMKworld', 176, 3.0),
#  ('CMKworld', 173, 3.5),
#  ('CMKworld', 130, 3.5),
#  ('CMKworld', 169, 2.5),
#  ('CMKworld', 567, 4.5),
#  ('CMKworld', 157, 2.5),
#  ('CMKworld', 170, 2.5),
#  ('CMKworld', 92, 2.5),
#  ('CMKworld', 93, 2.5),
#  ('CMKworld', 138, 2.5),
#  ('CMKworld', 160, 4.0),
#  ('CMKworld', 144, 3.5),
#  ('CMKworld', 142, 4.0),
#  ('CMKworld', 165, 2.5),
#  ('Camellia', 431, 3.0),
#  ('Camellia', 537, 4.0),
#  ('Camellia', 489, 4.5),
#  ('Camellia', 178, 3.0),
#  ('Camellia', 11, 3.5),
#  ('Camellia', 613, 4.0),
#  ('Camellia', 180, 4.0),
#  ('Camellia', 97, 4.0),
#  ('Camellia', 72, 4.5),
#  ('Camellia', 392, 2.5),
#  ('Camellia', 621, 3.5),
#  ('Camellia', 570, 4.0),
#  ('Camellia', 479, 4.0),
#  ('Camellia', 2, 3.0),
#  ('Camellia', 342, 4.0),
#  ('Camellia', 390, 3.5),
#  ('Camellia', 494, 3.5),
#  ('Camellia', 488, 5.0),
#  ('Camellia', 134, 4.0),
#  ('Camellia', 338, 4.5),
#  ('Camellia', 536, 4.0),
#  ('Camellia', 341, 3.5),
#  ('Camellia', 324, 5.0),
#  ('Camellia', 28, 4.0),
#  ('Camellia', 653, 4.5),
#  ('Camellia', 184, 3.0),
#  ('Camellia', 478, 4.0),
#  ('Camellia', 98, 3.5),
#  ('Camellia', 486, 4.0),
#  ('Camellia', 491, 4.0),
#  ('Camellia', 67, 3.5),
#  ('Camellia', 437, 4.0),
#  ('Camellia', 666, 2.5),
#  ('Camellia', 480, 4.0),
#  ('Camellia', 497, 4.5),
#  ('Camellia', 668, 4.0),
#  ('Camellia', 475, 3.5),
#  ('Camellia', 380, 4.0),
#  ('Camellia', 86, 3.0),
#  ('Camellia', 629, 3.5),
#  ('Camellia', 147, 4.0),
#  ('Camellia', 412, 3.5),
#  ('Camellia', 428, 2.5),
#  ('Camellia', 212, 3.5),
#  ('Camellia', 69, 4.0),
#  ('Camellia', 533, 3.5),
#  ('Camellia', 214, 4.0),
#  ('Camellia', 113, 3.0),
#  ('Camellia', 129, 4.0),
#  ('Camellia', 74, 4.5),
#  ('Camellia', 513, 3.0),
#  ('Camellia', 37, 3.0),
#  ('Camellia', 247, 3.5),
#  ('Camellia', 294, 4.0),
#  ('Camellia', 628, 4.0),
#  ('Camellia', 515, 4.0),
#  ('Camellia', 235, 2.5),
#  ('Camellia', 249, 5.0),
#  ('Camellia', 532, 3.0),
#  ('Camellia', 45, 3.0),
#  ('Camellia', 251, 4.0),
#  ('Camellia', 592, 4.0),
#  ('Camellia', 5, 4.0),
#  ('Camellia', 220, 3.5),
#  ('Camellia', 527, 3.0),
#  ('Camellia', 55, 4.0),
#  ('Camellia', 41, 3.5),
#  ('Camellia', 546, 4.0),
#  ('Camellia', 216, 3.0),
#  ('Camellia', 436, 4.0),
#  ('Camellia', 215, 4.0),
#  ('Camellia', 268, 4.5),
#  ('Camellia', 407, 4.0),
#  ('Camellia', 468, 3.0),
#  ('Camellia', 660, 3.5),
#  ('Camellia', 71, 4.0),
#  ('Camellia', 297, 4.0),
#  ('Camellia', 365, 4.0),
#  ('Camellia', 9, 4.0),
#  ('Camellia', 201, 4.5),
#  ('Camellia', 309, 3.0),
#  ('Camellia', 202, 3.0),
#  ('Camellia', 432, 3.0),
#  ('Camellia', 505, 2.5),
#  ('Camellia', 19, 3.0),
#  ('Camellia', 604, 3.5),
#  ('Camellia', 114, 3.5),
#  ('Camellia', 306, 5.0),
#  ('Camellia', 358, 2.5),
#  ('Camellia', 538, 2.5),
#  ('Camellia', 461, 4.0),
#  ('Camellia', 539, 5.0),
#  ('Camellia', 88, 4.0),
#  ('Cinephile', 84, 2.0),
#  ('Cinephile', 623, 2.5),
#  ('Cinephile', 594, 2.0),
#  ('Cinephile', 251, 3.0),
#  ('Cinephile', 209, 3.5),
#  ('Cinephile', 188, 1.5),
#  ('Cinephile', 216, 3.0),
#  ('Cinephile', 196, 3.5),
#  ('Cinephile', 306, 3.5),
#  ('Cinephile', 259, 3.5),
#  ('Cinephile', 567, 4.0),
#  ('Cinephile', 307, 4.0),
#  ('Cinephile', 215, 3.5),
#  ('Cinephile', 83, 3.5),
#  ('Cinephile', 24, 3.5),
#  ('Cinephile', 621, 2.0),
#  ('Cinephile', 72, 3.5),
#  ('Cinephile', 232, 3.0),
#  ('Cinephile', 128, 3.0),
#  ('Cinephile', 70, 3.5),
#  ('Cinephile', 13, 3.5),
#  ('Cinephile', 373, 4.5),
#  ('Cinephile', 170, 1.5),
#  ('Cinephile', 229, 3.5),
#  ('Cinephile', 14, 3.5),
#  ('DamianJeonDongHyun', 240, 5.0),
#  ('DamianJeonDongHyun', 614, 5.0),
#  ('DamianJeonDongHyun', 362, 2.0),
#  ('DamianJeonDongHyun', 591, 1.0),
#  ('DamianJeonDongHyun', 445, 2.0),
#  ('DamianJeonDongHyun', 632, 3.0),
#  ('DamianJeonDongHyun', 647, 5.0),
#  ('DamianJeonDongHyun', 386, 2.0),
#  ('DamianJeonDongHyun', 590, 5.0),
#  ('DamianJeonDongHyun', 444, 3.0),
#  ('DamianJeonDongHyun', 0, 4.0),
#  ('DamianJeonDongHyun', 559, 2.0),
#  ('DamianJeonDongHyun', 542, 5.0),
#  ('Dh', 300, 4.5),
#  ('Dh', 324, 3.5),
#  ('Dh', 32, 3.5),
#  ('Dh', 332, 3.0),
#  ('Dh', 23, 2.0),
#  ('Dh', 363, 3.0),
#  ('Dh', 5, 2.5),
#  ('Dh', 464, 4.0),
#  ('Dh', 19, 3.5),
#  ('Dh', 622, 5.0),
#  ('Dh', 14, 4.5),
#  ('Dh', 387, 3.0),
#  ('Dh', 606, 2.5),
#  ('Dh', 7, 4.0),
#  ('Dh', 9, 4.0),
#  ('Dh', 180, 4.0),
#  ('Dh', 83, 3.5),
#  ('Dh', 119, 2.5),
#  ('Dh', 15, 2.5),
#  ('Dilettante', 156, 3.0),
#  ('Dilettante', 4, 4.0),
#  ('Dilettante', 159, 3.5),
#  ('Dilettante', 137, 2.5),
#  ('Dilettante', 106, 3.5),
#  ('Dilettante', 155, 2.5),
#  ('Dilettante', 135, 3.5),
#  ('Dilettante', 92, 3.0),
#  ('Dilettante', 70, 5.0),
#  ('Dilettante', 100, 2.5),
#  ('Dilettante', 144, 3.0),
#  ('Dilettante', 187, 4.5),
#  ('Dilettante', 94, 3.0),
#  ('Dilettante', 163, 1.5),
#  ('Dilettante', 633, 4.0),
#  ('Dilettante', 96, 2.5),
#  ('Dilettante', 285, 3.5),
#  ('Dilettante', 121, 3.0),
#  ('Dilettante', 129, 3.0),
#  ('Dilettante', 128, 3.5),
#  ('Dilettante', 77, 4.0),
#  ('Dilettante', 190, 4.0),
#  ('Dilettante', 145, 3.0),
#  ('Dilettante', 139, 3.0),
#  ('Dilettante', 138, 1.0),
#  ('Dilettante', 109, 3.0),
#  ('Dilettante', 161, 3.5),
#  ('Dilettante', 93, 1.5),
#  ('Dilettante', 108, 3.5),
#  ('Django', 623, 5.0),
#  ('Django', 594, 3.5),
#  ('Django', 518, 2.0),
#  ('Django', 489, 5.0),
#  ('Django', 541, 5.0),
#  ('Django', 273, 3.5),
#  ('Django', 474, 4.0),
#  ('Django', 346, 4.0),
#  ('Django', 327, 4.5),
#  ('Django', 561, 3.0),
#  ('Django', 410, 4.5),
#  ('Django', 526, 4.0),
#  ('Django', 247, 3.5),
#  ('Django', 475, 4.5),
#  ('Doo', 114, 4.0),
#  ('Doo', 574, 3.5),
#  ('Doo', 313, 4.0),
#  ('Doo', 446, 2.5),
#  ('Doo', 18, 4.0),
#  ('Doo', 246, 3.5),
#  ('Doo', 42, 2.5),
#  ('Doo', 312, 3.0),
#  ('Doo', 219, 3.5),
#  ('Doo', 36, 4.0),
#  ('Doo', 294, 4.0),
#  ('Doo', 361, 4.0),
#  ('Doo', 310, 3.0),
#  ('Doo', 398, 3.5),
#  ('Doo', 509, 3.5),
#  ('Doo', 19, 3.5),
#  ('Doo', 99, 3.5),
#  ('Doo', 95, 3.0),
#  ('Doo', 573, 3.5),
#  ('Doo', 193, 3.0),
#  ('Doo', 150, 4.0),
#  ('Doo', 445, 3.5),
#  ('Doo', 579, 3.5),
#  ('Doo', 369, 4.0),
#  ('Doo', 41, 3.5),
#  ('Doo', 217, 4.0),
#  ('Doo', 353, 4.0),
#  ('Doo', 418, 4.0),
#  ('Doo', 542, 4.0),
#  ('Doo', 166, 4.5),
#  ('Doo', 96, 4.0),
#  ('Doo', 511, 3.0),
#  ('Doo', 408, 3.0),
#  ('Doo', 228, 4.0),
#  ('Doo', 52, 3.5),
#  ('Doo', 216, 4.0),
#  ('Doo', 101, 3.0),
#  ('Doo', 473, 4.0),
#  ('Doo', 367, 4.0),
#  ('Doo', 194, 4.0),
#  ('Doo', 290, 3.0),
#  ('Doo', 124, 4.0),
#  ('Doo', 176, 3.5),
#  ('Doo', 135, 4.5),
#  ('Doo', 424, 3.5),
#  ('Doo', 281, 2.0),
#  ('Doo', 129, 4.0),
#  ('Doo', 121, 4.0),
#  ('Doo', 658, 3.5),
#  ('Doo', 352, 4.0),
#  ('Doo', 242, 4.0),
#  ('Doo', 585, 2.0),
#  ('Doo', 253, 4.0),
#  ('Doo', 54, 4.0),
#  ('Doo', 202, 4.0),
#  ('Doo', 163, 4.0),
#  ('Doo', 426, 4.0),
#  ('Doo', 234, 4.0),
#  ('Doo', 3, 3.0),
#  ('Doo', 68, 4.0),
#  ('Doo', 119, 3.5),
#  ('Doo', 422, 4.0),
#  ('Doo', 180, 4.5),
#  ('Doo', 55, 3.5),
#  ('Doo', 186, 4.0),
#  ('Doo', 417, 3.0),
#  ('Doo', 661, 4.0),
#  ('Doo', 25, 4.0),
#  ('Doo', 56, 4.0),
#  ('Doo', 133, 3.5),
#  ('Doo', 463, 4.0),
#  ('Doo', 21, 4.0),
#  ('Doo', 526, 5.0),
#  ('Doo', 168, 3.5),
#  ('Doo', 57, 3.5),
#  ('Doo', 221, 3.5),
#  ('Doo', 470, 3.0),
#  ('Doo', 33, 3.0),
#  ('Doo', 24, 4.5),
#  ('Doo', 423, 3.5),
#  ('Doo', 156, 4.0),
#  ('Doo', 64, 3.5),
#  ('Doo', 220, 4.5),
#  ('Doo', 164, 3.0),
#  ('Doo', 184, 4.0),
#  ('Doo', 419, 4.0),
#  ('Doo', 35, 3.5),
#  ('Doo', 49, 3.5),
#  ('Doo', 157, 3.5),
#  ('Doo', 277, 4.5),
#  ('Doo', 211, 4.0),
#  ('Doo', 351, 3.0),
#  ('Doo', 421, 4.0),
#  ('Doo', 132, 4.0),
#  ('Doo', 170, 4.0),
#  ('Doo', 254, 4.0),
#  ('Doo', 210, 5.0),
#  ('Doo', 331, 4.5),
#  ('Doo', 630, 3.5),
#  ('Doo', 298, 3.5),
#  ('Doo', 566, 4.0),
#  ('Doo', 383, 4.0),
#  ('ElainePark', 220, 3.5),
#  ('ElainePark', 243, 3.0),
#  ('ElainePark', 341, 5.0),
#  ('ElainePark', 227, 3.5),
#  ('ElainePark', 248, 3.0),
#  ('ElainePark', 255, 5.0),
#  ('ElainePark', 375, 4.0),
#  ('ElainePark', 242, 3.0),
#  ('ElainePark', 347, 3.0),
#  ('ElainePark', 309, 3.0),
#  ('ElainePark', 652, 0.5),
#  ('ElainePark', 348, 4.5),
#  ('ElainePark', 402, 4.5),
#  ('ElainePark', 225, 4.5),
#  ('ElainePark', 247, 5.0),
#  ('ElainePark', 287, 4.5),
#  ('ElainePark', 271, 3.5),
#  ('ElainePark', 632, 1.5),
#  ('ElainePark', 324, 5.0),
#  ('ElainePark', 267, 4.5),
#  ('ElainePark', 616, 4.0),
#  ('ElainePark', 319, 4.5),
#  ('ElainePark', 526, 5.0),
#  ('ElainePark', 409, 3.0),
#  ('ElainePark', 190, 5.0),
#  ('ElainePark', 455, 4.0),
#  ('ElainePark', 261, 5.0),
#  ('ElainePark', 613, 4.5),
#  ('ElainePark', 308, 4.5),
#  ('ElainePark', 432, 3.5),
#  ('ElainePark', 320, 3.5),
#  ('ElainePark', 230, 4.0),
#  ('ElainePark', 49, 3.5),
#  ('ElainePark', 290, 2.5),
#  ('ElainePark', 343, 4.5),
#  ('ElainePark', 564, 3.0),
#  ('ElainePark', 415, 4.0),
#  ('ElainePark', 283, 3.5),
#  ...]

# %%
# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

#Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=data,
    test_size=0.1,
    val_size=0.1,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    lr=0.01,
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

# RandomSearch
rs_neumf = RandomSearch(
    model = neumf,
    space=[
        Discrete("num_epochs", [50, 100, 150, 200]),
        Discrete("num_factors", [4, 8]),
        Discrete("batch_size", [128, 256, 512])
    ],
    metric = fm,
    eval_method = ratio_split
)

# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[rs_neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 553
# Number of items = 670
# Number of ratings = 15429
# Max rating = 5.0
# Min rating = 0.5
# Global mean = 3.4
# ---
# Test data:
# Number of users = 480
# Number of items = 629
# Number of ratings = 1932
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Validation data:
# Number of users = 472
# Number of items = 624
# Number of ratings = 1932
# ---
# Total users = 553
# Total items = 670
#
# [RandomSearch_NeuMF] Training started!
# Evaluating: {'batch_size': 512, 'num_epochs': 100, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Early stopping:
# - best epoch = 22, stopped epoch = 27
# - best monitored value = 0.111646 (delta = -0.002216)
#
# Evaluating: {'batch_size': 512, 'num_epochs': 50, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# Early stopping:
# - best epoch = 22, stopped epoch = 27
# - best monitored value = 0.111646 (delta = -0.002216)
#
# Evaluating: {'batch_size': 512, 'num_epochs': 100, 'num_factors': 8}
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Early stopping:
# - best epoch = 8, stopped epoch = 13
# - best monitored value = 0.112632 (delta = -0.007952)
#
# Evaluating: {'batch_size': 512, 'num_epochs': 200, 'num_factors': 8}
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Early stopping:
# - best epoch = 8, stopped epoch = 13
# - best monitored value = 0.112632 (delta = -0.007952)
#
# Evaluating: {'batch_size': 512, 'num_epochs': 100, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Early stopping:
# - best epoch = 22, stopped epoch = 27
# - best monitored value = 0.111646 (delta = -0.002216)
#
# Evaluating: {'batch_size': 256, 'num_epochs': 150, 'num_factors': 8}
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# Early stopping:
# - best epoch = 8, stopped epoch = 13
# - best monitored value = 0.110611 (delta = -0.003041)
#
# Evaluating: {'batch_size': 256, 'num_epochs': 50, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# Early stopping:
# - best epoch = 23, stopped epoch = 28
# - best monitored value = 0.110135 (delta = -0.002242)
#
# Evaluating: {'batch_size': 128, 'num_epochs': 200, 'num_factors': 8}
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.118926 (delta = -0.007085)
#
# Evaluating: {'batch_size': 512, 'num_epochs': 100, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Early stopping:
# - best epoch = 22, stopped epoch = 27
# - best monitored value = 0.111646 (delta = -0.002216)
#
# Evaluating: {'batch_size': 128, 'num_epochs': 50, 'num_factors': 4}
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# Early stopping:
# - best epoch = 16, stopped epoch = 21
# - best monitored value = 0.118016 (delta = -0.005796)
#
# Best parameter settings: {'batch_size': 512, 'num_epochs': 100, 'num_factors': 8}
# F1@10 = 0.0216
#
# [RandomSearch_NeuMF] Evaluation started!
# HBox(children=(FloatProgress(value=0.0, description='Ranking', max=480.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Ranking', max=472.0, style=ProgressStyle(description_widt…
# VALIDATION:
# ...
#                    |  F1@10 | NDCG@10 | Precision@10 | Recall@10 | Time (s)
# ------------------ + ------ + ------- + ------------ + --------- + --------
# RandomSearch_NeuMF | 0.0216 |  0.0294 |       0.0153 |    0.0485 |   0.4348
#
# TEST:
# ...
#                    |  F1@10 | NDCG@10 | Precision@10 | Recall@10 | Train (s) | Test (s)
# ------------------ + ------ + ------- + ------------ + --------- + --------- + --------
# RandomSearch_NeuMF | 0.0166 |  0.0225 |       0.0117 |    0.0422 | 2807.3405 |   0.4269

# %%
print('Random search: ', rs_neumf.best_params)
# Out:
# Random search:  {'batch_size': 512, 'num_epochs': 100, 'num_factors': 8}

# %%
ratio_split = RatioSplit(
    data=data,
    test_size=0.2,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors = rs_neumf.best_params['num_factors'],
    layers=[32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_epochs = rs_neumf.best_params['num_epochs'],
    lr=0.01,
    num_neg=50,
    batch_size = rs_neumf.best_params['batch_size'],
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 553
# Number of items = 670
# Number of ratings = 15429
# Max rating = 5.0
# Min rating = 0.5
# Global mean = 3.4
# ---
# Test data:
# Number of users = 533
# Number of items = 660
# Number of ratings = 3864
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 553
# Total items = 670
#
# [NeuMF] Training started!
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# [NeuMF] Evaluation started!
# HBox(children=(FloatProgress(value=0.0, description='Ranking', max=533.0, style=ProgressStyle(description_widt…
# TEST:
# ...
#       |  F1@10 | NDCG@10 | Precision@10 | Recall@10 | Train (s) | Test (s)
# ----- + ------ + ------- + ------------ + --------- + --------- + --------
# NeuMF | 0.0260 |  0.0286 |       0.0224 |    0.0411 | 1296.6767 |   0.4338

# %%
all_prediction = pd.DataFrame(columns=['u_id','p_id','ncf_score'])

for u_idx,u_id in tqdm(enumerate(data_df['userID'].unique())):
    tmp = pd.DataFrame(neumf.rank(u_idx)).T
    tmp['u_id'] = u_id
    tmp = pd.DataFrame(tmp,columns=['u_id',0,1])
    tmp.rename(columns={0:'p_id',1:'ncf_score'}, inplace=True)
    all_prediction = all_prediction.append(tmp)
# Out:
# 553it [00:15, 35.38it/s]

# %%
all_prediction
# Out:
#          u_id   p_id  ncf_score
# 0    -채여니영화평-  356.0   0.056195
# 1    -채여니영화평-  611.0   0.009988
# 2    -채여니영화평-  627.0   0.000031
# 3    -채여니영화평-  174.0   0.001474
# 4    -채여니영화평-  363.0   0.000002
# 5    -채여니영화평-  106.0   0.003653
# 6    -채여니영화평-  620.0   0.016419
# 7    -채여니영화평-  593.0   0.010590
# 8    -채여니영화평-   42.0   0.000460
# 9    -채여니영화평-  653.0   0.000121
# 10   -채여니영화평-  393.0   0.001103
# 11   -채여니영화평-  374.0   0.005123
# 12   -채여니영화평-  256.0   0.003749
# 13   -채여니영화평-  352.0   0.000220
# 14   -채여니영화평-  335.0   0.017135
# 15   -채여니영화평-  492.0   0.035585
# 16   -채여니영화평-   80.0   0.000102
# 17   -채여니영화평-   28.0   0.009466
# 18   -채여니영화평-  505.0   0.001764
# 19   -채여니영화평-  546.0   0.015927
# 20   -채여니영화평-  112.0   0.004764
# 21   -채여니영화평-  267.0   0.017047
# 22   -채여니영화평-  463.0   0.000113
# 23   -채여니영화평-  622.0   0.047629
# 24   -채여니영화평-  574.0   0.000770
# 25   -채여니영화평-   94.0   0.002023
# 26   -채여니영화평-  249.0   0.003063
# 27   -채여니영화평-   54.0   0.000029
# 28   -채여니영화평-  405.0   0.107562
# 29   -채여니영화평-  156.0   0.007121
# ..        ...    ...        ...
# 640        음키  287.0   0.001739
# 641        음키   27.0   0.023815
# 642        음키  343.0   0.026472
# 643        음키  189.0   0.044288
# 644        음키  149.0   0.015278
# 645        음키  467.0   0.005867
# 646        음키    8.0   0.026057
# 647        음키  260.0   0.053259
# 648        음키  235.0   0.011991
# 649        음키  663.0   0.004558
# 650        음키  342.0   0.036172
# 651        음키  475.0   0.008156
# 652        음키  213.0   0.049803
# 653        음키  552.0   0.008061
# 654        음키  424.0   0.000601
# 655        음키  493.0   0.006174
# 656        음키   73.0   0.021002
# 657        음키  297.0   0.001503
# 658        음키  105.0   0.002754
# 659        음키  601.0   0.012779
# 660        음키   65.0   0.028737
# 661        음키  539.0   0.000524
# 662        음키   71.0   0.060035
# 663        음키  153.0   0.000381
# 664        음키  154.0   0.000750
# 665        음키  201.0   0.001426
# 666        음키    4.0   0.002153
# 667        음키  294.0   0.016911
# 668        음키  639.0   0.009814
# 669        음키    2.0   0.000965
#
# [370510 rows x 3 columns]

# %%
all_prediction.to_csv('../data/predictions/ncf_scores.scv',index=False)
